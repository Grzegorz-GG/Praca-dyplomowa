# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import wandb
import joblib
import torchvision.transforms as transforms
from torchvision.transforms import v2

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import timm
import matplotlib.pyplot as plt

from torch.optim.lr_scheduler import ReduceLROnPlateau
from tqdm import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
gt_path = 'train_gt.csv'
wavelength_path = 'wavelengths.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

output_dir = '/content/test_data'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# !tar -xzvf /content/drive/MyDrive/test.tar.gz -C {output_dir}
# Out:
# test/
# test/77.npz
# test/837.npz
# test/189.npz
# test/63.npz
# test/823.npz
# test/638.npz
# test/610.npz
# test/88.npz
# test/176.npz
# test/162.npz
# test/604.npz
# test/1145.npz
# test/1151.npz
# test/348.npz
# test/374.npz
# test/412.npz
# test/406.npz
# test/360.npz
# test/599.npz
# test/1019.npz
# test/1031.npz
# test/1025.npz
# test/228.npz
# test/200.npz
# test/566.npz
# test/572.npz
# test/214.npz
# test/943.npz
# test/957.npz
# test/758.npz
# test/980.npz
# test/994.npz
# test/764.npz
# test/770.npz
# test/771.npz
# test/765.npz
# test/995.npz
# test/981.npz
# test/759.npz
# test/956.npz
# test/942.npz
# test/573.npz
# test/215.npz
# test/201.npz
# test/567.npz
# test/229.npz
# test/1024.npz
# test/1030.npz
# test/1018.npz
# test/598.npz
# test/407.npz
# test/361.npz
# test/375.npz
# test/413.npz
# test/349.npz
# test/1150.npz
# test/1144.npz
# test/163.npz
# test/605.npz
# test/89.npz
# test/611.npz
# test/177.npz
# test/639.npz
# test/822.npz
# test/62.npz
# test/836.npz
# test/76.npz
# test/188.npz
# test/60.npz
# test/820.npz
# test/74.npz
# test/834.npz
# test/48.npz
# test/808.npz
# test/149.npz
# test/607.npz
# test/161.npz
# test/175.npz
# test/613.npz
# test/388.npz
# test/1152.npz
# test/1146.npz
# test/439.npz
# test/363.npz
# test/405.npz
# test/411.npz
# test/377.npz
# test/1026.npz
# test/1032.npz
# test/559.npz
# test/217.npz
# test/571.npz
# test/565.npz
# test/203.npz
# test/954.npz
# test/940.npz
# test/798.npz
# test/968.npz
# test/997.npz
# test/983.npz
# test/773.npz
# test/767.npz
# test/766.npz
# test/772.npz
# test/982.npz
# test/996.npz
# test/969.npz
# test/799.npz
# test/941.npz
# test/955.npz
# test/564.npz
# test/202.npz
# test/216.npz
# test/570.npz
# test/558.npz
# test/1033.npz
# test/1027.npz
# test/410.npz
# test/376.npz
# test/362.npz
# test/404.npz
# test/438.npz
# test/1147.npz
# test/1153.npz
# test/389.npz
# test/174.npz
# test/612.npz
# test/606.npz
# test/160.npz
# test/148.npz
# test/809.npz
# test/49.npz
# test/835.npz
# test/75.npz
# test/821.npz
# test/61.npz
# test/59.npz
# test/819.npz
# test/65.npz
# test/825.npz
# test/71.npz
# test/831.npz
# test/164.npz
# test/602.npz
# test/616.npz
# test/170.npz
# test/158.npz
# test/1143.npz
# test/399.npz
# test/400.npz
# test/366.npz
# test/372.npz
# test/414.npz
# test/428.npz
# test/1023.npz
# test/1037.npz
# test/574.npz
# test/212.npz
# test/206.npz
# test/560.npz
# test/548.npz
# test/979.npz
# test/951.npz
# test/789.npz
# test/945.npz
# test/776.npz
# test/762.npz
# test/992.npz
# test/986.npz
# test/987.npz
# test/993.npz
# test/763.npz
# test/777.npz
# test/944.npz
# test/788.npz
# test/950.npz
# test/978.npz
# test/549.npz
# test/207.npz
# test/561.npz
# test/575.npz
# test/213.npz
# test/1036.npz
# test/1022.npz
# test/429.npz
# test/373.npz
# test/415.npz
# test/401.npz
# test/367.npz
# test/398.npz
# test/1142.npz
# test/159.npz
# test/617.npz
# test/171.npz
# test/165.npz
# test/603.npz
# test/830.npz
# test/70.npz
# test/824.npz
# test/64.npz
# test/818.npz
# test/58.npz
# test/8.npz
# test/72.npz
# test/832.npz
# test/66.npz
# test/826.npz
# test/198.npz
# test/173.npz
# test/615.npz
# test/99.npz
# test/601.npz
# test/167.npz
# test/629.npz
# test/1140.npz
# test/417.npz
# test/371.npz
# test/365.npz
# test/403.npz
# test/359.npz
# test/1034.npz
# test/1020.npz
# test/1008.npz
# test/588.npz
# test/563.npz
# test/205.npz
# test/211.npz
# test/577.npz
# test/239.npz
# test/946.npz
# test/952.npz
# test/761.npz
# test/775.npz
# test/985.npz
# test/749.npz
# test/991.npz
# test/990.npz
# test/748.npz
# test/984.npz
# test/774.npz
# test/760.npz
# test/953.npz
# test/947.npz
# test/238.npz
# test/210.npz
# test/576.npz
# test/562.npz
# test/204.npz
# test/589.npz
# test/1009.npz
# test/1021.npz
# test/1035.npz
# test/358.npz
# test/364.npz
# test/402.npz
# test/416.npz
# test/370.npz
# test/1141.npz
# test/628.npz
# test/600.npz
# test/98.npz
# test/166.npz
# test/172.npz
# test/614.npz
# test/827.npz
# test/67.npz
# test/199.npz
# test/833.npz
# test/73.npz
# test/9.npz
# test/14.npz
# test/854.npz
# test/698.npz
# test/840.npz
# test/28.npz
# test/868.npz
# test/129.npz
# test/897.npz
# test/883.npz
# test/115.npz
# test/673.npz
# test/667.npz
# test/101.npz
# test/1126.npz
# test/1132.npz
# test/459.npz
# test/471.npz
# test/317.npz
# test/303.npz
# test/465.npz
# test/288.npz
# test/1052.npz
# test/1046.npz
# test/539.npz
# test/1091.npz
# test/505.npz
# test/263.npz
# test/277.npz
# test/511.npz
# test/1085.npz
# test/920.npz
# test/934.npz
# test/908.npz
# test/707.npz
# test/713.npz
# test/712.npz
# test/706.npz
# test/909.npz
# test/935.npz
# test/921.npz
# test/276.npz
# test/1084.npz
# test/510.npz
# test/504.npz
# test/1090.npz
# test/262.npz
# test/538.npz
# test/1047.npz
# test/1053.npz
# test/289.npz
# test/302.npz
# test/464.npz
# test/470.npz
# test/316.npz
# test/458.npz
# test/1133.npz
# test/1127.npz
# test/666.npz
# test/100.npz
# test/114.npz
# test/672.npz
# test/882.npz
# test/128.npz
# test/896.npz
# test/869.npz
# test/29.npz
# test/841.npz
# test/699.npz
# test/855.npz
# test/15.npz
# test/843.npz
# test/17.npz
# test/857.npz
# test/880.npz
# test/658.npz
# test/894.npz
# test/102.npz
# test/664.npz
# test/670.npz
# test/116.npz
# test/499.npz
# test/1119.npz
# test/1131.npz
# test/1125.npz
# test/328.npz
# test/466.npz
# test/300.npz
# test/314.npz
# test/472.npz
# test/1079.npz
# test/1045.npz
# test/1051.npz
# test/248.npz
# test/512.npz
# test/1086.npz
# test/274.npz
# test/260.npz
# test/1092.npz
# test/506.npz
# test/937.npz
# test/923.npz
# test/738.npz
# test/710.npz
# test/704.npz
# test/705.npz
# test/711.npz
# test/739.npz
# test/922.npz
# test/936.npz
# test/261.npz
# test/507.npz
# test/1093.npz
# test/1087.npz
# test/513.npz
# test/275.npz
# test/249.npz
# test/1050.npz
# test/1044.npz
# test/1078.npz
# test/315.npz
# test/473.npz
# test/467.npz
# test/301.npz
# test/329.npz
# test/1124.npz
# test/1130.npz
# test/1118.npz
# test/498.npz
# test/671.npz
# test/117.npz
# test/103.npz
# test/665.npz
# test/895.npz
# test/659.npz
# test/881.npz
# test/856.npz
# test/16.npz
# test/842.npz
# test/846.npz
# test/12.npz
# test/852.npz
# test/661.npz
# test/107.npz
# test/113.npz
# test/675.npz
# test/885.npz
# test/891.npz
# test/649.npz
# test/1134.npz
# test/1120.npz
# test/1108.npz
# test/488.npz
# test/305.npz
# test/463.npz
# test/477.npz
# test/311.npz
# test/339.npz
# test/1040.npz
# test/1054.npz
# test/1068.npz
# test/271.npz
# test/517.npz
# test/1083.npz
# test/1097.npz
# test/503.npz
# test/265.npz
# test/259.npz
# test/932.npz
# test/926.npz
# test/715.npz
# test/701.npz
# test/729.npz
# test/728.npz
# test/700.npz
# test/714.npz
# test/927.npz
# test/933.npz
# test/258.npz
# test/502.npz
# test/1096.npz
# test/264.npz
# test/270.npz
# test/1082.npz
# test/516.npz
# test/1069.npz
# test/1055.npz
# test/1041.npz
# test/338.npz
# test/476.npz
# test/310.npz
# test/304.npz
# test/462.npz
# test/489.npz
# test/1109.npz
# test/1121.npz
# test/1135.npz
# test/648.npz
# test/890.npz
# test/884.npz
# test/112.npz
# test/674.npz
# test/660.npz
# test/106.npz
# test/853.npz
# test/13.npz
# test/847.npz
# test/39.npz
# test/879.npz
# test/11.npz
# test/689.npz
# test/851.npz
# test/845.npz
# test/676.npz
# test/110.npz
# test/104.npz
# test/662.npz
# test/892.npz
# test/138.npz
# test/886.npz
# test/1123.npz
# test/1137.npz
# test/312.npz
# test/474.npz
# test/460.npz
# test/306.npz
# test/448.npz
# test/1057.npz
# test/1043.npz
# test/299.npz
# test/266.npz
# test/1094.npz
# test/500.npz
# test/514.npz
# test/1080.npz
# test/272.npz
# test/528.npz
# test/919.npz
# test/925.npz
# test/931.npz
# test/702.npz
# test/716.npz
# test/717.npz
# test/703.npz
# test/930.npz
# test/924.npz
# test/918.npz
# test/529.npz
# test/1081.npz
# test/515.npz
# test/273.npz
# test/267.npz
# test/501.npz
# test/1095.npz
# test/298.npz
# test/1042.npz
# test/1056.npz
# test/449.npz
# test/461.npz
# test/307.npz
# test/313.npz
# test/475.npz
# test/1136.npz
# test/1122.npz
# test/139.npz
# test/887.npz
# test/893.npz
# test/105.npz
# test/663.npz
# test/677.npz
# test/111.npz
# test/844.npz
# test/850.npz
# test/688.npz
# test/10.npz
# test/878.npz
# test/38.npz
# test/35.npz
# test/875.npz
# test/21.npz
# test/861.npz
# test/691.npz
# test/849.npz
# test/685.npz
# test/108.npz
# test/134.npz
# test/652.npz
# test/646.npz
# test/120.npz
# test/493.npz
# test/1107.npz
# test/1113.npz
# test/487.npz
# test/478.npz
# test/450.npz
# test/336.npz
# test/322.npz
# test/444.npz
# test/1073.npz
# test/281.npz
# test/295.npz
# test/1067.npz
# test/518.npz
# test/1098.npz
# test/524.npz
# test/242.npz
# test/256.npz
# test/530.npz
# test/901.npz
# test/915.npz
# test/929.npz
# test/726.npz
# test/732.npz
# test/733.npz
# test/727.npz
# test/928.npz
# test/914.npz
# test/900.npz
# test/257.npz
# test/531.npz
# test/525.npz
# test/243.npz
# test/1099.npz
# test/519.npz
# test/294.npz
# test/1066.npz
# test/1072.npz
# test/280.npz
# test/323.npz
# test/445.npz
# test/451.npz
# test/337.npz
# test/479.npz
# test/486.npz
# test/1112.npz
# test/1106.npz
# test/492.npz
# test/647.npz
# test/121.npz
# test/135.npz
# test/653.npz
# test/109.npz
# test/684.npz
# test/848.npz
# test/690.npz
# test/860.npz
# test/20.npz
# test/874.npz
# test/34.npz
# test/22.npz
# test/862.npz
# test/36.npz
# test/876.npz
# test/686.npz
# test/692.npz
# test/679.npz
# test/123.npz
# test/645.npz
# test/889.npz
# test/651.npz
# test/137.npz
# test/1138.npz
# test/1110.npz
# test/484.npz
# test/490.npz
# test/1104.npz
# test/309.npz
# test/447.npz
# test/321.npz
# test/335.npz
# test/453.npz
# test/1058.npz
# test/1064.npz
# test/296.npz
# test/282.npz
# test/1070.npz
# test/269.npz
# test/533.npz
# test/255.npz
# test/241.npz
# test/527.npz
# test/916.npz
# test/902.npz
# test/719.npz
# test/731.npz
# test/725.npz
# test/724.npz
# test/730.npz
# test/718.npz
# test/903.npz
# test/917.npz
# test/240.npz
# test/526.npz
# test/532.npz
# test/254.npz
# test/268.npz
# test/283.npz
# test/1071.npz
# test/1065.npz
# test/297.npz
# test/1059.npz
# test/334.npz
# test/452.npz
# test/446.npz
# test/320.npz
# test/308.npz
# test/1105.npz
# test/491.npz
# test/485.npz
# test/1111.npz
# test/1139.npz
# test/650.npz
# test/888.npz
# test/136.npz
# test/122.npz
# test/644.npz
# test/678.npz
# test/693.npz
# test/687.npz
# test/877.npz
# test/37.npz
# test/863.npz
# test/23.npz
# test/683.npz
# test/697.npz
# test/27.npz
# test/867.npz
# test/33.npz
# test/873.npz
# test/898.npz
# test/640.npz
# test/126.npz
# test/132.npz
# test/654.npz
# test/668.npz
# test/1115.npz
# test/481.npz
# test/495.npz
# test/1101.npz
# test/1129.npz
# test/324.npz
# test/442.npz
# test/456.npz
# test/330.npz
# test/318.npz
# test/293.npz
# test/1061.npz
# test/1075.npz
# test/287.npz
# test/1049.npz
# test/250.npz
# test/536.npz
# test/522.npz
# test/244.npz
# test/278.npz
# test/913.npz
# test/907.npz
# test/734.npz
# test/720.npz
# test/708.npz
# test/709.npz
# test/721.npz
# test/735.npz
# test/906.npz
# test/912.npz
# test/279.npz
# test/523.npz
# test/245.npz
# test/251.npz
# test/537.npz
# test/1048.npz
# test/1074.npz
# test/286.npz
# test/292.npz
# test/1060.npz
# test/319.npz
# test/457.npz
# test/331.npz
# test/325.npz
# test/443.npz
# test/1128.npz
# test/1100.npz
# test/494.npz
# test/480.npz
# test/1114.npz
# test/669.npz
# test/133.npz
# test/655.npz
# test/641.npz
# test/899.npz
# test/127.npz
# test/872.npz
# test/32.npz
# test/866.npz
# test/26.npz
# test/696.npz
# test/682.npz
# test/694.npz
# test/18.npz
# test/680.npz
# test/858.npz
# test/30.npz
# test/870.npz
# test/24.npz
# test/864.npz
# test/657.npz
# test/131.npz
# test/125.npz
# test/643.npz
# test/119.npz
# test/496.npz
# test/1102.npz
# test/1116.npz
# test/482.npz
# test/333.npz
# test/455.npz
# test/441.npz
# test/327.npz
# test/469.npz
# test/284.npz
# test/1076.npz
# test/1062.npz
# test/290.npz
# test/247.npz
# test/521.npz
# test/535.npz
# test/253.npz
# test/1089.npz
# test/509.npz
# test/938.npz
# test/904.npz
# test/910.npz
# test/723.npz
# test/737.npz
# test/736.npz
# test/722.npz
# test/911.npz
# test/905.npz
# test/939.npz
# test/508.npz
# test/1088.npz
# test/534.npz
# test/252.npz
# test/246.npz
# test/520.npz
# test/1063.npz
# test/291.npz
# test/285.npz
# test/1077.npz
# test/468.npz
# test/440.npz
# test/326.npz
# test/332.npz
# test/454.npz
# test/483.npz
# test/1117.npz
# test/1103.npz
# test/497.npz
# test/118.npz
# test/124.npz
# test/642.npz
# test/656.npz
# test/130.npz
# test/865.npz
# test/25.npz
# test/871.npz
# test/31.npz
# test/859.npz
# test/681.npz
# test/19.npz
# test/695.npz
# test/56.npz
# test/816.npz
# test/4.npz
# test/42.npz
# test/802.npz
# test/194.npz
# test/180.npz
# test/95.npz
# test/619.npz
# test/81.npz
# test/631.npz
# test/157.npz
# test/143.npz
# test/625.npz
# test/396.npz
# test/382.npz
# test/369.npz
# test/355.npz
# test/433.npz
# test/427.npz
# test/341.npz
# test/1038.npz
# test/584.npz
# test/1010.npz
# test/1004.npz
# test/590.npz
# test/209.npz
# test/221.npz
# test/547.npz
# test/553.npz
# test/235.npz
# test/962.npz
# test/976.npz
# test/786.npz
# test/792.npz
# test/779.npz
# test/745.npz
# test/751.npz
# test/989.npz
# test/988.npz
# test/750.npz
# test/744.npz
# test/778.npz
# test/793.npz
# test/787.npz
# test/977.npz
# test/963.npz
# test/552.npz
# test/234.npz
# test/220.npz
# test/546.npz
# test/208.npz
# test/591.npz
# test/1005.npz
# test/1011.npz
# test/585.npz
# test/1039.npz
# test/426.npz
# test/340.npz
# test/354.npz
# test/432.npz
# test/368.npz
# test/383.npz
# test/397.npz
# test/142.npz
# test/624.npz
# test/630.npz
# test/156.npz
# test/80.npz
# test/618.npz
# test/94.npz
# test/181.npz
# test/195.npz
# test/803.npz
# test/43.npz
# test/817.npz
# test/57.npz
# test/5.npz
# test/41.npz
# test/801.npz
# test/7.npz
# test/55.npz
# test/815.npz
# test/183.npz
# test/197.npz
# test/69.npz
# test/829.npz
# test/82.npz
# test/168.npz
# test/96.npz
# test/626.npz
# test/140.npz
# test/154.npz
# test/632.npz
# test/381.npz
# test/395.npz
# test/418.npz
# test/342.npz
# test/424.npz
# test/430.npz
# test/356.npz
# test/1007.npz
# test/593.npz
# test/587.npz
# test/1013.npz
# test/578.npz
# test/236.npz
# test/550.npz
# test/544.npz
# test/222.npz
# test/975.npz
# test/961.npz
# test/949.npz
# test/791.npz
# test/785.npz
# test/752.npz
# test/746.npz
# test/747.npz
# test/753.npz
# test/784.npz
# test/790.npz
# test/948.npz
# test/960.npz
# test/974.npz
# test/545.npz
# test/223.npz
# test/237.npz
# test/551.npz
# test/579.npz
# test/1012.npz
# test/586.npz
# test/592.npz
# test/1006.npz
# test/431.npz
# test/357.npz
# test/343.npz
# test/425.npz
# test/419.npz
# test/394.npz
# test/380.npz
# test/155.npz
# test/633.npz
# test/627.npz
# test/141.npz
# test/169.npz
# test/97.npz
# test/83.npz
# test/196.npz
# test/828.npz
# test/68.npz
# test/182.npz
# test/6.npz
# test/814.npz
# test/54.npz
# test/800.npz
# test/40.npz
# test/186.npz
# test/78.npz
# test/838.npz
# test/192.npz
# test/44.npz
# test/804.npz
# test/50.npz
# test/810.npz
# test/2.npz
# test/145.npz
# test/623.npz
# test/637.npz
# test/151.npz
# test/179.npz
# test/87.npz
# test/93.npz
# test/384.npz
# test/390.npz
# test/421.npz
# test/347.npz
# test/353.npz
# test/435.npz
# test/409.npz
# test/1002.npz
# test/596.npz
# test/582.npz
# test/1016.npz
# test/555.npz
# test/233.npz
# test/227.npz
# test/541.npz
# test/569.npz
# test/794.npz
# test/958.npz
# test/780.npz
# test/970.npz
# test/964.npz
# test/757.npz
# test/743.npz
# test/742.npz
# test/756.npz
# test/965.npz
# test/971.npz
# test/781.npz
# test/959.npz
# test/795.npz
# test/568.npz
# test/226.npz
# test/540.npz
# test/554.npz
# test/232.npz
# test/1017.npz
# test/583.npz
# test/597.npz
# test/1003.npz
# test/408.npz
# test/352.npz
# test/434.npz
# test/420.npz
# test/346.npz
# test/391.npz
# test/385.npz
# test/92.npz
# test/178.npz
# test/86.npz
# test/636.npz
# test/150.npz
# test/144.npz
# test/622.npz
# test/811.npz
# test/51.npz
# test/3.npz
# test/805.npz
# test/45.npz
# test/193.npz
# test/187.npz
# test/839.npz
# test/79.npz
# test/191.npz
# test/185.npz
# test/1.npz
# test/53.npz
# test/813.npz
# test/47.npz
# test/807.npz
# test/152.npz
# test/634.npz
# test/620.npz
# test/146.npz
# test/90.npz
# test/608.npz
# test/84.npz
# test/393.npz
# test/387.npz
# test/1149.npz
# test/436.npz
# test/350.npz
# test/344.npz
# test/422.npz
# test/378.npz
# test/581.npz
# test/1015.npz
# test/1001.npz
# test/595.npz
# test/1029.npz
# test/542.npz
# test/224.npz
# test/230.npz
# test/556.npz
# test/218.npz
# test/783.npz
# test/797.npz
# test/967.npz
# test/973.npz
# test/740.npz
# test/998.npz
# test/754.npz
# test/768.npz
# test/769.npz
# test/755.npz
# test/999.npz
# test/741.npz
# test/972.npz
# test/966.npz
# test/796.npz
# test/782.npz
# test/219.npz
# test/231.npz
# test/557.npz
# test/543.npz
# test/225.npz
# test/1028.npz
# test/594.npz
# test/1000.npz
# test/1014.npz
# test/580.npz
# test/379.npz
# test/345.npz
# test/423.npz
# test/437.npz
# test/351.npz
# test/1148.npz
# test/386.npz
# test/392.npz
# test/85.npz
# test/609.npz
# test/91.npz
# test/621.npz
# test/147.npz
# test/153.npz
# test/635.npz
# test/806.npz
# test/46.npz
# test/0.npz
# test/812.npz
# test/52.npz
# test/184.npz
# test/190.npz

# %%
output_dir = '/content/train_data'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# !tar -xzvf /content/drive/MyDrive/train.tar.gz -C {output_dir}
# Out:
# train/
# train/77.npz
# train/837.npz
# train/189.npz
# train/1409.npz
# train/63.npz
# train/823.npz
# train/1347.npz
# train/1421.npz
# train/1435.npz
# train/1353.npz
# train/638.npz
# train/610.npz
# train/1384.npz
# train/88.npz
# train/176.npz
# train/162.npz
# train/1390.npz
# train/604.npz
# train/1179.npz
# train/1623.npz
# train/1145.npz
# train/1151.npz
# train/1637.npz
# train/348.npz
# train/374.npz
# train/1186.npz
# train/412.npz
# train/406.npz
# train/1192.npz
# train/360.npz
# train/599.npz
# train/1019.npz
# train/1031.npz
# train/1025.npz
# train/228.npz
# train/200.npz
# train/566.npz
# train/572.npz
# train/214.npz
# train/943.npz
# train/1569.npz
# train/957.npz
# train/1233.npz
# train/1555.npz
# train/1541.npz
# train/1227.npz
# train/758.npz
# train/980.npz
# train/994.npz
# train/764.npz
# train/1596.npz
# train/1582.npz
# train/770.npz
# train/1583.npz
# train/771.npz
# train/765.npz
# train/1597.npz
# train/995.npz
# train/981.npz
# train/759.npz
# train/1540.npz
# train/1226.npz
# train/1232.npz
# train/1554.npz
# train/956.npz
# train/942.npz
# train/1568.npz
# train/573.npz
# train/215.npz
# train/201.npz
# train/567.npz
# train/229.npz
# train/1024.npz
# train/1030.npz
# train/1018.npz
# train/598.npz
# train/1193.npz
# train/407.npz
# train/361.npz
# train/375.npz
# train/413.npz
# train/1187.npz
# train/349.npz
# train/1150.npz
# train/1636.npz
# train/1622.npz
# train/1144.npz
# train/1178.npz
# train/163.npz
# train/605.npz
# train/1391.npz
# train/89.npz
# train/1385.npz
# train/611.npz
# train/177.npz
# train/639.npz
# train/1434.npz
# train/1352.npz
# train/1346.npz
# train/1420.npz
# train/1408.npz
# train/822.npz
# train/62.npz
# train/836.npz
# train/76.npz
# train/188.npz
# train/60.npz
# train/820.npz
# train/1378.npz
# train/74.npz
# train/834.npz
# train/1350.npz
# train/1436.npz
# train/1422.npz
# train/1344.npz
# train/48.npz
# train/808.npz
# train/149.npz
# train/1393.npz
# train/607.npz
# train/161.npz
# train/175.npz
# train/613.npz
# train/1387.npz
# train/1608.npz
# train/388.npz
# train/1634.npz
# train/1152.npz
# train/1146.npz
# train/1620.npz
# train/439.npz
# train/363.npz
# train/405.npz
# train/1191.npz
# train/1185.npz
# train/411.npz
# train/377.npz
# train/1026.npz
# train/1032.npz
# train/559.npz
# train/217.npz
# train/571.npz
# train/565.npz
# train/203.npz
# train/954.npz
# train/1218.npz
# train/940.npz
# train/798.npz
# train/968.npz
# train/1224.npz
# train/1542.npz
# train/1556.npz
# train/1230.npz
# train/997.npz
# train/983.npz
# train/773.npz
# train/1581.npz
# train/1595.npz
# train/767.npz
# train/1594.npz
# train/766.npz
# train/772.npz
# train/1580.npz
# train/982.npz
# train/996.npz
# train/1557.npz
# train/1231.npz
# train/1225.npz
# train/969.npz
# train/1543.npz
# train/799.npz
# train/941.npz
# train/1219.npz
# train/955.npz
# train/564.npz
# train/202.npz
# train/216.npz
# train/570.npz
# train/558.npz
# train/1033.npz
# train/1027.npz
# train/410.npz
# train/1184.npz
# train/376.npz
# train/362.npz
# train/1190.npz
# train/404.npz
# train/438.npz
# train/1147.npz
# train/1621.npz
# train/1635.npz
# train/1153.npz
# train/389.npz
# train/1609.npz
# train/174.npz
# train/1386.npz
# train/612.npz
# train/606.npz
# train/1392.npz
# train/160.npz
# train/148.npz
# train/1423.npz
# train/809.npz
# train/49.npz
# train/1345.npz
# train/1351.npz
# train/1437.npz
# train/835.npz
# train/75.npz
# train/1379.npz
# train/821.npz
# train/61.npz
# train/1433.npz
# train/59.npz
# train/1355.npz
# train/819.npz
# train/1341.npz
# train/1427.npz
# train/65.npz
# train/1369.npz
# train/825.npz
# train/71.npz
# train/831.npz
# train/164.npz
# train/1396.npz
# train/602.npz
# train/616.npz
# train/1382.npz
# train/170.npz
# train/158.npz
# train/1157.npz
# train/1631.npz
# train/1625.npz
# train/1143.npz
# train/399.npz
# train/1619.npz
# train/400.npz
# train/1194.npz
# train/366.npz
# train/372.npz
# train/1180.npz
# train/414.npz
# train/428.npz
# train/1023.npz
# train/1037.npz
# train/574.npz
# train/212.npz
# train/206.npz
# train/560.npz
# train/548.npz
# train/1547.npz
# train/1221.npz
# train/979.npz
# train/1235.npz
# train/1553.npz
# train/951.npz
# train/789.npz
# train/945.npz
# train/1209.npz
# train/1584.npz
# train/776.npz
# train/762.npz
# train/1590.npz
# train/992.npz
# train/986.npz
# train/987.npz
# train/993.npz
# train/763.npz
# train/1591.npz
# train/1585.npz
# train/777.npz
# train/1208.npz
# train/944.npz
# train/788.npz
# train/950.npz
# train/1234.npz
# train/978.npz
# train/1552.npz
# train/1546.npz
# train/1220.npz
# train/549.npz
# train/207.npz
# train/561.npz
# train/575.npz
# train/213.npz
# train/1036.npz
# train/1022.npz
# train/429.npz
# train/373.npz
# train/415.npz
# train/1181.npz
# train/1195.npz
# train/401.npz
# train/367.npz
# train/1618.npz
# train/398.npz
# train/1624.npz
# train/1142.npz
# train/1156.npz
# train/1630.npz
# train/159.npz
# train/1383.npz
# train/617.npz
# train/171.npz
# train/165.npz
# train/603.npz
# train/1397.npz
# train/830.npz
# train/70.npz
# train/824.npz
# train/1368.npz
# train/64.npz
# train/1340.npz
# train/1426.npz
# train/1432.npz
# train/818.npz
# train/1354.npz
# train/58.npz
# train/1424.npz
# train/1342.npz
# train/1356.npz
# train/1430.npz
# train/8.npz
# train/1418.npz
# train/72.npz
# train/832.npz
# train/66.npz
# train/826.npz
# train/198.npz
# train/173.npz
# train/615.npz
# train/1381.npz
# train/99.npz
# train/1395.npz
# train/601.npz
# train/167.npz
# train/629.npz
# train/1140.npz
# train/1626.npz
# train/1632.npz
# train/1154.npz
# train/1168.npz
# train/1183.npz
# train/417.npz
# train/371.npz
# train/365.npz
# train/403.npz
# train/1197.npz
# train/359.npz
# train/1034.npz
# train/1020.npz
# train/1008.npz
# train/588.npz
# train/563.npz
# train/205.npz
# train/211.npz
# train/577.npz
# train/239.npz
# train/1550.npz
# train/1236.npz
# train/1222.npz
# train/1544.npz
# train/946.npz
# train/952.npz
# train/1578.npz
# train/1593.npz
# train/761.npz
# train/775.npz
# train/1587.npz
# train/985.npz
# train/749.npz
# train/991.npz
# train/990.npz
# train/748.npz
# train/984.npz
# train/774.npz
# train/1586.npz
# train/1592.npz
# train/760.npz
# train/953.npz
# train/1579.npz
# train/947.npz
# train/1223.npz
# train/1545.npz
# train/1551.npz
# train/1237.npz
# train/238.npz
# train/210.npz
# train/576.npz
# train/562.npz
# train/204.npz
# train/589.npz
# train/1009.npz
# train/1021.npz
# train/1035.npz
# train/358.npz
# train/364.npz
# train/1196.npz
# train/402.npz
# train/416.npz
# train/1182.npz
# train/370.npz
# train/1169.npz
# train/1633.npz
# train/1155.npz
# train/1141.npz
# train/1627.npz
# train/628.npz
# train/600.npz
# train/1394.npz
# train/98.npz
# train/166.npz
# train/172.npz
# train/1380.npz
# train/614.npz
# train/827.npz
# train/67.npz
# train/199.npz
# train/1419.npz
# train/833.npz
# train/73.npz
# train/1357.npz
# train/9.npz
# train/1431.npz
# train/1425.npz
# train/1343.npz
# train/1318.npz
# train/14.npz
# train/854.npz
# train/698.npz
# train/840.npz
# train/1442.npz
# train/1324.npz
# train/28.npz
# train/868.npz
# train/1330.npz
# train/1456.npz
# train/129.npz
# train/897.npz
# train/883.npz
# train/115.npz
# train/1481.npz
# train/673.npz
# train/667.npz
# train/1495.npz
# train/101.npz
# train/1668.npz
# train/1126.npz
# train/1640.npz
# train/1654.npz
# train/1132.npz
# train/459.npz
# train/471.npz
# train/1683.npz
# train/317.npz
# train/303.npz
# train/1697.npz
# train/465.npz
# train/1708.npz
# train/288.npz
# train/1052.npz
# train/1720.npz
# train/1046.npz
# train/539.npz
# train/1091.npz
# train/505.npz
# train/263.npz
# train/277.npz
# train/511.npz
# train/1085.npz
# train/920.npz
# train/934.npz
# train/1278.npz
# train/1536.npz
# train/1250.npz
# train/908.npz
# train/1244.npz
# train/1522.npz
# train/707.npz
# train/1293.npz
# train/1287.npz
# train/713.npz
# train/712.npz
# train/1286.npz
# train/1292.npz
# train/706.npz
# train/1245.npz
# train/909.npz
# train/1523.npz
# train/1537.npz
# train/1251.npz
# train/1279.npz
# train/935.npz
# train/921.npz
# train/276.npz
# train/1084.npz
# train/510.npz
# train/504.npz
# train/1090.npz
# train/262.npz
# train/538.npz
# train/1721.npz
# train/1047.npz
# train/1053.npz
# train/289.npz
# train/1709.npz
# train/1696.npz
# train/302.npz
# train/464.npz
# train/470.npz
# train/316.npz
# train/1682.npz
# train/458.npz
# train/1655.npz
# train/1133.npz
# train/1127.npz
# train/1641.npz
# train/1669.npz
# train/666.npz
# train/100.npz
# train/1494.npz
# train/1480.npz
# train/114.npz
# train/672.npz
# train/882.npz
# train/128.npz
# train/896.npz
# train/1331.npz
# train/1457.npz
# train/1443.npz
# train/869.npz
# train/29.npz
# train/1325.npz
# train/841.npz
# train/699.npz
# train/855.npz
# train/15.npz
# train/1319.npz
# train/1469.npz
# train/843.npz
# train/17.npz
# train/857.npz
# train/1455.npz
# train/1333.npz
# train/1327.npz
# train/1441.npz
# train/880.npz
# train/658.npz
# train/894.npz
# train/1496.npz
# train/102.npz
# train/664.npz
# train/670.npz
# train/116.npz
# train/1482.npz
# train/499.npz
# train/1119.npz
# train/1131.npz
# train/1657.npz
# train/1643.npz
# train/1125.npz
# train/328.npz
# train/466.npz
# train/300.npz
# train/1694.npz
# train/1680.npz
# train/314.npz
# train/472.npz
# train/1079.npz
# train/1045.npz
# train/1723.npz
# train/1051.npz
# train/248.npz
# train/512.npz
# train/1086.npz
# train/274.npz
# train/260.npz
# train/1092.npz
# train/506.npz
# train/937.npz
# train/923.npz
# train/1509.npz
# train/1521.npz
# train/1247.npz
# train/1253.npz
# train/1535.npz
# train/738.npz
# train/1284.npz
# train/710.npz
# train/704.npz
# train/1290.npz
# train/1291.npz
# train/705.npz
# train/711.npz
# train/1285.npz
# train/739.npz
# train/1252.npz
# train/1534.npz
# train/1520.npz
# train/1246.npz
# train/922.npz
# train/1508.npz
# train/936.npz
# train/261.npz
# train/507.npz
# train/1093.npz
# train/1087.npz
# train/513.npz
# train/275.npz
# train/249.npz
# train/1050.npz
# train/1044.npz
# train/1722.npz
# train/1078.npz
# train/315.npz
# train/1681.npz
# train/473.npz
# train/467.npz
# train/1695.npz
# train/301.npz
# train/329.npz
# train/1642.npz
# train/1124.npz
# train/1130.npz
# train/1656.npz
# train/1118.npz
# train/498.npz
# train/671.npz
# train/1483.npz
# train/117.npz
# train/103.npz
# train/1497.npz
# train/665.npz
# train/895.npz
# train/659.npz
# train/881.npz
# train/1326.npz
# train/1440.npz
# train/1454.npz
# train/1332.npz
# train/856.npz
# train/16.npz
# train/1468.npz
# train/842.npz
# train/1336.npz
# train/1450.npz
# train/1444.npz
# train/1322.npz
# train/846.npz
# train/1478.npz
# train/12.npz
# train/852.npz
# train/661.npz
# train/1493.npz
# train/107.npz
# train/113.npz
# train/1487.npz
# train/675.npz
# train/885.npz
# train/891.npz
# train/649.npz
# train/1652.npz
# train/1134.npz
# train/1120.npz
# train/1646.npz
# train/1108.npz
# train/488.npz
# train/305.npz
# train/1691.npz
# train/463.npz
# train/477.npz
# train/1685.npz
# train/311.npz
# train/339.npz
# train/1726.npz
# train/1040.npz
# train/1054.npz
# train/1068.npz
# train/271.npz
# train/517.npz
# train/1083.npz
# train/1097.npz
# train/503.npz
# train/265.npz
# train/259.npz
# train/1242.npz
# train/1524.npz
# train/1530.npz
# train/1256.npz
# train/932.npz
# train/1518.npz
# train/926.npz
# train/1281.npz
# train/715.npz
# train/701.npz
# train/1295.npz
# train/729.npz
# train/728.npz
# train/1294.npz
# train/700.npz
# train/714.npz
# train/1280.npz
# train/927.npz
# train/933.npz
# train/1519.npz
# train/1531.npz
# train/1257.npz
# train/1243.npz
# train/1525.npz
# train/258.npz
# train/502.npz
# train/1096.npz
# train/264.npz
# train/270.npz
# train/1082.npz
# train/516.npz
# train/1069.npz
# train/1055.npz
# train/1727.npz
# train/1041.npz
# train/338.npz
# train/476.npz
# train/310.npz
# train/1684.npz
# train/1690.npz
# train/304.npz
# train/462.npz
# train/489.npz
# train/1109.npz
# train/1121.npz
# train/1647.npz
# train/1653.npz
# train/1135.npz
# train/648.npz
# train/890.npz
# train/884.npz
# train/1486.npz
# train/112.npz
# train/674.npz
# train/660.npz
# train/106.npz
# train/1492.npz
# train/1479.npz
# train/853.npz
# train/13.npz
# train/847.npz
# train/1445.npz
# train/1323.npz
# train/1337.npz
# train/1451.npz
# train/1321.npz
# train/1447.npz
# train/1453.npz
# train/39.npz
# train/1335.npz
# train/879.npz
# train/11.npz
# train/689.npz
# train/851.npz
# train/1309.npz
# train/845.npz
# train/676.npz
# train/110.npz
# train/1484.npz
# train/1490.npz
# train/104.npz
# train/662.npz
# train/892.npz
# train/138.npz
# train/886.npz
# train/1645.npz
# train/1123.npz
# train/1137.npz
# train/1651.npz
# train/1679.npz
# train/1686.npz
# train/312.npz
# train/474.npz
# train/460.npz
# train/306.npz
# train/1692.npz
# train/448.npz
# train/1731.npz
# train/1057.npz
# train/1043.npz
# train/1725.npz
# train/299.npz
# train/1719.npz
# train/266.npz
# train/1094.npz
# train/500.npz
# train/514.npz
# train/1080.npz
# train/272.npz
# train/528.npz
# train/919.npz
# train/1255.npz
# train/1533.npz
# train/1527.npz
# train/1241.npz
# train/925.npz
# train/1269.npz
# train/931.npz
# train/702.npz
# train/1296.npz
# train/1282.npz
# train/716.npz
# train/717.npz
# train/1283.npz
# train/1297.npz
# train/703.npz
# train/930.npz
# train/1268.npz
# train/924.npz
# train/1526.npz
# train/1240.npz
# train/1254.npz
# train/918.npz
# train/1532.npz
# train/529.npz
# train/1081.npz
# train/515.npz
# train/273.npz
# train/267.npz
# train/501.npz
# train/1095.npz
# train/1718.npz
# train/298.npz
# train/1042.npz
# train/1724.npz
# train/1730.npz
# train/1056.npz
# train/449.npz
# train/461.npz
# train/1693.npz
# train/307.npz
# train/313.npz
# train/1687.npz
# train/475.npz
# train/1678.npz
# train/1136.npz
# train/1650.npz
# train/1644.npz
# train/1122.npz
# train/139.npz
# train/887.npz
# train/893.npz
# train/105.npz
# train/1491.npz
# train/663.npz
# train/677.npz
# train/1485.npz
# train/111.npz
# train/844.npz
# train/1308.npz
# train/850.npz
# train/688.npz
# train/10.npz
# train/1452.npz
# train/878.npz
# train/1334.npz
# train/38.npz
# train/1320.npz
# train/1446.npz
# train/1339.npz
# train/35.npz
# train/875.npz
# train/21.npz
# train/861.npz
# train/1463.npz
# train/1305.npz
# train/691.npz
# train/849.npz
# train/685.npz
# train/1311.npz
# train/1477.npz
# train/108.npz
# train/1488.npz
# train/134.npz
# train/652.npz
# train/646.npz
# train/120.npz
# train/1649.npz
# train/493.npz
# train/1107.npz
# train/1661.npz
# train/1675.npz
# train/1113.npz
# train/487.npz
# train/478.npz
# train/450.npz
# train/336.npz
# train/322.npz
# train/444.npz
# train/1729.npz
# train/1073.npz
# train/281.npz
# train/1715.npz
# train/1701.npz
# train/295.npz
# train/1067.npz
# train/518.npz
# train/1098.npz
# train/524.npz
# train/242.npz
# train/256.npz
# train/530.npz
# train/901.npz
# train/915.npz
# train/1259.npz
# train/1517.npz
# train/1271.npz
# train/929.npz
# train/1265.npz
# train/1503.npz
# train/726.npz
# train/732.npz
# train/733.npz
# train/727.npz
# train/1264.npz
# train/928.npz
# train/1502.npz
# train/1516.npz
# train/1270.npz
# train/1258.npz
# train/914.npz
# train/900.npz
# train/257.npz
# train/531.npz
# train/525.npz
# train/243.npz
# train/1099.npz
# train/519.npz
# train/294.npz
# train/1700.npz
# train/1066.npz
# train/1072.npz
# train/1714.npz
# train/280.npz
# train/1728.npz
# train/323.npz
# train/445.npz
# train/451.npz
# train/337.npz
# train/479.npz
# train/1674.npz
# train/486.npz
# train/1112.npz
# train/1106.npz
# train/492.npz
# train/1660.npz
# train/1648.npz
# train/647.npz
# train/121.npz
# train/135.npz
# train/653.npz
# train/1489.npz
# train/109.npz
# train/1310.npz
# train/684.npz
# train/1476.npz
# train/1462.npz
# train/848.npz
# train/690.npz
# train/1304.npz
# train/860.npz
# train/20.npz
# train/874.npz
# train/34.npz
# train/1338.npz
# train/1448.npz
# train/22.npz
# train/862.npz
# train/36.npz
# train/876.npz
# train/1474.npz
# train/686.npz
# train/1312.npz
# train/1306.npz
# train/692.npz
# train/1460.npz
# train/679.npz
# train/123.npz
# train/645.npz
# train/889.npz
# train/651.npz
# train/137.npz
# train/1138.npz
# train/1110.npz
# train/484.npz
# train/1676.npz
# train/1662.npz
# train/490.npz
# train/1104.npz
# train/1689.npz
# train/309.npz
# train/447.npz
# train/321.npz
# train/335.npz
# train/453.npz
# train/1058.npz
# train/1064.npz
# train/1702.npz
# train/296.npz
# train/282.npz
# train/1716.npz
# train/1070.npz
# train/269.npz
# train/533.npz
# train/255.npz
# train/241.npz
# train/527.npz
# train/916.npz
# train/902.npz
# train/1528.npz
# train/1500.npz
# train/1266.npz
# train/1272.npz
# train/1514.npz
# train/1299.npz
# train/719.npz
# train/731.npz
# train/725.npz
# train/724.npz
# train/730.npz
# train/718.npz
# train/1298.npz
# train/1273.npz
# train/1515.npz
# train/1501.npz
# train/1267.npz
# train/903.npz
# train/1529.npz
# train/917.npz
# train/240.npz
# train/526.npz
# train/532.npz
# train/254.npz
# train/268.npz
# train/1717.npz
# train/283.npz
# train/1071.npz
# train/1065.npz
# train/297.npz
# train/1703.npz
# train/1059.npz
# train/334.npz
# train/452.npz
# train/446.npz
# train/320.npz
# train/308.npz
# train/1688.npz
# train/1663.npz
# train/1105.npz
# train/491.npz
# train/485.npz
# train/1111.npz
# train/1677.npz
# train/1139.npz
# train/650.npz
# train/888.npz
# train/136.npz
# train/122.npz
# train/644.npz
# train/678.npz
# train/693.npz
# train/1307.npz
# train/1461.npz
# train/1475.npz
# train/1313.npz
# train/687.npz
# train/877.npz
# train/37.npz
# train/1449.npz
# train/863.npz
# train/23.npz
# train/683.npz
# train/1317.npz
# train/1471.npz
# train/1465.npz
# train/1303.npz
# train/697.npz
# train/27.npz
# train/867.npz
# train/1459.npz
# train/33.npz
# train/873.npz
# train/898.npz
# train/640.npz
# train/126.npz
# train/132.npz
# train/654.npz
# train/668.npz
# train/1673.npz
# train/1115.npz
# train/481.npz
# train/495.npz
# train/1101.npz
# train/1667.npz
# train/1129.npz
# train/324.npz
# train/442.npz
# train/456.npz
# train/330.npz
# train/318.npz
# train/1698.npz
# train/1707.npz
# train/293.npz
# train/1061.npz
# train/1075.npz
# train/287.npz
# train/1713.npz
# train/1049.npz
# train/250.npz
# train/536.npz
# train/522.npz
# train/244.npz
# train/278.npz
# train/1263.npz
# train/1505.npz
# train/1511.npz
# train/1277.npz
# train/913.npz
# train/1539.npz
# train/907.npz
# train/734.npz
# train/720.npz
# train/708.npz
# train/1288.npz
# train/1289.npz
# train/709.npz
# train/721.npz
# train/735.npz
# train/906.npz
# train/912.npz
# train/1538.npz
# train/1510.npz
# train/1276.npz
# train/1262.npz
# train/1504.npz
# train/279.npz
# train/523.npz
# train/245.npz
# train/251.npz
# train/537.npz
# train/1048.npz
# train/1074.npz
# train/1712.npz
# train/286.npz
# train/292.npz
# train/1706.npz
# train/1060.npz
# train/1699.npz
# train/319.npz
# train/457.npz
# train/331.npz
# train/325.npz
# train/443.npz
# train/1128.npz
# train/1100.npz
# train/494.npz
# train/1666.npz
# train/1672.npz
# train/480.npz
# train/1114.npz
# train/669.npz
# train/133.npz
# train/655.npz
# train/641.npz
# train/899.npz
# train/127.npz
# train/1458.npz
# train/872.npz
# train/32.npz
# train/866.npz
# train/26.npz
# train/1464.npz
# train/696.npz
# train/1302.npz
# train/1316.npz
# train/682.npz
# train/1470.npz
# train/1300.npz
# train/694.npz
# train/1466.npz
# train/1472.npz
# train/18.npz
# train/680.npz
# train/1314.npz
# train/858.npz
# train/30.npz
# train/870.npz
# train/24.npz
# train/1328.npz
# train/864.npz
# train/657.npz
# train/131.npz
# train/125.npz
# train/643.npz
# train/1499.npz
# train/119.npz
# train/1664.npz
# train/496.npz
# train/1102.npz
# train/1116.npz
# train/482.npz
# train/1670.npz
# train/1658.npz
# train/333.npz
# train/455.npz
# train/441.npz
# train/327.npz
# train/469.npz
# train/284.npz
# train/1710.npz
# train/1076.npz
# train/1062.npz
# train/1704.npz
# train/290.npz
# train/247.npz
# train/521.npz
# train/535.npz
# train/253.npz
# train/1089.npz
# train/509.npz
# train/938.npz
# train/1274.npz
# train/1512.npz
# train/1506.npz
# train/1260.npz
# train/904.npz
# train/1248.npz
# train/910.npz
# train/723.npz
# train/737.npz
# train/736.npz
# train/722.npz
# train/911.npz
# train/1249.npz
# train/905.npz
# train/1507.npz
# train/1261.npz
# train/1275.npz
# train/939.npz
# train/1513.npz
# train/508.npz
# train/1088.npz
# train/534.npz
# train/252.npz
# train/246.npz
# train/520.npz
# train/1063.npz
# train/291.npz
# train/1705.npz
# train/1711.npz
# train/285.npz
# train/1077.npz
# train/468.npz
# train/440.npz
# train/326.npz
# train/332.npz
# train/454.npz
# train/1659.npz
# train/483.npz
# train/1117.npz
# train/1671.npz
# train/1665.npz
# train/1103.npz
# train/497.npz
# train/118.npz
# train/1498.npz
# train/124.npz
# train/642.npz
# train/656.npz
# train/130.npz
# train/865.npz
# train/1329.npz
# train/25.npz
# train/871.npz
# train/31.npz
# train/1473.npz
# train/859.npz
# train/1315.npz
# train/681.npz
# train/19.npz
# train/695.npz
# train/1301.npz
# train/1467.npz
# train/56.npz
# train/816.npz
# train/4.npz
# train/1428.npz
# train/42.npz
# train/802.npz
# train/1366.npz
# train/1400.npz
# train/194.npz
# train/180.npz
# train/1414.npz
# train/1372.npz
# train/1399.npz
# train/95.npz
# train/619.npz
# train/81.npz
# train/631.npz
# train/157.npz
# train/143.npz
# train/625.npz
# train/1158.npz
# train/396.npz
# train/1602.npz
# train/1164.npz
# train/1170.npz
# train/1616.npz
# train/382.npz
# train/369.npz
# train/355.npz
# train/433.npz
# train/427.npz
# train/341.npz
# train/1038.npz
# train/584.npz
# train/1010.npz
# train/1004.npz
# train/590.npz
# train/209.npz
# train/221.npz
# train/547.npz
# train/553.npz
# train/235.npz
# train/962.npz
# train/1548.npz
# train/976.npz
# train/1212.npz
# train/786.npz
# train/1574.npz
# train/1560.npz
# train/792.npz
# train/1206.npz
# train/779.npz
# train/745.npz
# train/751.npz
# train/989.npz
# train/988.npz
# train/750.npz
# train/744.npz
# train/778.npz
# train/1561.npz
# train/1207.npz
# train/793.npz
# train/787.npz
# train/1213.npz
# train/1575.npz
# train/977.npz
# train/963.npz
# train/1549.npz
# train/552.npz
# train/234.npz
# train/220.npz
# train/546.npz
# train/208.npz
# train/591.npz
# train/1005.npz
# train/1011.npz
# train/585.npz
# train/1039.npz
# train/426.npz
# train/340.npz
# train/354.npz
# train/432.npz
# train/368.npz
# train/1171.npz
# train/383.npz
# train/1617.npz
# train/1603.npz
# train/397.npz
# train/1165.npz
# train/1159.npz
# train/142.npz
# train/624.npz
# train/630.npz
# train/156.npz
# train/80.npz
# train/618.npz
# train/94.npz
# train/1398.npz
# train/1415.npz
# train/181.npz
# train/1373.npz
# train/1367.npz
# train/195.npz
# train/1401.npz
# train/1429.npz
# train/803.npz
# train/43.npz
# train/817.npz
# train/57.npz
# train/5.npz
# train/41.npz
# train/801.npz
# train/7.npz
# train/1359.npz
# train/55.npz
# train/815.npz
# train/1371.npz
# train/183.npz
# train/1417.npz
# train/1403.npz
# train/197.npz
# train/1365.npz
# train/69.npz
# train/829.npz
# train/82.npz
# train/168.npz
# train/96.npz
# train/626.npz
# train/140.npz
# train/154.npz
# train/632.npz
# train/1629.npz
# train/1615.npz
# train/381.npz
# train/1173.npz
# train/1167.npz
# train/395.npz
# train/1601.npz
# train/418.npz
# train/1198.npz
# train/342.npz
# train/424.npz
# train/430.npz
# train/356.npz
# train/1007.npz
# train/593.npz
# train/587.npz
# train/1013.npz
# train/578.npz
# train/236.npz
# train/550.npz
# train/544.npz
# train/222.npz
# train/975.npz
# train/1239.npz
# train/961.npz
# train/949.npz
# train/791.npz
# train/1205.npz
# train/1563.npz
# train/1577.npz
# train/1211.npz
# train/785.npz
# train/1588.npz
# train/752.npz
# train/746.npz
# train/747.npz
# train/753.npz
# train/1589.npz
# train/1576.npz
# train/784.npz
# train/1210.npz
# train/1204.npz
# train/790.npz
# train/948.npz
# train/1562.npz
# train/960.npz
# train/1238.npz
# train/974.npz
# train/545.npz
# train/223.npz
# train/237.npz
# train/551.npz
# train/579.npz
# train/1012.npz
# train/586.npz
# train/592.npz
# train/1006.npz
# train/431.npz
# train/357.npz
# train/343.npz
# train/425.npz
# train/1199.npz
# train/419.npz
# train/1166.npz
# train/1600.npz
# train/394.npz
# train/380.npz
# train/1614.npz
# train/1172.npz
# train/1628.npz
# train/155.npz
# train/633.npz
# train/627.npz
# train/141.npz
# train/169.npz
# train/97.npz
# train/83.npz
# train/196.npz
# train/1402.npz
# train/828.npz
# train/68.npz
# train/1364.npz
# train/1370.npz
# train/1416.npz
# train/182.npz
# train/6.npz
# train/814.npz
# train/54.npz
# train/1358.npz
# train/800.npz
# train/40.npz
# train/186.npz
# train/1412.npz
# train/78.npz
# train/1374.npz
# train/838.npz
# train/1360.npz
# train/1406.npz
# train/192.npz
# train/44.npz
# train/1348.npz
# train/804.npz
# train/50.npz
# train/810.npz
# train/2.npz
# train/145.npz
# train/623.npz
# train/637.npz
# train/151.npz
# train/179.npz
# train/87.npz
# train/93.npz
# train/1176.npz
# train/1610.npz
# train/384.npz
# train/390.npz
# train/1604.npz
# train/1162.npz
# train/1638.npz
# train/421.npz
# train/347.npz
# train/353.npz
# train/435.npz
# train/1189.npz
# train/409.npz
# train/1002.npz
# train/596.npz
# train/582.npz
# train/1016.npz
# train/555.npz
# train/233.npz
# train/227.npz
# train/541.npz
# train/569.npz
# train/1566.npz
# train/794.npz
# train/1200.npz
# train/958.npz
# train/1214.npz
# train/780.npz
# train/1572.npz
# train/970.npz
# train/964.npz
# train/1228.npz
# train/757.npz
# train/743.npz
# train/1599.npz
# train/1598.npz
# train/742.npz
# train/756.npz
# train/1229.npz
# train/965.npz
# train/971.npz
# train/781.npz
# train/1215.npz
# train/959.npz
# train/1573.npz
# train/1567.npz
# train/1201.npz
# train/795.npz
# train/568.npz
# train/226.npz
# train/540.npz
# train/554.npz
# train/232.npz
# train/1017.npz
# train/583.npz
# train/597.npz
# train/1003.npz
# train/408.npz
# train/1188.npz
# train/352.npz
# train/434.npz
# train/420.npz
# train/346.npz
# train/1639.npz
# train/1605.npz
# train/391.npz
# train/1163.npz
# train/1177.npz
# train/385.npz
# train/1611.npz
# train/92.npz
# train/178.npz
# train/86.npz
# train/636.npz
# train/150.npz
# train/144.npz
# train/622.npz
# train/811.npz
# train/51.npz
# train/3.npz
# train/805.npz
# train/1349.npz
# train/45.npz
# train/1361.npz
# train/193.npz
# train/1407.npz
# train/1413.npz
# train/187.npz
# train/839.npz
# train/1375.npz
# train/79.npz
# train/1405.npz
# train/191.npz
# train/1363.npz
# train/1377.npz
# train/185.npz
# train/1411.npz
# train/1.npz
# train/1439.npz
# train/53.npz
# train/813.npz
# train/47.npz
# train/807.npz
# train/152.npz
# train/634.npz
# train/620.npz
# train/146.npz
# train/90.npz
# train/608.npz
# train/84.npz
# train/1388.npz
# train/1161.npz
# train/393.npz
# train/1607.npz
# train/1613.npz
# train/387.npz
# train/1175.npz
# train/1149.npz
# train/436.npz
# train/350.npz
# train/344.npz
# train/422.npz
# train/378.npz
# train/581.npz
# train/1015.npz
# train/1001.npz
# train/595.npz
# train/1029.npz
# train/542.npz
# train/224.npz
# train/230.npz
# train/556.npz
# train/218.npz
# train/1571.npz
# train/1217.npz
# train/783.npz
# train/797.npz
# train/1203.npz
# train/1565.npz
# train/967.npz
# train/973.npz
# train/1559.npz
# train/740.npz
# train/998.npz
# train/754.npz
# train/768.npz
# train/769.npz
# train/755.npz
# train/999.npz
# train/741.npz
# train/972.npz
# train/1558.npz
# train/966.npz
# train/1202.npz
# train/796.npz
# train/1564.npz
# train/1570.npz
# train/782.npz
# train/1216.npz
# train/219.npz
# train/231.npz
# train/557.npz
# train/543.npz
# train/225.npz
# train/1028.npz
# train/594.npz
# train/1000.npz
# train/1014.npz
# train/580.npz
# train/379.npz
# train/345.npz
# train/423.npz
# train/437.npz
# train/351.npz
# train/1148.npz
# train/386.npz
# train/1612.npz
# train/1174.npz
# train/1160.npz
# train/1606.npz
# train/392.npz
# train/1389.npz
# train/85.npz
# train/609.npz
# train/91.npz
# train/621.npz
# train/147.npz
# train/153.npz
# train/635.npz
# train/806.npz
# train/46.npz
# train/1438.npz
# train/812.npz
# train/52.npz
# train/1376.npz
# train/1410.npz
# train/184.npz
# train/190.npz
# train/1404.npz
# train/1362.npz
# train/0.npz

# %%
gt_df = pd.read_csv(gt_path)
wavelength_df = pd.read_csv(wavelength_path)

# %%
# def load_data(directory: str):
#     data = []

#     all_files = np.array(
#         sorted(
#             glob(os.path.join(directory, "*.npz")),
#             key=lambda x: int(os.path.basename(x).replace(".npz", "")),
#         )
#     )

#     for file_name in all_files:
#         with np.load(file_name) as npz:
#             raw_arr = np.ma.MaskedArray(data=npz['data'], mask=npz['mask'])
#             img_tensor_raw = torch.as_tensor(raw_arr.data, dtype=torch.float)
#             img_tensor_mask = ~torch.as_tensor(raw_arr.mask) # Revert mask: 0 is invalid, 1 is valid
#             img_tensor_masked = torch.mul(img_tensor_raw, img_tensor_mask)
#         data.append(img_tensor_masked)

#     return data

# %%
def load_data(directory: str):
    data = []

    all_files = np.array(
        sorted(
            glob(os.path.join(directory, "*.npz")),
            key=lambda x: int(os.path.basename(x).replace(".npz", "")),
        )
    )

    for file_name in all_files:
        with np.load(file_name) as npz:
            # Create masked array
            raw_arr = np.ma.MaskedArray(
                data=npz['data'],
                mask=npz['mask']
            )

            # Raw tensor (KEEP values as-is)
            img_tensor = torch.as_tensor(raw_arr.data, dtype=torch.float32)

            # Mask: 1 = valid, 0 = invalid
            mask = ~torch.as_tensor(raw_arr.mask)

        # Store BOTH
        data.append((img_tensor, mask))

    return data

# %%
def load_gt(file_path: str):
    """Load labels for train set from the ground truth file.
    Args:
        file_path (str): Path to the ground truth .csv file.
    Returns:
        [type]: 2D numpy array with soil properties levels
    """
    gt_file = pd.read_csv(file_path)
    labels = gt_file[["P", "K", "Mg", "pH"]].values
    return labels

# %%
X_train_full_data = load_data("/content/train_data/train")
y_train = load_gt("train_gt.csv")

# %%
original_spectral_channels = X_train_full_data[0][0].shape[0]
print(f"Original spectral channels: {original_spectral_channels}")
reduced_spectral_channels = 3 # Number of channels after 1x1 convolution
# Out:
# Original spectral channels: 150

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# -----------------------
# Split into train, val, test
# -----------------------

# Create an array of indices for X_train_full_data
original_indices = np.arange(len(X_train_full_data))

# First, split off test set (20%)
X_temp, X_test, y_temp, y_test, temp_indices, test_indices = train_test_split(
    X_train_full_data, y_train, original_indices, test_size=0.2, random_state=93
)

# Then, split remaining 80% into train/val (20% val of original, means 25% of X_temp)
X_train_final, X_val, y_train_final, y_val, train_indices, val_indices = train_test_split(
    X_temp, y_temp, temp_indices, test_size=0.25, random_state=93
)

print(f"Train patches: {len(X_train_final)}")
print(f"Validation patches: {len(X_val)}")
print(f"Test patches: {len(X_test)}")
# Out:
# Train patches: 1038
# Validation patches: 347
# Test patches: 347

# %%
def _pad_to_size_static(x, mask, size=(224, 224)):
    _, h, w = x.shape
    th, tw = size

    # ---- STEP 1: CROP if too large ----
    if h > th:
        start_h = (h - th) // 2
        x = x[:, start_h:start_h + th, :]
        mask = mask[:, start_h:start_h + th, :]
        h = th

    if w > tw:
        start_w = (w - tw) // 2
        x = x[:, :, start_w:start_w + tw]
        mask = mask[:, :, start_w:start_w + tw]
        w = tw

    # ---- STEP 2: PAD if too small ----
    pad_h = th - h
    pad_w = tw - w

    pad_top = pad_h // 2
    pad_bottom = pad_h - pad_top
    pad_left = pad_w // 2
    pad_right = pad_w - pad_left

    x = F.pad(x, (pad_left, pad_right, pad_top, pad_bottom), value=0)
    mask = F.pad(mask, (pad_left, pad_right, pad_top, pad_bottom), value=0)

    return x, mask

def calculate_global_stats(X_data, pad_function):
    print("Calculating global per-channel means and std deviations from training data...")

    # Initialize lists to store valid pixel values for each channel
    num_channels = X_data[0][0].shape[0]
    channel_data = [[] for _ in range(num_channels)]

    for x_item, mask_item in tqdm(X_data, desc="Processing X_data for global stats"):
        # Pad to consistent size first, as this affects the mask and values
        x_padded, mask_padded = pad_function(x_item, mask_item)

        # Extract valid pixels per channel
        for c in range(num_channels):
            valid_c_pixels = x_padded[c][mask_padded[c]].cpu().numpy()
            channel_data[c].extend(valid_c_pixels)

    # Calculate global mean and std for each channel
    global_means = torch.tensor([np.mean(c_data) for c_data in channel_data], dtype=torch.float32)
    global_stds = torch.tensor([np.std(c_data) for c_data in channel_data], dtype=torch.float32)

    print(f"Global Means (per channel): {global_means}")
    print(f"Global Std Devs (per channel): {global_stds}")
    return global_means, global_stds

# Call the new function to calculate global_means and global_stds
global_means, global_stds = calculate_global_stats(X_train_final, _pad_to_size_static)
# Out:
# Calculating global per-channel means and std deviations from training data...
# Processing X_data for global stats: 100%|██████████| 1038/1038 [00:58<00:00, 17.72it/s]
# Global Means (per channel): tensor([ 335.9208,  335.9069,  331.7341,  338.8154,  347.5788,  364.8742,
#          374.7284,  375.6686,  377.9044,  380.5071,  385.3977,  393.0356,
#          398.9632,  414.6352,  429.2801,  437.0627,  446.8707,  456.7486,
#          466.4856,  467.3013,  475.4815,  490.8455,  513.5848,  538.7640,
#          552.9874,  561.9896,  574.5370,  582.4282,  594.5684,  603.2874,
#          615.0793,  623.9404,  630.4449,  633.6147,  633.7065,  634.5967,
#          641.4842,  646.1486,  654.0912,  663.0143,  672.3674,  677.5461,
#          681.8059,  684.6404,  691.3089,  698.3139,  701.8467,  701.3326,
#          704.2673,  707.9794,  713.8121,  717.9084,  720.1819,  720.1807,
#          724.6096,  729.8087,  735.5328,  749.8523,  756.5817,  753.4753,
#          745.9611,  736.2238,  730.0534,  727.6396,  731.4945,  725.1307,
#          721.3279,  725.2855,  735.6935,  767.1006,  809.9006,  859.7301,
#          909.7721,  953.6044,  989.5249, 1022.1210, 1063.2218, 1101.7101,
#         1140.1877, 1178.6686, 1217.1389, 1255.6162, 1293.3997, 1332.8531,
#         1371.3094, 1409.9130, 1448.3417, 1484.5037, 1516.0455, 1541.4043,
#         1560.3298, 1573.9320, 1585.1880, 1592.7898, 1599.0718, 1611.7577,
#         1626.3330, 1641.4867, 1656.4990, 1670.0714, 1681.0873, 1689.0701,
#         1694.5651, 1699.4468, 1707.1460, 1714.1692, 1719.0737, 1724.9669,
#         1731.1602, 1737.1106, 1743.0660, 1749.0170, 1754.9700, 1760.9218,
#         1766.3571, 1774.0505, 1777.5378, 1783.7629, 1789.6421, 1800.2988,
#         1806.9561, 1796.4390, 1788.9020, 1793.6204, 1797.5359, 1800.8910,
#         1800.9287, 1802.1481, 1795.6338, 1791.5885, 1785.2273, 1793.1414,
#         1813.2843, 1821.8802, 1824.5221, 1830.5850, 1833.3019, 1836.2848,
#         1838.1533, 1839.6110, 1838.7266, 1841.1298, 1842.4954, 1843.9945,
#         1845.5948, 1847.2983, 1848.9431, 1850.0889, 1850.7344, 1851.3804])
# Global Std Devs (per channel): tensor([  83.5873,   83.7653,   83.4014,   84.5802,   86.1347,   88.7148,
#           90.4081,   90.9201,   91.8524,   92.9585,   94.5505,   96.6639,
#           98.4999,  102.0280,  105.7160,  108.3418,  111.5205,  114.8222,
#          118.4507,  121.0003,  125.1584,  130.8163,  137.6284,  144.5518,
#          149.2494,  152.4832,  156.2876,  159.1453,  162.6483,  165.2235,
#          168.1445,  170.2286,  171.6481,  172.3057,  172.3524,  172.6893,
#          174.4849,  175.9304,  178.1496,  180.6055,  183.1349,  184.7287,
#          186.0806,  187.0240,  188.8106,  190.6415,  191.6702,  191.7381,
#          192.6331,  193.7447,  195.2692,  196.2812,  196.7366,  196.6100,
#          197.4340,  198.4577,  199.8287,  203.5765,  205.8412,  205.8975,
#          204.9395,  203.5873,  203.3045,  204.2423,  206.9723,  206.4860,
#          207.5778,  210.8626,  214.0988,  218.6282,  221.9299,  226.1496,
#          235.7151,  254.3087,  281.8895,  315.1451,  351.9620,  393.0307,
#          436.4501,  481.5943,  528.0056,  575.3966,  622.6531,  672.2050,
#          722.4652,  772.8344,  822.0925,  866.8821,  903.8373,  931.0487,
#          948.7209,  959.0867,  965.9850,  970.8072,  974.6891,  982.7004,
#          991.8544, 1000.2990, 1007.8807, 1013.9455, 1018.0976, 1020.4000,
#         1021.4677, 1022.4651, 1025.0201, 1027.1683, 1028.0685, 1029.4962,
#         1031.1110, 1032.6251, 1034.1447, 1035.6680, 1037.1963, 1038.7286,
#         1040.0420, 1042.5991, 1042.6829, 1044.2885, 1045.6670, 1050.2690,
#         1053.2218, 1046.6475, 1041.8191, 1044.0597, 1045.7576, 1046.9637,
#         1046.2347, 1046.2178, 1041.8618, 1038.7881, 1034.0177, 1036.9529,
#         1047.3926, 1051.6470, 1052.7375, 1055.7521, 1056.3102, 1056.0933,
#         1054.2118, 1051.3027, 1046.6459, 1043.7375, 1040.2922, 1036.7638,
#         1033.2627, 1029.4626, 1025.0566, 1020.1485, 1014.8145, 1009.1259])

# %%
global_means.shape
# Out:
# torch.Size([150])

# %%
global_stds.shape
# Out:
# torch.Size([150])

# %%
# -------------------------------
# Scale labels
# -------------------------------
scaler_y = StandardScaler()
y_train_final_scaled = scaler_y.fit_transform(y_train_final)
y_val_scaled   = scaler_y.transform(y_val)
y_test_scaled  = scaler_y.transform(y_test)
joblib.dump(scaler_y, "scaler_labels.pkl")
print("Label scaler saved.")
# Out:
# Label scaler saved.

# %%
import torch
from torch.utils.data import Dataset
import torch.nn.functional as F
from torchvision.transforms import v2


class NPZDataset(Dataset):
    def __init__(self, tensor_list, labels = None, augment=True, size=(224, 224), global_means=None, global_stds=None):
        """
        tensor_list: list of tuples -> [(x, mask), ...]
                     x: (C, H, W)
                     mask: (C, H, W) with 1=valid, 0=invalid
        """
        self.tensor_list = tensor_list
        self.labels = labels
        self.augment = augment
        self.size = size
        self.global_means = global_means
        self.global_stds = global_stds

        self.transform_aug = v2.Compose([
            v2.RandomHorizontalFlip(p=0.5),
            v2.GaussianNoise(mean=0.0, sigma=0.03),
        ])

        #self.transform_basic = v2.Compose([])

    def __len__(self):
        return len(self.tensor_list)

    # ┅ Crop (if too large) + Pad (if too small)
    def pad_to_size(self, x, mask):
        _, h, w = x.shape
        th, tw = self.size

        # ---- STEP 1: CROP if too large ----
        if h > th:
            start_h = (h - th) // 2
            x = x[:, start_h:start_h + th, :]
            mask = mask[:, start_h:start_h + th, :]
            h = th

        if w > tw:
            start_w = (w - tw) // 2
            x = x[:, :, start_w:start_w + tw]
            mask = mask[:, :, start_w:start_w + tw]
            w = tw

        # ---- STEP 2: PAD if too small ----
        pad_h = th - h
        pad_w = tw - w

        pad_top = pad_h // 2
        pad_bottom = pad_h - pad_top
        pad_left = pad_w // 2
        pad_right = pad_w - pad_left

        x = F.pad(x, (pad_left, pad_right, pad_top, pad_bottom), value=0)
        mask = F.pad(mask, (pad_left, pad_right, pad_top, pad_bottom), value=0)

        return x, mask

    def normalize_with_mask(self, x, mask):
        # mask: 1 = valid, 0 = invalid
        if self.global_means is not None and self.global_stds is not None:
            # Use global per-channel statistics for normalization
            # Reshape global_means and global_stds to (C, 1, 1) for broadcasting
            x_norm = (x - self.global_means.to(x.device).view(-1, 1, 1)) / \
                     (self.global_stds.to(x.device).view(-1, 1, 1) + 1e-6)

        # ---- IMPORTANT: keep invalid pixels neutral ----
        x_norm = x_norm * mask

        return x_norm

    def __getitem__(self, idx):
        x, mask = self.tensor_list[idx]

        # 1. FIX SIZE FIRST
        x, mask = self.pad_to_size(x, mask)

        # 2. NORMALIZE USING MASK
        x = self.normalize_with_mask(x, mask)

        # 4. AUGMENTATION (only if labels are present, typically for training/validation)
        if self.augment and self.labels is not None:
            x = self.transform_aug(x)

        if self.labels is not None:
            y = torch.tensor(self.labels[idx], dtype=torch.float32)
            return x, y
        else:
            # For submission or inference without labels, return only the features
            return x

# %%
def check_normalized_stats(dataset: NPZDataset, device: torch.device):
    """
    Checks the per-channel mean and standard deviation of data AFTER normalization.
    It re-applies padding and normalization from the dataset's methods to raw data
    and then calculates statistics only on valid (non-masked) normalized pixels.
    """
    print("\nChecking per-channel means and std deviations for normalized data...")

    num_channels = dataset.tensor_list[0][0].shape[0]
    channel_data_normalized = [[] for _ in range(num_channels)]

    for idx in tqdm(range(len(dataset)), desc="Processing dataset for normalized stats"): # Iterate through the original data for accurate stats
        x_raw, mask_raw = dataset.tensor_list[idx]

        # Apply padding using the dataset's method
        x_padded, mask_padded = dataset.pad_to_size(x_raw, mask_raw)

        # Apply normalization using the dataset's method (which uses global_means/stds)
        x_normalized = dataset.normalize_with_mask(x_padded, mask_padded)

        # Extract valid pixels per channel from the normalized data
        for c in range(num_channels):
            # Ensure mask_padded is also on CPU if x_normalized is on CPU for indexing
            valid_c_pixels = x_normalized[c][mask_padded[c]].cpu().numpy()
            channel_data_normalized[c].extend(valid_c_pixels)

    # Calculate mean and std for each channel from the normalized valid pixels
    means_normalized = torch.tensor([np.mean(c_data) for c_data in channel_data_normalized if len(c_data) > 0], dtype=torch.float32)
    stds_normalized = torch.tensor([np.std(c_data) for c_data in channel_data_normalized if len(c_data) > 0], dtype=torch.float32)

    print(f"Normalized Means (per channel): {means_normalized}")
    print(f"Normalized Std Devs (per channel): {stds_normalized}")
    return means_normalized, stds_normalized

# %%
# -----------------------
# Create Dataset and DataLoader with global stats
# -----------------------

train_dataset = NPZDataset(X_train_final, y_train_final_scaled, augment=True, global_means=global_means, global_stds=global_stds)
val_dataset   = NPZDataset(X_val, y_val_scaled, augment=False, global_means=global_means, global_stds=global_stds)
test_dataset  = NPZDataset(X_test, y_test_scaled, augment=False, global_means=global_means, global_stds=global_stds)


train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=2, pin_memory=True)

# %%
# Verify normalization for the training dataset
normalized_means_train, normalized_stds_train = check_normalized_stats(train_dataset, device)
# Out:
# Checking per-channel means and std deviations for normalized data...
# Processing dataset for normalized stats: 100%|██████████| 1038/1038 [00:56<00:00, 18.45it/s]

# %%
import torch
import torch.nn as nn
import timm

class HyperspectralRegressor(nn.Module):
    def __init__(
        self,
        original_in_channels: int = 150,
        reduced_in_channels: int = 10,
        n_outputs: int = 4,
        backbone_name: str = "efficientnet_b0",
        pretrained: bool = False,
        dropout: float = 0.3,
        regressor: nn.Module = None,
    ):
        """
        original_in_channels: Number of input spectral bands (masked pixels are zero).
        reduced_in_channels: Number of channels after 1x1 convolution.
        n_outputs: Number of regression outputs.
        backbone_name: Name of the model in timm.
        pretrained: Whether to load ImageNet weights (safe only if reduced_in_channels==3).
        """
        super().__init__()

        # 1x1 spectral reducer: Conv -> BN -> ReLU
        self.spectral_reducer = nn.Sequential(
            nn.Conv2d(original_in_channels, reduced_in_channels, kernel_size=1, bias=True),
            nn.BatchNorm2d(reduced_in_channels),
            nn.ReLU(inplace=True),
        )

        effective_pretrained = pretrained
        if pretrained and reduced_in_channels != 3:
            effective_pretrained = False

        self.backbone = timm.create_model(
            backbone_name,
            pretrained=effective_pretrained,
            in_chans=reduced_in_channels,
            num_classes=0,
        )

        feat_dim = getattr(self.backbone, "num_features", None)
        if feat_dim is None:
            if hasattr(self.backbone, "fc") and hasattr(self.backbone.fc, "in_features"):
                feat_dim = self.backbone.fc.in_features
            else:
                raise RuntimeError("Backbone features cannot be determined")

        # Use provided regressor or default to the original one
        if regressor is None:
            self.regressor = nn.Sequential(
                nn.Linear(feat_dim, 512),
                nn.ReLU(inplace=True),
                nn.Dropout(dropout),
                nn.Linear(512, n_outputs),
            )
        else:
            self.regressor = regressor

        nn.init.kaiming_normal_(self.spectral_reducer[0].weight, nonlinearity="relu")
        if self.spectral_reducer[0].bias is not None:
            nn.init.zeros_(self.spectral_reducer[0].bias)

    def forward(self, x):
        """
        x: (B, original_in_channels, H, W)  -- masked pixels = 0
        returns: (B, n_outputs)
        """
        x = self.spectral_reducer(x)      # (B, reduced_in_channels, H, W)
        features = self.backbone(x)       # (B, feat_dim)
        out = self.regressor(features)    # (B, n_outputs)
        return out

    def freeze_backbone(self):
        for p in self.backbone.parameters():
            p.requires_grad = False

    def unfreeze_backbone(self):
        for p in self.backbone.parameters():
            p.requires_grad = True

# %% [markdown]
# ## **Overfitting on one batch**

# %%
def overfit_single_batch(
    model: nn.Module,
    criterion: nn.Module,
    optimizer: optim.Optimizer,
    x_single: torch.Tensor,
    y_single: torch.Tensor,
    epochs: int = 500,
    device: torch.device = torch.device("cpu")
):
    """
    Performs overfitting of a model on a single batch of data.

    Args:
        model (nn.Module): The model to overfit.
        criterion (nn.Module): The loss function.
        optimizer (optim.Optimizer): The optimizer.
        x_single (torch.Tensor): The input features for the single batch.
        y_single (torch.Tensor): The target labels for the single batch.
        epochs (int): The number of epochs to train for.
        device (torch.device): The device (CPU/GPU) to run the training on.
    """
    print(f"\n--- Starting Overfitting on Single Batch for {epochs} epochs ---")

    x_single, y_single = x_single.to(device), y_single.to(device)

    for epoch_overfit in range(epochs):
        model.train()
        optimizer.zero_grad()

        outputs_overfit = model(x_single)
        loss_overfit = criterion(outputs_overfit, y_single)

        loss_overfit.backward()
        optimizer.step()

        if (epoch_overfit + 1) % 10 == 0 or epoch_overfit == 0:
            print(f"Overfit Epoch {epoch_overfit+1}/{epochs} - Loss: {loss_overfit.item():.6f}")

    print("--- Overfitting complete ---")

# %%
train_data_single_batch = next(iter(train_loader))

# %%
train_data_single_batch[0].shape
# Out:
# torch.Size([64, 150, 224, 224])

# %%
train_data_single_batch[1].shape
# Out:
# torch.Size([64, 4])

# %%
import torch
import torch.nn as nn
import timm

# Re-initialize a fresh model for overfitting
model_overfit = HyperspectralRegressor(
    reduced_in_channels = 3,   # reduced channels
    n_outputs = 4,      # P, K, Mg, pH
    backbone_name = "convnext_base_in22k",
    pretrained = True  # Use pre-trained weights
)
model_overfit = model_overfit.to(device)

# Define optimizer and criterion for overfitting
optimizer_overfit = optim.AdamW(model_overfit.parameters(), lr=8e-5, weight_decay=1e-4)
criterion_overfit = nn.SmoothL1Loss(beta=1.0)

# Extract the single batch
x_single, y_single = train_data_single_batch

# Move x_single and y_single to the device for consistent usage
x_single = x_single.to(device)
y_single = y_single.to(device)

# Call the overfit_single_batch function
overfit_single_batch(
    model=model_overfit,
    criterion=criterion_overfit,
    optimizer=optimizer_overfit,
    x_single=x_single,
    y_single=y_single,
    epochs=100,
    device=device
)
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/_factory.py:138: UserWarning: Mapping deprecated model name convnext_base_in22k to current convnext_base.fb_in22k.
#   model = create_fn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# --- Starting Overfitting on Single Batch for 100 epochs ---
# Overfit Epoch 1/100 - Loss: 0.450368
# Overfit Epoch 10/100 - Loss: 0.241486
# Overfit Epoch 20/100 - Loss: 0.069687
# Overfit Epoch 30/100 - Loss: 0.021556
# Overfit Epoch 40/100 - Loss: 0.017770
# Overfit Epoch 50/100 - Loss: 0.015186
# Overfit Epoch 60/100 - Loss: 0.013060
# Overfit Epoch 70/100 - Loss: 0.014344
# Overfit Epoch 80/100 - Loss: 0.009942
# Overfit Epoch 90/100 - Loss: 0.011951
# Overfit Epoch 100/100 - Loss: 0.012068
# --- Overfitting complete ---

# %%
print('\n--- Model Overfit Predictions vs. True Values ---')
model_overfit.eval() # Set model to evaluation mode

with torch.no_grad():
    outputs_single_batch = model_overfit(x_single)

print("Predictions:")
print(outputs_single_batch.cpu().numpy())
print("\nTrue Values:")
print(y_single.cpu().numpy())
# Out:
# --- Model Overfit Predictions vs. True Values ---
# Predictions:
# [[-0.49326852  0.42544964  1.3154963  -1.5591632 ]
#  [-1.3326854   0.8424472   1.6836411   0.5562009 ]
#  [-0.8033349   0.6021602   0.28541684  0.08406287]
#  [-0.6916579  -0.15126894 -1.7309012  -1.0819119 ]
#  [-0.65845644 -0.84430206  1.1219705  -1.8029302 ]
#  [-0.4718208   0.153808   -0.22064495  0.29844546]
#  [ 0.59174436 -0.5876257  -0.31603894  0.4826819 ]
#  [-0.46627045 -0.6789033  -0.5017163  -0.6529521 ]
#  [ 0.12115322 -0.21493419 -0.09127805  0.4757113 ]
#  [ 1.1137576   2.3602264  -0.08124782  2.211998  ]
#  [ 0.5961181   0.2929509  -1.1817037   0.07345161]
#  [-0.11377377 -0.2684372  -0.13895153 -1.0474842 ]
#  [ 1.6637022   0.7477354   1.4042246   0.09545218]
#  [-0.47917655 -0.91356415  0.85278994  0.4049458 ]
#  [ 0.4160859   0.1462563   0.358995    0.03518713]
#  [-1.1235795  -0.60380304 -1.8690336  -0.44044957]
#  [ 1.0260412   1.3576623  -0.14420179  0.73257965]
#  [ 2.5430446   3.527835    3.8068047   1.6862494 ]
#  [ 0.26178923 -0.3489454  -0.54475087 -0.73829746]
#  [-0.6210681  -0.19376849 -0.84161174 -0.30266315]
#  [-0.09498912  1.2373846   2.0918543  -0.3258035 ]
#  [-0.88245976 -0.3390355  -0.1741944  -0.34295166]
#  [ 0.26921222 -1.0960683  -2.3928118  -0.71874785]
#  [-0.3112276  -0.4423826  -0.99248224  2.386286  ]
#  [ 0.30442366 -0.2669898  -0.06841187 -0.99482733]
#  [ 0.2952689   1.0122045   0.2951978   0.08531597]
#  [ 0.38175604  0.4748947   0.04431909  0.32932982]
#  [ 0.7232451   2.697334    0.6429976  -0.7439785 ]
#  [-0.05112356  1.8486147   1.0046111  -0.6261498 ]
#  [-1.2469705  -0.5949078   1.6837147   0.8309759 ]
#  [ 0.09825242 -0.38219535 -0.64988416  0.8312164 ]
#  [-1.2604682  -1.3539919  -0.70449436 -1.1271994 ]
#  [-0.6306133  -1.0951596  -0.43139896 -2.2421012 ]
#  [-0.4574187  -0.873148   -0.19138902  0.03271475]
#  [ 0.11578946  1.0785543   0.6674317   1.5434923 ]
#  [-0.7067868   0.15860379  0.39618206  0.12131333]
#  [-0.11691382 -0.3652975  -0.4113996   0.02404869]
#  [-0.7338426  -0.9432268  -0.8173095   0.4142098 ]
#  [ 0.20559241 -0.5135081   0.62489116  0.04881475]
#  [-1.358464   -0.0473241  -0.5963172  -0.05908656]
#  [-0.8952258   0.25785905  2.619651    1.2790679 ]
#  [ 1.1238972   1.7030921   1.2930077  -0.63863933]
#  [ 0.14520878 -0.43967518 -0.21281502  1.2859739 ]
#  [-1.2734861   0.93572235  1.3163792   0.44485578]
#  [ 1.0814755   0.27198416 -0.33369505  0.29938036]
#  [ 0.3312391   0.21231848  2.0798864   2.5120118 ]
#  [-1.2022082  -1.0775818   0.345694   -1.4245889 ]
#  [-0.48213038 -0.3580746   0.18928951 -1.1936835 ]
#  [-0.06743197 -0.5077499  -1.140219    0.1258882 ]
#  [ 4.782436    2.4430182   0.24314019 -0.08606891]
#  [ 0.5062456   0.30334708 -0.82714367  0.06434352]
#  [-1.3916873  -0.5657599   3.8693378   0.4628075 ]
#  [ 0.2787464   0.08838038 -0.7167953   2.3151462 ]
#  [ 0.23074487 -0.4178853   0.0560654   0.4436013 ]
#  [-0.58673644 -1.0529182  -1.3193698   0.46107402]
#  [ 1.3133956   2.5781589  -1.0206122  -0.36605978]
#  [ 0.49386513 -0.19813421 -0.20450026 -0.7321483 ]
#  [-0.7478974   0.17195526  1.2703097   0.45186698]
#  [ 1.1982476   3.9555058   0.21781453  3.6882575 ]
#  [-1.0118239  -1.5482717   0.20795414 -0.72197944]
#  [ 0.07206894 -1.100462    0.10586684 -0.685629  ]
#  [ 0.80278736  1.0521926   0.6741031   0.09595612]
#  [ 0.3406932   1.2567168   0.5326407  -0.68004847]
#  [-0.068074    0.21877825  0.05001961  0.3438958 ]]
#
# True Values:
# [[-0.48429713  0.4776109   1.4057288  -1.5017383 ]
#  [-1.4344758   0.7103551   1.7606179   0.4510633 ]
#  [-0.78122795  0.5441092   0.2903633   0.06050299]
#  [-0.61704266 -0.13749878 -1.7654582  -1.111178  ]
#  [-0.66944224 -0.9521035   1.1522367  -1.8922987 ]
#  [-0.48080382  0.14511918 -0.29266867  0.3338952 ]
#  [ 0.5986271  -0.61961174 -0.36871633  0.4510633 ]
#  [-0.49827033 -0.73598385 -0.6222085  -0.72061765]
#  [ 0.10607125 -0.27049547 -0.14057337  0.4510633 ]
#  [ 1.1750222   2.4725611  -0.21662103  2.4038649 ]
#  [ 0.63705343  0.2448667  -1.2305897   0.06050299]
#  [-0.13846003 -0.30374464 -0.1659226  -1.111178  ]
#  [ 1.6990179   0.69373053  1.4817765   0.06050299]
#  [-0.48429713 -0.9188543   0.9747922   0.4510633 ]
#  [ 0.37156236  0.07862084  0.31571254  0.06050299]
#  [-1.0257592  -0.6694855  -1.9403678  -0.44722542]
#  [ 1.0702231   1.3420893  -0.1659226   0.84162366]
#  [ 2.5723438   3.51991     3.7378569   1.6227443 ]
#  [ 0.2458034  -0.42011672 -0.5461608  -0.72061765]
#  [-0.62053597 -0.20399712 -0.87570065 -0.33005735]
#  [-0.13846003  1.2257173   2.0901577  -0.33005735]
#  [-0.85109407 -0.38686755 -0.1659226  -0.33005735]
#  [ 0.36108243 -1.1682231  -2.4042585  -0.72061765]
#  [-0.23976585 -0.4533659  -0.9517483   2.4038649 ]
#  [ 0.28073645 -0.3203692  -0.14057337 -1.111178  ]
#  [ 0.35060254  0.9264747   0.26501408  0.06050299]
#  [ 0.3925222   0.5108601   0.06222036  0.4510633 ]
#  [ 0.8676115   2.805053    0.64525235 -0.72061765]
#  [-0.14544664  1.9405744   1.1268874  -0.72061765]
#  [-1.458929   -0.5863626   1.8620148   0.84162366]
#  [ 0.15847081 -0.43674132 -0.7489546   0.84162366]
#  [-1.2667972  -1.3510935  -0.72360533 -1.111178  ]
#  [-0.6240293  -1.1017247  -0.49546242 -2.2828588 ]
#  [-0.41792434 -0.85235596 -0.1659226   0.06050299]
#  [ 0.17244403  1.0428468   0.7213      1.6227443 ]
#  [-0.7113619   0.11187001  0.34106174  0.06050299]
#  [-0.08256717 -0.37024298 -0.41941476  0.06050299]
#  [-0.72882843 -0.9188543  -0.85035145  0.4510633 ]
#  [ 0.19340384 -0.53648883  0.64525235  0.06050299]
#  [-1.4414624  -0.1042496  -0.7489546  -0.05666511]
#  [-0.9209601   0.27811587  2.470396    1.2321839 ]
#  [ 1.1400893   1.5748335   1.2789828  -0.72061765]
#  [ 0.20388375 -0.43674132 -0.19127181  1.2321839 ]
#  [-1.3226901   0.97634846  1.4817765   0.4510633 ]
#  [ 1.1400893   0.26149127 -0.39406553  0.37295124]
#  [ 0.45190835  0.26149127  1.9887608   2.4038649 ]
#  [-1.172478   -1.0851002   0.36641097 -1.5017383 ]
#  [-0.42491096 -0.4699905   0.16361722 -1.111178  ]
#  [ 0.04668508 -0.53648883 -1.1291928   0.06050299]
#  [ 4.493661    2.2065678   0.18896644 -0.33005735]
#  [ 0.55321413  0.22824211 -0.85035145  0.06050299]
#  [-1.448449   -0.63623637  3.8392537   0.4510633 ]
#  [ 0.4169753   0.17836834 -0.67290694  2.3648088 ]
#  [ 0.23532349 -0.4533659   0.03687114  0.4510633 ]
#  [-0.5681364  -1.1183493  -1.2559389   0.4510633 ]
#  [ 1.3846205   2.6720562  -1.0531452  -0.33005735]
#  [ 0.50780123 -0.23724629 -0.21662103 -0.72061765]
#  [-0.7462949   0.17836834  1.2029351   0.4510633 ]
#  [ 1.3147545   3.7526543   0.11291879  3.575546  ]
#  [-0.93144006 -1.5505886   0.21431567 -0.72061765]
#  [ 0.05367169 -1.1682231   0.13826801 -0.72061765]
#  [ 0.8571316   1.0262222   0.7213      0.06050299]
#  [ 0.3086829   1.192468    0.5692047  -0.72061765]
#  [-0.11750021  0.12849459  0.06222036  0.4510633 ]]

# %%
# Load the label scaler
scaler_y = joblib.load("scaler_labels.pkl")
print("Label scaler loaded.")

print('\n--- Unscaled Model Overfit Predictions vs. Unscaled True Values ---')
# Inverse transform predictions and true values
unscaled_predictions = scaler_y.inverse_transform(outputs_single_batch.cpu().numpy())
unscaled_true_values = scaler_y.inverse_transform(y_single.cpu().numpy())

print("Unscaled Predictions:")
print(unscaled_predictions)
print("\nUnscaled True Values:")
print(unscaled_true_values)
# Out:
# Label scaler loaded.
#
# --- Unscaled Model Overfit Predictions vs. Unscaled True Values ---
# Unscaled Predictions:
# [[ 56.243183  253.8624    210.44043     6.385297 ]
#  [ 32.21387   278.9456    224.96335     6.9269195]
#  [ 47.36716   264.49188   169.80487     6.806032 ]
#  [ 50.56405   219.17169    90.26324     6.5074935]
#  [ 51.51448   177.48447   202.80603     6.322882 ]
#  [ 56.85715   237.52264   149.84126     6.8609233]
#  [ 87.30297   192.92403   146.07806     6.908096 ]
#  [ 57.016037  187.4335    138.7533      6.6173253]
#  [ 73.83174   215.34212   154.94464     6.906311 ]
#  [102.24622   370.24286   155.34033     7.350874 ]
#  [ 87.42818   245.89235   111.928505    6.803315 ]
#  [ 67.106674  212.12381   153.06398     6.5163083]
#  [117.98905   273.2485    213.94066     6.8089485]
#  [ 56.646584  173.31822   192.18713     6.888192 ]
#  [ 82.27454   237.0684    172.70744     6.793518 ]
#  [ 38.199776  191.95093    84.81406     6.671735 ]
#  [ 99.73524   309.93674   152.85686     6.97208  ]
#  [143.16127   440.47668   308.71994     7.21626  ]
#  [ 77.85761   207.28108   137.05562     6.5954733]
#  [ 52.584766  216.61526   125.34477     6.707014 ]
#  [ 67.64441   302.7018    241.06694     6.7010894]
#  [ 45.10212   207.87718   151.67369     6.6966987]
#  [ 78.07011   162.34024    64.15156     6.6004786]
#  [ 61.454323  201.66066   119.39309     7.395499 ]
#  [ 79.07807   212.21088   155.8467      6.529791 ]
#  [ 78.81601   289.1568    170.19072     6.806353 ]
#  [ 81.29181   256.8366    160.29381     6.868831 ]
#  [ 91.06734   390.5205    183.91106     6.5940185]
#  [ 68.90011   339.46844   198.17633     6.624188 ]
#  [ 34.66756   192.486     224.96625     6.997274 ]
#  [ 73.17618   205.28104   132.90822     6.9973354]
#  [ 34.281174  146.82565   130.7539      6.495898 ]
#  [ 52.311523  162.3949    141.52724     6.210436 ]
#  [ 57.26943   175.74931   150.99538     6.792885 ]
#  [ 73.67819   293.14786   184.87495     7.179708 ]
#  [ 50.130966  237.81113   174.17444     6.81557  ]
#  [ 67.016785  206.29749   142.3162      6.790666 ]
#  [ 49.35646   171.53395   126.303474    6.890564 ]
#  [ 76.24891   197.38234   183.19678     6.797007 ]
#  [ 31.475931  225.42418   135.0214      6.76938  ]
#  [ 44.736675  243.78151   261.88797     7.1120043]
#  [102.53648   330.715     209.55327     6.62099  ]
#  [ 74.520355  201.82352   150.15015     7.1137724]
#  [ 33.90852   284.55627   210.47525     6.898411 ]
#  [101.32211   244.63116   145.38155     6.8611627]
#  [ 79.845695  241.04216   240.59482     7.42769  ]
#  [ 35.948936  163.45224   172.18274     6.4197536]
#  [ 56.562027  206.73195   166.01274     6.478875 ]
#  [ 68.433266  197.7287    113.56503     6.8167415]
#  [207.26653   375.22293   168.1371      6.762471 ]
#  [ 84.85547   246.5177    125.91552     6.8009834]
#  [ 30.524874  194.23929   311.1868      6.903007 ]
#  [ 78.34303   233.58705   130.26865     7.377284 ]
#  [ 76.96893   203.13423   160.75719     6.8980894]
#  [ 53.56755   164.9358    106.49772     6.902563 ]
#  [107.961105  383.3519    118.283394    6.690782 ]
#  [ 84.50106   216.35266   150.47815     6.597048 ]
#  [ 48.95413   238.61424   208.65785     6.9002056]
#  [104.664856  466.2019    167.13803     7.728859 ]
#  [ 41.398914  135.13936   166.74904     6.5996513]
#  [ 72.42664   162.07596   162.7218      6.6089587]
#  [ 93.34433   291.56216   185.13814     6.8090777]
#  [ 80.11633   303.8647    179.55759     6.6103873]
#  [ 68.41489   241.43073   160.51869     6.8725605]]
#
# Unscaled True Values:
# [[ 56.5      257.       214.         6.4     ]
#  [ 29.300001 271.       228.         6.9     ]
#  [ 48.       261.       170.         6.8     ]
#  [ 52.7      220.        88.899994   6.5     ]
#  [ 51.2      171.       204.         6.3     ]
#  [ 56.6      237.       147.         6.87    ]
#  [ 87.5      191.       144.         6.9     ]
#  [ 56.100002 184.       134.         6.6     ]
#  [ 73.4      212.       153.         6.9     ]
#  [104.       377.       150.         7.4     ]
#  [ 88.6      243.       110.         6.8     ]
#  [ 66.4      210.       152.         6.5     ]
#  [119.       270.       217.         6.8     ]
#  [ 56.5      173.       197.         6.9     ]
#  [ 81.       233.       171.         6.8     ]
#  [ 41.       188.        82.         6.67    ]
#  [101.       309.       152.         7.      ]
#  [144.       440.       306.         7.2     ]
#  [ 77.4      203.       137.         6.6     ]
#  [ 52.6      216.       124.         6.7     ]
#  [ 66.4      302.       241.         6.7     ]
#  [ 46.       205.       152.         6.7     ]
#  [ 80.7      158.        63.699997   6.6     ]
#  [ 63.5      201.       121.         7.4     ]
#  [ 78.4      209.       153.         6.5     ]
#  [ 80.4      284.       169.         6.8     ]
#  [ 81.6      259.       161.         6.9     ]
#  [ 95.2      397.       184.         6.6     ]
#  [ 66.2      345.       203.         6.6     ]
#  [ 28.6      193.       232.         7.      ]
#  [ 74.9      202.       129.         7.      ]
#  [ 34.1      147.       130.         6.5     ]
#  [ 52.5      162.       139.         6.2     ]
#  [ 58.4      177.       152.         6.8     ]
#  [ 75.3      291.       187.         7.2     ]
#  [ 50.       235.       172.         6.8     ]
#  [ 68.       206.       142.         6.8     ]
#  [ 49.5      173.       125.         6.9     ]
#  [ 75.9      196.       184.         6.8     ]
#  [ 29.1      222.       129.         6.77    ]
#  [ 44.       245.       256.         7.1     ]
#  [103.       323.       209.         6.6     ]
#  [ 76.2      202.       151.         7.1     ]
#  [ 32.499996 287.       217.         6.9     ]
#  [103.       244.       143.         6.88    ]
#  [ 83.3      244.       237.         7.4     ]
#  [ 36.8      163.       173.         6.4     ]
#  [ 58.2      200.       165.         6.5     ]
#  [ 71.7      196.       114.         6.8     ]
#  [199.       361.       166.         6.7     ]
#  [ 86.2      242.       125.         6.8     ]
#  [ 28.9      190.       310.         6.9     ]
#  [ 82.3      239.       132.         7.39    ]
#  [ 77.1      201.       160.         6.9     ]
#  [ 54.100002 161.       109.         6.9     ]
#  [110.       389.       117.         6.7     ]
#  [ 84.9      214.       150.         6.6     ]
#  [ 49.       239.       206.         6.9     ]
#  [108.       454.       163.         7.7     ]
#  [ 43.7      135.       167.         6.6     ]
#  [ 71.9      158.       164.         6.6     ]
#  [ 94.9      290.       187.         6.8     ]
#  [ 79.2      300.       181.         6.6     ]
#  [ 67.       236.       161.         6.9     ]]

# %%
plt.figure(figsize=(15, 5))

metrics = ['P', 'K', 'Mg', 'pH']
for i, metric in enumerate(metrics):
    plt.subplot(1, 4, i + 1) # 1 row, 4 columns
    plt.scatter(unscaled_true_values[:, i], unscaled_predictions[:, i], alpha=0.7)
    plt.plot([min(unscaled_true_values[:, i]), max(unscaled_true_values[:, i])],
             [min(unscaled_true_values[:, i]), max(unscaled_true_values[:, i])],
             'r--') # Red dashed line for ideal prediction
    plt.title(f'{metric} (Overfit Batch)')
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Training loop**

# %%
import os
import torch
from tqdm import tqdm

def train_with_early_stopping(
    model,
    train_loader,
    val_loader,
    optimizer,
    scheduler,            # ReduceLROnPlateau expected
    criterion,
    device,
    epochs=120,
    warmup_epochs=5,
    patience=20,
    save_path="best_hyperspectral_model.pth",
    use_amp=True, # Re-introduced use_amp parameter
    max_grad_norm=1.0,
    wandb_run=None
):
    # initial LRs per param_group (order must match how optimizer was created)
    initial_lrs = [pg['lr'] for pg in optimizer.param_groups]

    best_val_loss = float('inf')
    early_stop_counter = 0
    scaler = torch.cuda.amp.GradScaler(enabled=use_amp) # Re-introduced GradScaler initialization

    for epoch in range(epochs):
        # ---------- TRAIN ----------
        model.train()
        train_running_loss = 0.0
        train_samples = 0

        # linear warmup
        if epoch < warmup_epochs:
            warmup_factor = (epoch + 1) / float(warmup_epochs)
            for i, pg in enumerate(optimizer.param_groups):
                pg['lr'] = initial_lrs[i] * warmup_factor

        loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}", leave=False)
        for xb, yb in loop:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            optimizer.zero_grad()

            with torch.cuda.amp.autocast(enabled=use_amp): # Re-introduced torch.cuda.amp.autocast context
                preds = model(xb)
                loss = criterion(preds, yb)

            scaler.scale(loss).backward() # Re-introduced scaler.scale and backward

            # Calculate gradient norm before clipping
            # Unscale the gradients before clipping, if using AMP
            if use_amp:
                scaler.unscale_(optimizer)

            # Pass inf to just calculate norm, not clip
            #total_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), float('inf'))
            total_norm = torch.sqrt(
                sum(p.grad.detach().norm(2)**2 for p in model.parameters() if p.grad is not None)
            )

            # for name, p in model.named_parameters():
            #   if p.grad is not None:
            #       print(name, p.grad.abs().mean().item())
            #       break

            # Clip gradient
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)

            scaler.step(optimizer) # Re-introduced scaler.step
            scaler.update() # Re-introduced scaler.update

            bsz = xb.size(0)
            train_running_loss += loss.item() * bsz
            train_samples += bsz

            loop.set_postfix(
                train_loss=loss.item(),
                grad_norm=total_norm.item(), # Log gradient norm
                lr_backbone=optimizer.param_groups[0]['lr'],
                lr_head=optimizer.param_groups[1]['lr']
            )

        train_loss = train_running_loss / max(1, train_samples)

        # ---------- VALIDATION ----------
        model.eval()
        val_running_loss = 0.0
        val_samples = 0
        # optional threshold for logging outlier batches (set after first epoch if desired)
        outlier_threshold = None

        with torch.no_grad():
            for i, (xv, yv) in enumerate(val_loader):
                xv = xv.to(device, non_blocking=True)
                yv = yv.to(device, non_blocking=True)

                with torch.cuda.amp.autocast(enabled=use_amp): # Re-introduced torch.cuda.amp.autocast context
                    vpreds = model(xv)
                    vloss = criterion(vpreds, yv)

                bsz = xv.size(0)
                val_running_loss += vloss.item() * bsz
                val_samples += bsz

                # detect very large batch losses for debugging
                if outlier_threshold is not None and vloss.item() > outlier_threshold:
                    print(f"[DEBUG] Large val batch loss epoch {epoch+1} batch {i}: {vloss.item():.4f}")
                    # optionally save xv, yv, vpreds.cpu() for inspection

        val_loss = val_running_loss / max(1, val_samples)

        # ---------- SCHEDULER ----------
        # ReduceLROnPlateau expects scheduler.step(metric)
        if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
            scheduler.step(val_loss)
        else:
            # if you use other schedulers, call scheduler.step() here (after warmup if needed)
            if epoch >= warmup_epochs - 1:
                scheduler.step()

        # ---------- LOGGING ----------
        current_lrs = [pg['lr'] for pg in optimizer.param_groups]
        print(f"Epoch {epoch+1}/{epochs} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f} - backbone LR: {current_lrs[0]:.6f} - head LR: {current_lrs[1]:.6f}")

        if wandb_run is not None:
            wandb_run.log({
                "train_loss": train_loss,
                "val_loss": val_loss,
                "epoch": epoch + 1,
                "lr_backbone": current_lrs[0],
                "lr_head": current_lrs[1],
                "grad_norm": total_norm.item() # Log gradient norm to wandb
            })

        # ---------- EARLY STOPPING & CHECKPOINT ----------
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0
            # save full checkpoint
            torch.save({
                "epoch": epoch,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "scheduler_state_dict": scheduler.state_dict() if hasattr(scheduler, "state_dict") else None,
                "val_loss": val_loss,
            }, save_path)
            print(f"Saved best model (val_loss={val_loss:.4f})")
        else:
            early_stop_counter += 1
            if early_stop_counter >= patience:
                print(f"Early stopping at epoch {epoch+1} (no improvement for {patience} epochs)")
                break

    # load best model if exists
    if os.path.exists(save_path):
        ckpt = torch.load(save_path, map_location=device)
        model.load_state_dict(ckpt["model_state_dict"])
    return model

# %%
# ----- Model -----
model = HyperspectralRegressor(
    reduced_in_channels = 3,   # reduced channels
    n_outputs = 4,      # P, K, Mg, pH
    backbone_name = "convnext_base_in22k",
    pretrained = True
)

model = model.to(device);

# ----- Optimizer -----
optimizer = optim.AdamW([
    {"params": model.backbone.parameters(), "lr": 5e-6},
    {"params": model.regressor.parameters(), "lr": 1e-5},
], weight_decay=1e-4)

# ----- Loss -----
#criterion = nn.MSELoss()
criterion = nn.SmoothL1Loss(beta=1.0)

# ----- Scheduler -----
scheduler = ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.3,
    patience=5,
    min_lr=1e-6
)

# ----- Hyperparameters -----
epochs = 80
patience = 10  # Increased early stopping patience
warmup_epochs = 8 # Number of epochs for warm-up

# ----- Initialize wandb -----
# Initializing Weights & Biases for experiment tracking.
wandb.init(
    project="hyperview_challenge convnext_base_in22k (pretrained=true), 1x1 cov, nn.SmoothL1Loss(beta=1.0), global normalization",
    config={
        "learning_rate_backbone": 5e-6, # Updated in config
        "learning_rate_head": 1e-5, # Updated in config
        "epochs": epochs,
        "batch_size": 32,
        "optimizer": "AdamW",
        "criterion": "SmoothL1Loss(beta=1.0)",
        "backbone": "convnext_base_in22k",
        "1x1_conv_filters": 3,
        "scheduler": "ReduceLROnPlateau",
        "scheduler_factor": 0.3,
        "scheduler_patience": 5,
        "min_lr": 1e-6,
        "warmup_epochs": warmup_epochs,
        "early_stopping_patience": patience,
        "use_amp": True,
        "gaussian_noise_enabled": True
    }
)
# Log a note to wandb about this run's configuration
wandb.run.log({"note": "This run uses: (1) convnext_base_in22k backbone (pretrained=true), (2) 1x1 conv used, (3) nn.SmoothL1Loss(beta=1.0), (4)padding instead of resize (!), (5) batch size 32, (6) Automatic Mixed Precision enabled, (7) Lowered LRs and Increased Early Stopping Patience (15), (8) Global normalization (!)"})
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/_factory.py:138: UserWarning: Mapping deprecated model name convnext_base_in22k to current convnext_base.fb_in22k.
#   model = create_fn(
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ggasowski977 (ggasowski977-politechnika-warszawska) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/content/wandb/run-20260423_020820-0cz23zfl</code>
# Syncing run <strong><a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20convnext_base_in22k%20%28pretrained%3Dtrue%29%2C%201x1%20cov%2C%20nn.SmoothL1Loss%28beta%3D1.0%29%2C%20global%20normalization/runs/0cz23zfl' target="_blank">giddy-haze-2</a></strong> to <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20convnext_base_in22k%20%28pretrained%3Dtrue%29%2C%201x1%20cov%2C%20nn.SmoothL1Loss%28beta%3D1.0%29%2C%20global%20normalization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20convnext_base_in22k%20%28pretrained%3Dtrue%29%2C%201x1%20cov%2C%20nn.SmoothL1Loss%28beta%3D1.0%29%2C%20global%20normalization' target="_blank">https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20convnext_base_in22k%20%28pretrained%3Dtrue%29%2C%201x1%20cov%2C%20nn.SmoothL1Loss%28beta%3D1.0%29%2C%20global%20normalization</a>
#  View run at <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20convnext_base_in22k%20%28pretrained%3Dtrue%29%2C%201x1%20cov%2C%20nn.SmoothL1Loss%28beta%3D1.0%29%2C%20global%20normalization/runs/0cz23zfl' target="_blank">https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20convnext_base_in22k%20%28pretrained%3Dtrue%29%2C%201x1%20cov%2C%20nn.SmoothL1Loss%28beta%3D1.0%29%2C%20global%20normalization/runs/0cz23zfl</a>

# %%
train_with_early_stopping(
    model = model,
    train_loader = train_loader,
    val_loader = val_loader,
    optimizer = optimizer,
    scheduler = scheduler,            # ReduceLROnPlateau expected
    criterion = criterion,
    device = device,
    epochs  = epochs,
    warmup_epochs = warmup_epochs,
    patience = patience,
    save_path="best_hyperspectral_model.pth",
    max_grad_norm=1.0,
    wandb_run=wandb.run
)

# ----- Finish wandb -----
wandb.finish()
# Out:
# /tmp/ipykernel_957/3985730387.py:26: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp) # Re-introduced GradScaler initialization
# Epoch 1/80:   0%|          | 0/17 [00:00<?, ?it/s]/tmp/ipykernel_957/3985730387.py:47: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp): # Re-introduced torch.cuda.amp.autocast context
# /tmp/ipykernel_957/3985730387.py:100: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp): # Re-introduced torch.cuda.amp.autocast context
# Epoch 1/80 - Train Loss: 0.3945 - Val Loss: 0.4375 - backbone LR: 0.000001 - head LR: 0.000001
# Saved best model (val_loss=0.4375)
# Epoch 2/80 - Train Loss: 0.3913 - Val Loss: 0.4366 - backbone LR: 0.000001 - head LR: 0.000003
# Saved best model (val_loss=0.4366)
# Epoch 3/80 - Train Loss: 0.3850 - Val Loss: 0.4349 - backbone LR: 0.000002 - head LR: 0.000004
# Saved best model (val_loss=0.4349)
# Epoch 4/80 - Train Loss: 0.3787 - Val Loss: 0.4330 - backbone LR: 0.000003 - head LR: 0.000005
# Saved best model (val_loss=0.4330)
# Epoch 5/80 - Train Loss: 0.3735 - Val Loss: 0.4312 - backbone LR: 0.000003 - head LR: 0.000006
# Saved best model (val_loss=0.4312)
# Epoch 6/80 - Train Loss: 0.3715 - Val Loss: 0.4295 - backbone LR: 0.000004 - head LR: 0.000008
# Saved best model (val_loss=0.4295)
# Epoch 7/80 - Train Loss: 0.3659 - Val Loss: 0.4281 - backbone LR: 0.000004 - head LR: 0.000009
# Saved best model (val_loss=0.4281)
# Epoch 8/80 - Train Loss: 0.3637 - Val Loss: 0.4269 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4269)
# Epoch 9/80 - Train Loss: 0.3619 - Val Loss: 0.4262 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4262)
# Epoch 10/80 - Train Loss: 0.3619 - Val Loss: 0.4255 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4255)
# Epoch 11/80 - Train Loss: 0.3581 - Val Loss: 0.4251 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4251)
# Epoch 12/80 - Train Loss: 0.3575 - Val Loss: 0.4246 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4246)
# Epoch 13/80 - Train Loss: 0.3555 - Val Loss: 0.4240 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4240)
# Epoch 14/80 - Train Loss: 0.3544 - Val Loss: 0.4227 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4227)
# Epoch 15/80 - Train Loss: 0.3522 - Val Loss: 0.4225 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4225)
# Epoch 16/80 - Train Loss: 0.3504 - Val Loss: 0.4221 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4221)
# Epoch 17/80 - Train Loss: 0.3483 - Val Loss: 0.4216 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4216)
# Epoch 18/80 - Train Loss: 0.3463 - Val Loss: 0.4220 - backbone LR: 0.000005 - head LR: 0.000010
# Epoch 19/80 - Train Loss: 0.3461 - Val Loss: 0.4215 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4215)
# Epoch 20/80 - Train Loss: 0.3454 - Val Loss: 0.4209 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4209)
# Epoch 21/80 - Train Loss: 0.3434 - Val Loss: 0.4207 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4207)
# Epoch 22/80 - Train Loss: 0.3404 - Val Loss: 0.4198 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4198)
# Epoch 23/80 - Train Loss: 0.3418 - Val Loss: 0.4201 - backbone LR: 0.000005 - head LR: 0.000010
# Epoch 24/80 - Train Loss: 0.3416 - Val Loss: 0.4194 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4194)
# Epoch 25/80 - Train Loss: 0.3383 - Val Loss: 0.4186 - backbone LR: 0.000005 - head LR: 0.000010
# Saved best model (val_loss=0.4186)
# Epoch 26/80 - Train Loss: 0.3358 - Val Loss: 0.4189 - backbone LR: 0.000005 - head LR: 0.000010
# Epoch 27/80 - Train Loss: 0.3331 - Val Loss: 0.4188 - backbone LR: 0.000005 - head LR: 0.000010
# Epoch 28/80 - Train Loss: 0.3320 - Val Loss: 0.4202 - backbone LR: 0.000005 - head LR: 0.000010
# Epoch 29/80 - Train Loss: 0.3284 - Val Loss: 0.4193 - backbone LR: 0.000005 - head LR: 0.000010
# Epoch 30/80 - Train Loss: 0.3258 - Val Loss: 0.4190 - backbone LR: 0.000005 - head LR: 0.000010
# Epoch 31/80 - Train Loss: 0.3252 - Val Loss: 0.4195 - backbone LR: 0.000002 - head LR: 0.000003
# Epoch 32/80 - Train Loss: 0.3217 - Val Loss: 0.4197 - backbone LR: 0.000002 - head LR: 0.000003
# Epoch 33/80 - Train Loss: 0.3208 - Val Loss: 0.4197 - backbone LR: 0.000002 - head LR: 0.000003
# Epoch 34/80 - Train Loss: 0.3227 - Val Loss: 0.4196 - backbone LR: 0.000002 - head LR: 0.000003
# Epoch 35/80 - Train Loss: 0.3195 - Val Loss: 0.4196 - backbone LR: 0.000002 - head LR: 0.000003
# Early stopping at epoch 35 (no improvement for 10 epochs)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>grad_norm</td><td>▁▂▂█▂▆▃▁▁▄▂▂▂▃▂▂▂▃▂▃▂▃▂▃▁▁▁▃▃▂▁▁▂▁▄</td></tr><tr><td>lr_backbone</td><td>▁▂▃▄▅▆▇███████████████████████▂▂▂▂▂</td></tr><tr><td>lr_head</td><td>▁▂▃▄▅▆▇███████████████████████▂▂▂▂▂</td></tr><tr><td>train_loss</td><td>██▇▇▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁</td></tr><tr><td>val_loss</td><td>██▇▆▆▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>35</td></tr><tr><td>grad_norm</td><td>17855.03711</td></tr><tr><td>lr_backbone</td><td>0.0</td></tr><tr><td>lr_head</td><td>0.0</td></tr><tr><td>note</td><td>This run uses: (1) c...</td></tr><tr><td>train_loss</td><td>0.31954</td></tr><tr><td>val_loss</td><td>0.41956</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">giddy-haze-2</strong> at: <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20convnext_base_in22k%20%28pretrained%3Dtrue%29%2C%201x1%20cov%2C%20nn.SmoothL1Loss%28beta%3D1.0%29%2C%20global%20normalization/runs/0cz23zfl' target="_blank">https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20convnext_base_in22k%20%28pretrained%3Dtrue%29%2C%201x1%20cov%2C%20nn.SmoothL1Loss%28beta%3D1.0%29%2C%20global%20normalization/runs/0cz23zfl</a><br> View project at: <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20convnext_base_in22k%20%28pretrained%3Dtrue%29%2C%201x1%20cov%2C%20nn.SmoothL1Loss%28beta%3D1.0%29%2C%20global%20normalization' target="_blank">https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20convnext_base_in22k%20%28pretrained%3Dtrue%29%2C%201x1%20cov%2C%20nn.SmoothL1Loss%28beta%3D1.0%29%2C%20global%20normalization</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260423_020820-0cz23zfl/logs</code>

# %%
# ----- Load best model -----
checkpoint = torch.load("best_hyperspectral_model.pth")
model.load_state_dict(checkpoint["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## **Evaluate results in comparision to the Baseline Regressor.**

# %%
class BaselineRegressor:
    """
    Baseline regressor, which calculates the mean value of the target from the training
    data and returns it for each testing sample.
    """
    def __init__(self):
        self.mean = 0

    def fit(self, X_train: np.ndarray, y_train: np.ndarray):
        self.mean = np.mean(y_train, axis=0)
        self.classes_count = y_train.shape[1]
        return self

    def predict(self, X_test: np.ndarray):
        return np.full((len(X_test), self.classes_count), self.mean)


class SpectralCurveFiltering():
    """
    Create a histogram (a spectral curve) of a 3D cube, using the merge_function
    to aggregate all pixels within one band. The return array will have
    the shape of [CHANNELS_COUNT]
    """

    def __init__(self, merge_function = np.mean):
        self.merge_function = merge_function

    def __call__(self, sample: np.ndarray):
        return self.merge_function(sample, axis=(1, 2))

# %%
def evaluate_dl_model(model, test_loader, scaler_y, device):
    """Evaluates the deep learning model on the local test dataset."""
    model.eval()
    test_predictions_scaled = []
    y_true_scaled = [] # To collect the true scaled labels from the DataLoader

    with torch.no_grad():
        for X_batch_test, y_batch_true_scaled in test_loader:
            X_batch_test = X_batch_test.to(device)
            preds_batch = model(X_batch_test)
            test_predictions_scaled.append(preds_batch.cpu().numpy())
            y_true_scaled.append(y_batch_true_scaled.cpu().numpy())

    y_test_scaled_pred = np.vstack(test_predictions_scaled)
    y_test_scaled_true = np.vstack(y_true_scaled)

    # Inverse transform predictions and true values
    y_test_pred = scaler_y.inverse_transform(y_test_scaled_pred)
    y_test_true_from_loader = scaler_y.inverse_transform(y_test_scaled_true)

    model_mse_targets = np.mean((y_test_true_from_loader - y_test_pred)**2, axis=0)
    return y_test_pred, y_test_true_from_loader, model_mse_targets

def evaluate_baseline_regressor(baseline_regressor, X_test_filtered, y_test_true):
    """Evaluates the baseline regressor on the test dataset."""
    baseline_preds_test = baseline_regressor.predict(X_test_filtered)
    baseline_mse_targets = np.mean((y_test_true - baseline_preds_test)**2, axis=0)
    return baseline_preds_test, baseline_mse_targets

def calculate_and_print_results(model_mse_targets, baseline_mse_targets, y_test_true, y_test_pred, baseline_preds_test):
    """Calculates and prints the challenge score and per-target comparison, and plots results."""
    challenge_score = np.mean(model_mse_targets / baseline_mse_targets)

    target_names = ["P", "K", "Mg", "pH"]
    print("Per-target comparison (on local test set from training data):")
    for i, name in enumerate(target_names):
        print(f"{name}: Model MSE = {model_mse_targets[i]:.4f}, Baseline MSE = {baseline_mse_targets[i]:.4f}, Normalized = {model_mse_targets[i]/baseline_mse_targets[i]:.4f}")

    print(f"\nChallenge normalized score (lower is better, on local test set): {challenge_score:.4f}")

    # Plotting
    plt.figure(figsize=(15, 5))
    for i, metric in enumerate(target_names):
        plt.subplot(1, 4, i + 1)
        plt.scatter(y_test_true[:, i], y_test_pred[:, i], alpha=0.7, label='DL Model Predictions')
        plt.scatter(y_test_true[:, i], baseline_preds_test[:, i], alpha=0.7, label='Baseline Predictions', marker='x')
        min_val = min(y_test_true[:, i].min(), y_test_pred[:, i].min(), baseline_preds_test[:, i].min())
        max_val = max(y_test_true[:, i].max(), y_test_pred[:, i].max(), baseline_preds_test[:, i].max())
        plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='Ideal Prediction')
        plt.title(f'{metric} Predictions')
        plt.xlabel('True Values')
        plt.ylabel('Predictions')
        plt.grid(True)
        plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Get true y values from the local test dataset (inverse-scaled)
y_test_scaled_true = np.array([test_dataset[i][1].numpy() for i in range(len(test_dataset))])
y_test_true = scaler_y.inverse_transform(y_test_scaled_true)

# %%
# We need the original unscaled, non-PCA data for the baseline regressor
X_test_nonpca = [X_train_full_data[i] for i in test_indices]

# We need to apply SpectralCurveFiltering to the original X_test_nonpca for the baseline regressor
filtering = SpectralCurveFiltering()
X_test_filtered = np.array([filtering(cube[0].cpu().numpy()) for cube in X_test_nonpca]) # Accessing the image tensor from tuple

# Train a new baseline regressor on the combined training and validation splits
# Combine train and validation indices
combined_train_val_indices = train_indices.tolist() + val_indices.tolist() # Convert to list for concatenation

# Get the original unscaled, non-PCA data for the baseline training
X_combined_train_val_nonpca = [X_train_full_data[i] for i in combined_train_val_indices]
y_combined_train_val_nonpca = y_train[combined_train_val_indices] # Use unscaled y_train for baseline training

X_combined_train_val_filtered = np.array([filtering(cube[0].cpu().numpy()) for cube in X_combined_train_val_nonpca]) # Accessing the image tensor from tuple

# %%
baseline_reg_current = BaselineRegressor() # Initialize a new baseline regressor
baseline_reg_current = baseline_reg_current.fit(X_combined_train_val_filtered, y_combined_train_val_nonpca)

baseline_preds_test = baseline_reg_current.predict(X_test_filtered)

# %%
# Load the best model weights
checkpoint = torch.load("best_hyperspectral_model.pth")
model.load_state_dict(checkpoint["model_state_dict"])
model.eval()

# Iterate through the local test loader to get predictions
test_predictions_scaled = []

# # Create a DataLoader for the local test dataset
# local_test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

with torch.no_grad():
    for X_batch_test, _ in test_loader:
        X_batch_test = X_batch_test.to(next(model.parameters()).device)
        preds_batch = model(X_batch_test)
        test_predictions_scaled.append(preds_batch.cpu().numpy())

y_test_scaled_pred = np.vstack(test_predictions_scaled) # predicted in scaled units

# Convert to numpy and inverse scale to original units
y_test_pred = scaler_y.inverse_transform(y_test_scaled_pred)

# %%
# -----------------------------
# Compute MSE per target
# -----------------------------
model_mse_targets = np.mean((y_test_true - y_test_pred)**2, axis=0)
baseline_mse_targets = np.mean((y_test_true - baseline_preds_test)**2, axis=0)

# Compute normalized score (challenge metric)
challenge_score = np.mean(model_mse_targets / baseline_mse_targets)

# -----------------------------
# Print per-target comparison
# -----------------------------
target_names = ["P", "K", "Mg", "pH"]
print("Per-target comparison (on local test set from training data):")
for i, name in enumerate(target_names):
    print(f"{name}: Model MSE = {model_mse_targets[i]:.4f}, Baseline MSE = {baseline_mse_targets[i]:.4f}, Normalized = {model_mse_targets[i]/baseline_mse_targets[i]:.4f}")

print(f"\nChallenge normalized score (lower is better, on local test set): {challenge_score:.4f}")
# Out:
# Per-target comparison (on local test set from training data):
# P: Model MSE = 961.5493, Baseline MSE = 956.1005, Normalized = 1.0057
# K: Model MSE = 3242.3088, Baseline MSE = 3448.3214, Normalized = 0.9403
# Mg: Model MSE = 1424.8456, Baseline MSE = 1448.3911, Normalized = 0.9837
# pH: Model MSE = 0.0608, Baseline MSE = 0.0677, Normalized = 0.8980
#
# Challenge normalized score (lower is better, on local test set): 0.9569

# %%
# Load the best model weights for the deep learning model
#model.load_state_dict(torch.load("best_hyperspectral_model.pth"))

# Evaluate the deep learning model
dl_y_test_pred, dl_y_test_true, dl_model_mse_targets = evaluate_dl_model(model, test_loader, scaler_y, device)

# Evaluate the baseline regressor (using the globally available y_test_true from inverse scaling test_dataset labels)
baseline_y_test_pred, baseline_mse_targets = evaluate_baseline_regressor(baseline_reg_current, X_test_filtered, y_test_true)

# Calculate and print combined results, including plotting
calculate_and_print_results(dl_model_mse_targets, baseline_mse_targets, y_test_true, dl_y_test_pred, baseline_y_test_pred)
# Out:
# Per-target comparison (on local test set from training data):
# P: Model MSE = 961.5493, Baseline MSE = 956.1005, Normalized = 1.0057
# K: Model MSE = 3242.3088, Baseline MSE = 3448.3214, Normalized = 0.9403
# Mg: Model MSE = 1424.8456, Baseline MSE = 1448.3911, Normalized = 0.9837
# pH: Model MSE = 0.0608, Baseline MSE = 0.0677, Normalized = 0.8980
#
# Challenge normalized score (lower is better, on local test set): 0.9569

# %%
def display_predictions_table(model, test_loader, scaler_y, device):
    """Displays the model's predictions against ground truth values in a tabular form (unscaled)."""
    model.eval()  # Set the model to evaluation mode
    all_predictions_scaled = []
    all_true_values_scaled = []

    with torch.no_grad():
        for X_batch, y_batch_true_scaled in test_loader:
            X_batch = X_batch.to(device)
            preds_batch = model(X_batch)
            all_predictions_scaled.append(preds_batch.cpu().numpy())
            all_true_values_scaled.append(y_batch_true_scaled.cpu().numpy())

    # Concatenate all batches
    y_predictions_scaled = np.vstack(all_predictions_scaled)
    y_true_scaled = np.vstack(all_true_values_scaled)

    # Inverse transform to get original values
    y_predictions_unscaled = scaler_y.inverse_transform(y_predictions_scaled)
    y_true_unscaled = scaler_y.inverse_transform(y_true_scaled)

    # Create a DataFrame for display
    target_names = ["P", "K", "Mg", "pH"]

    # To ensure consistent number of samples, we'll just take a few examples from the test set
    num_samples_to_display = min(10, len(y_predictions_unscaled))

    # Correctly build the dictionary for DataFrame
    data_for_df = {}
    for i, name in enumerate(target_names):
        data_for_df[f'True {name}'] = y_true_unscaled[:num_samples_to_display, i]
        data_for_df[f'Pred {name}'] = y_predictions_unscaled[:num_samples_to_display, i]

    df_display = pd.DataFrame(data_for_df)

    print(f"\nSample of {num_samples_to_display} Predictions vs. True Values (Unscaled):")
    display(df_display)

# Example usage of the function:
display_predictions_table(model, test_loader, scaler_y, device)
# Out:
# Sample of 10 Predictions vs. True Values (Unscaled):
#        True P     Pred P  True K      Pred K     True Mg     Pred Mg  True pH  \
# 0   64.599998  67.982132   243.0  233.455597  184.000000  152.802826     6.50
# 1   36.099998  67.960861   193.0  223.414108   77.200005  157.848618     5.73
# 2   56.400002  66.243362   213.0  209.766953  154.000000  169.826141     6.70
# 3   46.500000  65.504700   146.0  209.786774  116.000000  150.458572     6.90
# 4   57.599998  65.006332   234.0  234.840286  167.000000  169.029831     6.40
# 5   68.400002  67.094131   230.0  232.114258  220.000000  158.826141     6.80
# 6   35.500000  64.607414   132.0  209.716187  120.000000  151.153870     6.80
# 7   96.199997  64.463448   226.0  217.881088  140.000000  161.048325     6.80
# 8   45.400002  70.396194   209.0  224.207108  143.000000  159.079590     6.80
# 9  123.000000  75.166504   363.0  239.595886  195.000000  155.299789     6.96
#
#     Pred pH
# 0  6.708163
# 1  6.806095
# 2  6.689506
# 3  6.712736
# 4  6.614975
# 5  6.825886
# 6  6.707272
# 7  6.711034
# 8  6.752722
# 9  6.808602

# %%
import matplotlib.pyplot as plt
import numpy as np

target_names = ["P", "K", "Mg", "pH"]

# Get the MSEs from the kernel state
# Assuming model_mse_targets and baseline_mse_targets are available from previous execution
model_mse_targets = np.array(model_mse_targets) # Ensure it's a numpy array for indexing
baseline_mse_targets = np.array(baseline_mse_targets) # Ensure it's a numpy array for indexing

x = np.arange(len(target_names))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, model_mse_targets, width, label='Model MSE')
rects2 = ax.bar(x + width/2, baseline_mse_targets, width, label='Baseline MSE')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Target')
ax.set_ylabel('Mean Squared Error (MSE)')
ax.set_title('Model vs. Baseline MSE for Individual Targets')
ax.set_xticks(x)
ax.set_xticklabels(target_names)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Generate submission file

# %%
import gc

del train_dataset
del val_dataset
del test_dataset
del train_loader
del val_loader
del test_loader

gc.collect()
# Out:
# 13649

# %%
# import torch
# torch.cuda.empty_cache()

# %%
X_test_submission = load_data("/content/test_data/test")

# %%
test_dataset_submission  = NPZDataset(X_test_submission, augment=False, global_means=global_means, global_stds=global_stds)
test_submission_loader  = DataLoader(test_dataset_submission, batch_size=64, shuffle=False, num_workers=2, pin_memory=True)

# %%
model.eval() # Set the model to evaluation mode

submission_predictions_scaled = []

with torch.no_grad():
    for X_batch_submission in test_submission_loader:
        # X_batch_submission contains only features, no labels for submission dataset
        X_batch_submission = X_batch_submission.to(next(model.parameters()).device)
        preds_batch = model(X_batch_submission)
        submission_predictions_scaled.append(preds_batch.cpu().numpy())

y_submission_scaled_pred = np.vstack(submission_predictions_scaled)

# Inverse transform predictions to get original values
y_submission_pred = scaler_y.inverse_transform(y_submission_scaled_pred)

# Create submission DataFrame
submission = pd.DataFrame(data=y_submission_pred, columns=["P", "K", "Mg", "pH"])

# Save to CSV
submission.to_csv("submission.csv", index_label="sample_index")
print("Submission file 'submission.csv' created successfully!")
# Out:
# Submission file 'submission.csv' created successfully!
