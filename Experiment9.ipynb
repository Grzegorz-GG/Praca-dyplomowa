# %% [markdown]
# <a href="https://colab.research.google.com/github/Grzegorz-GG/DissertationPW/blob/main/Experiment9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import wandb
import joblib
import torchvision.transforms as transforms
from torchvision.transforms import v2

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import timm
import matplotlib.pyplot as plt

from torch.optim.lr_scheduler import ReduceLROnPlateau
from tqdm import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
gt_path = 'train_gt.csv'
wavelength_path = 'wavelengths.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

output_dir = '/content/test_data'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# !tar -xzvf /content/drive/MyDrive/test.tar.gz -C {output_dir}
# Out:
# test/
# test/77.npz
# test/837.npz
# test/189.npz
# test/63.npz
# test/823.npz
# test/638.npz
# test/610.npz
# test/88.npz
# test/176.npz
# test/162.npz
# test/604.npz
# test/1145.npz
# test/1151.npz
# test/348.npz
# test/374.npz
# test/412.npz
# test/406.npz
# test/360.npz
# test/599.npz
# test/1019.npz
# test/1031.npz
# test/1025.npz
# test/228.npz
# test/200.npz
# test/566.npz
# test/572.npz
# test/214.npz
# test/943.npz
# test/957.npz
# test/758.npz
# test/980.npz
# test/994.npz
# test/764.npz
# test/770.npz
# test/771.npz
# test/765.npz
# test/995.npz
# test/981.npz
# test/759.npz
# test/956.npz
# test/942.npz
# test/573.npz
# test/215.npz
# test/201.npz
# test/567.npz
# test/229.npz
# test/1024.npz
# test/1030.npz
# test/1018.npz
# test/598.npz
# test/407.npz
# test/361.npz
# test/375.npz
# test/413.npz
# test/349.npz
# test/1150.npz
# test/1144.npz
# test/163.npz
# test/605.npz
# test/89.npz
# test/611.npz
# test/177.npz
# test/639.npz
# test/822.npz
# test/62.npz
# test/836.npz
# test/76.npz
# test/188.npz
# test/60.npz
# test/820.npz
# test/74.npz
# test/834.npz
# test/48.npz
# test/808.npz
# test/149.npz
# test/607.npz
# test/161.npz
# test/175.npz
# test/613.npz
# test/388.npz
# test/1152.npz
# test/1146.npz
# test/439.npz
# test/363.npz
# test/405.npz
# test/411.npz
# test/377.npz
# test/1026.npz
# test/1032.npz
# test/559.npz
# test/217.npz
# test/571.npz
# test/565.npz
# test/203.npz
# test/954.npz
# test/940.npz
# test/798.npz
# test/968.npz
# test/997.npz
# test/983.npz
# test/773.npz
# test/767.npz
# test/766.npz
# test/772.npz
# test/982.npz
# test/996.npz
# test/969.npz
# test/799.npz
# test/941.npz
# test/955.npz
# test/564.npz
# test/202.npz
# test/216.npz
# test/570.npz
# test/558.npz
# test/1033.npz
# test/1027.npz
# test/410.npz
# test/376.npz
# test/362.npz
# test/404.npz
# test/438.npz
# test/1147.npz
# test/1153.npz
# test/389.npz
# test/174.npz
# test/612.npz
# test/606.npz
# test/160.npz
# test/148.npz
# test/809.npz
# test/49.npz
# test/835.npz
# test/75.npz
# test/821.npz
# test/61.npz
# test/59.npz
# test/819.npz
# test/65.npz
# test/825.npz
# test/71.npz
# test/831.npz
# test/164.npz
# test/602.npz
# test/616.npz
# test/170.npz
# test/158.npz
# test/1143.npz
# test/399.npz
# test/400.npz
# test/366.npz
# test/372.npz
# test/414.npz
# test/428.npz
# test/1023.npz
# test/1037.npz
# test/574.npz
# test/212.npz
# test/206.npz
# test/560.npz
# test/548.npz
# test/979.npz
# test/951.npz
# test/789.npz
# test/945.npz
# test/776.npz
# test/762.npz
# test/992.npz
# test/986.npz
# test/987.npz
# test/993.npz
# test/763.npz
# test/777.npz
# test/944.npz
# test/788.npz
# test/950.npz
# test/978.npz
# test/549.npz
# test/207.npz
# test/561.npz
# test/575.npz
# test/213.npz
# test/1036.npz
# test/1022.npz
# test/429.npz
# test/373.npz
# test/415.npz
# test/401.npz
# test/367.npz
# test/398.npz
# test/1142.npz
# test/159.npz
# test/617.npz
# test/171.npz
# test/165.npz
# test/603.npz
# test/830.npz
# test/70.npz
# test/824.npz
# test/64.npz
# test/818.npz
# test/58.npz
# test/8.npz
# test/72.npz
# test/832.npz
# test/66.npz
# test/826.npz
# test/198.npz
# test/173.npz
# test/615.npz
# test/99.npz
# test/601.npz
# test/167.npz
# test/629.npz
# test/1140.npz
# test/417.npz
# test/371.npz
# test/365.npz
# test/403.npz
# test/359.npz
# test/1034.npz
# test/1020.npz
# test/1008.npz
# test/588.npz
# test/563.npz
# test/205.npz
# test/211.npz
# test/577.npz
# test/239.npz
# test/946.npz
# test/952.npz
# test/761.npz
# test/775.npz
# test/985.npz
# test/749.npz
# test/991.npz
# test/990.npz
# test/748.npz
# test/984.npz
# test/774.npz
# test/760.npz
# test/953.npz
# test/947.npz
# test/238.npz
# test/210.npz
# test/576.npz
# test/562.npz
# test/204.npz
# test/589.npz
# test/1009.npz
# test/1021.npz
# test/1035.npz
# test/358.npz
# test/364.npz
# test/402.npz
# test/416.npz
# test/370.npz
# test/1141.npz
# test/628.npz
# test/600.npz
# test/98.npz
# test/166.npz
# test/172.npz
# test/614.npz
# test/827.npz
# test/67.npz
# test/199.npz
# test/833.npz
# test/73.npz
# test/9.npz
# test/14.npz
# test/854.npz
# test/698.npz
# test/840.npz
# test/28.npz
# test/868.npz
# test/129.npz
# test/897.npz
# test/883.npz
# test/115.npz
# test/673.npz
# test/667.npz
# test/101.npz
# test/1126.npz
# test/1132.npz
# test/459.npz
# test/471.npz
# test/317.npz
# test/303.npz
# test/465.npz
# test/288.npz
# test/1052.npz
# test/1046.npz
# test/539.npz
# test/1091.npz
# test/505.npz
# test/263.npz
# test/277.npz
# test/511.npz
# test/1085.npz
# test/920.npz
# test/934.npz
# test/908.npz
# test/707.npz
# test/713.npz
# test/712.npz
# test/706.npz
# test/909.npz
# test/935.npz
# test/921.npz
# test/276.npz
# test/1084.npz
# test/510.npz
# test/504.npz
# test/1090.npz
# test/262.npz
# test/538.npz
# test/1047.npz
# test/1053.npz
# test/289.npz
# test/302.npz
# test/464.npz
# test/470.npz
# test/316.npz
# test/458.npz
# test/1133.npz
# test/1127.npz
# test/666.npz
# test/100.npz
# test/114.npz
# test/672.npz
# test/882.npz
# test/128.npz
# test/896.npz
# test/869.npz
# test/29.npz
# test/841.npz
# test/699.npz
# test/855.npz
# test/15.npz
# test/843.npz
# test/17.npz
# test/857.npz
# test/880.npz
# test/658.npz
# test/894.npz
# test/102.npz
# test/664.npz
# test/670.npz
# test/116.npz
# test/499.npz
# test/1119.npz
# test/1131.npz
# test/1125.npz
# test/328.npz
# test/466.npz
# test/300.npz
# test/314.npz
# test/472.npz
# test/1079.npz
# test/1045.npz
# test/1051.npz
# test/248.npz
# test/512.npz
# test/1086.npz
# test/274.npz
# test/260.npz
# test/1092.npz
# test/506.npz
# test/937.npz
# test/923.npz
# test/738.npz
# test/710.npz
# test/704.npz
# test/705.npz
# test/711.npz
# test/739.npz
# test/922.npz
# test/936.npz
# test/261.npz
# test/507.npz
# test/1093.npz
# test/1087.npz
# test/513.npz
# test/275.npz
# test/249.npz
# test/1050.npz
# test/1044.npz
# test/1078.npz
# test/315.npz
# test/473.npz
# test/467.npz
# test/301.npz
# test/329.npz
# test/1124.npz
# test/1130.npz
# test/1118.npz
# test/498.npz
# test/671.npz
# test/117.npz
# test/103.npz
# test/665.npz
# test/895.npz
# test/659.npz
# test/881.npz
# test/856.npz
# test/16.npz
# test/842.npz
# test/846.npz
# test/12.npz
# test/852.npz
# test/661.npz
# test/107.npz
# test/113.npz
# test/675.npz
# test/885.npz
# test/891.npz
# test/649.npz
# test/1134.npz
# test/1120.npz
# test/1108.npz
# test/488.npz
# test/305.npz
# test/463.npz
# test/477.npz
# test/311.npz
# test/339.npz
# test/1040.npz
# test/1054.npz
# test/1068.npz
# test/271.npz
# test/517.npz
# test/1083.npz
# test/1097.npz
# test/503.npz
# test/265.npz
# test/259.npz
# test/932.npz
# test/926.npz
# test/715.npz
# test/701.npz
# test/729.npz
# test/728.npz
# test/700.npz
# test/714.npz
# test/927.npz
# test/933.npz
# test/258.npz
# test/502.npz
# test/1096.npz
# test/264.npz
# test/270.npz
# test/1082.npz
# test/516.npz
# test/1069.npz
# test/1055.npz
# test/1041.npz
# test/338.npz
# test/476.npz
# test/310.npz
# test/304.npz
# test/462.npz
# test/489.npz
# test/1109.npz
# test/1121.npz
# test/1135.npz
# test/648.npz
# test/890.npz
# test/884.npz
# test/112.npz
# test/674.npz
# test/660.npz
# test/106.npz
# test/853.npz
# test/13.npz
# test/847.npz
# test/39.npz
# test/879.npz
# test/11.npz
# test/689.npz
# test/851.npz
# test/845.npz
# test/676.npz
# test/110.npz
# test/104.npz
# test/662.npz
# test/892.npz
# test/138.npz
# test/886.npz
# test/1123.npz
# test/1137.npz
# test/312.npz
# test/474.npz
# test/460.npz
# test/306.npz
# test/448.npz
# test/1057.npz
# test/1043.npz
# test/299.npz
# test/266.npz
# test/1094.npz
# test/500.npz
# test/514.npz
# test/1080.npz
# test/272.npz
# test/528.npz
# test/919.npz
# test/925.npz
# test/931.npz
# test/702.npz
# test/716.npz
# test/717.npz
# test/703.npz
# test/930.npz
# test/924.npz
# test/918.npz
# test/529.npz
# test/1081.npz
# test/515.npz
# test/273.npz
# test/267.npz
# test/501.npz
# test/1095.npz
# test/298.npz
# test/1042.npz
# test/1056.npz
# test/449.npz
# test/461.npz
# test/307.npz
# test/313.npz
# test/475.npz
# test/1136.npz
# test/1122.npz
# test/139.npz
# test/887.npz
# test/893.npz
# test/105.npz
# test/663.npz
# test/677.npz
# test/111.npz
# test/844.npz
# test/850.npz
# test/688.npz
# test/10.npz
# test/878.npz
# test/38.npz
# test/35.npz
# test/875.npz
# test/21.npz
# test/861.npz
# test/691.npz
# test/849.npz
# test/685.npz
# test/108.npz
# test/134.npz
# test/652.npz
# test/646.npz
# test/120.npz
# test/493.npz
# test/1107.npz
# test/1113.npz
# test/487.npz
# test/478.npz
# test/450.npz
# test/336.npz
# test/322.npz
# test/444.npz
# test/1073.npz
# test/281.npz
# test/295.npz
# test/1067.npz
# test/518.npz
# test/1098.npz
# test/524.npz
# test/242.npz
# test/256.npz
# test/530.npz
# test/901.npz
# test/915.npz
# test/929.npz
# test/726.npz
# test/732.npz
# test/733.npz
# test/727.npz
# test/928.npz
# test/914.npz
# test/900.npz
# test/257.npz
# test/531.npz
# test/525.npz
# test/243.npz
# test/1099.npz
# test/519.npz
# test/294.npz
# test/1066.npz
# test/1072.npz
# test/280.npz
# test/323.npz
# test/445.npz
# test/451.npz
# test/337.npz
# test/479.npz
# test/486.npz
# test/1112.npz
# test/1106.npz
# test/492.npz
# test/647.npz
# test/121.npz
# test/135.npz
# test/653.npz
# test/109.npz
# test/684.npz
# test/848.npz
# test/690.npz
# test/860.npz
# test/20.npz
# test/874.npz
# test/34.npz
# test/22.npz
# test/862.npz
# test/36.npz
# test/876.npz
# test/686.npz
# test/692.npz
# test/679.npz
# test/123.npz
# test/645.npz
# test/889.npz
# test/651.npz
# test/137.npz
# test/1138.npz
# test/1110.npz
# test/484.npz
# test/490.npz
# test/1104.npz
# test/309.npz
# test/447.npz
# test/321.npz
# test/335.npz
# test/453.npz
# test/1058.npz
# test/1064.npz
# test/296.npz
# test/282.npz
# test/1070.npz
# test/269.npz
# test/533.npz
# test/255.npz
# test/241.npz
# test/527.npz
# test/916.npz
# test/902.npz
# test/719.npz
# test/731.npz
# test/725.npz
# test/724.npz
# test/730.npz
# test/718.npz
# test/903.npz
# test/917.npz
# test/240.npz
# test/526.npz
# test/532.npz
# test/254.npz
# test/268.npz
# test/283.npz
# test/1071.npz
# test/1065.npz
# test/297.npz
# test/1059.npz
# test/334.npz
# test/452.npz
# test/446.npz
# test/320.npz
# test/308.npz
# test/1105.npz
# test/491.npz
# test/485.npz
# test/1111.npz
# test/1139.npz
# test/650.npz
# test/888.npz
# test/136.npz
# test/122.npz
# test/644.npz
# test/678.npz
# test/693.npz
# test/687.npz
# test/877.npz
# test/37.npz
# test/863.npz
# test/23.npz
# test/683.npz
# test/697.npz
# test/27.npz
# test/867.npz
# test/33.npz
# test/873.npz
# test/898.npz
# test/640.npz
# test/126.npz
# test/132.npz
# test/654.npz
# test/668.npz
# test/1115.npz
# test/481.npz
# test/495.npz
# test/1101.npz
# test/1129.npz
# test/324.npz
# test/442.npz
# test/456.npz
# test/330.npz
# test/318.npz
# test/293.npz
# test/1061.npz
# test/1075.npz
# test/287.npz
# test/1049.npz
# test/250.npz
# test/536.npz
# test/522.npz
# test/244.npz
# test/278.npz
# test/913.npz
# test/907.npz
# test/734.npz
# test/720.npz
# test/708.npz
# test/709.npz
# test/721.npz
# test/735.npz
# test/906.npz
# test/912.npz
# test/279.npz
# test/523.npz
# test/245.npz
# test/251.npz
# test/537.npz
# test/1048.npz
# test/1074.npz
# test/286.npz
# test/292.npz
# test/1060.npz
# test/319.npz
# test/457.npz
# test/331.npz
# test/325.npz
# test/443.npz
# test/1128.npz
# test/1100.npz
# test/494.npz
# test/480.npz
# test/1114.npz
# test/669.npz
# test/133.npz
# test/655.npz
# test/641.npz
# test/899.npz
# test/127.npz
# test/872.npz
# test/32.npz
# test/866.npz
# test/26.npz
# test/696.npz
# test/682.npz
# test/694.npz
# test/18.npz
# test/680.npz
# test/858.npz
# test/30.npz
# test/870.npz
# test/24.npz
# test/864.npz
# test/657.npz
# test/131.npz
# test/125.npz
# test/643.npz
# test/119.npz
# test/496.npz
# test/1102.npz
# test/1116.npz
# test/482.npz
# test/333.npz
# test/455.npz
# test/441.npz
# test/327.npz
# test/469.npz
# test/284.npz
# test/1076.npz
# test/1062.npz
# test/290.npz
# test/247.npz
# test/521.npz
# test/535.npz
# test/253.npz
# test/1089.npz
# test/509.npz
# test/938.npz
# test/904.npz
# test/910.npz
# test/723.npz
# test/737.npz
# test/736.npz
# test/722.npz
# test/911.npz
# test/905.npz
# test/939.npz
# test/508.npz
# test/1088.npz
# test/534.npz
# test/252.npz
# test/246.npz
# test/520.npz
# test/1063.npz
# test/291.npz
# test/285.npz
# test/1077.npz
# test/468.npz
# test/440.npz
# test/326.npz
# test/332.npz
# test/454.npz
# test/483.npz
# test/1117.npz
# test/1103.npz
# test/497.npz
# test/118.npz
# test/124.npz
# test/642.npz
# test/656.npz
# test/130.npz
# test/865.npz
# test/25.npz
# test/871.npz
# test/31.npz
# test/859.npz
# test/681.npz
# test/19.npz
# test/695.npz
# test/56.npz
# test/816.npz
# test/4.npz
# test/42.npz
# test/802.npz
# test/194.npz
# test/180.npz
# test/95.npz
# test/619.npz
# test/81.npz
# test/631.npz
# test/157.npz
# test/143.npz
# test/625.npz
# test/396.npz
# test/382.npz
# test/369.npz
# test/355.npz
# test/433.npz
# test/427.npz
# test/341.npz
# test/1038.npz
# test/584.npz
# test/1010.npz
# test/1004.npz
# test/590.npz
# test/209.npz
# test/221.npz
# test/547.npz
# test/553.npz
# test/235.npz
# test/962.npz
# test/976.npz
# test/786.npz
# test/792.npz
# test/779.npz
# test/745.npz
# test/751.npz
# test/989.npz
# test/988.npz
# test/750.npz
# test/744.npz
# test/778.npz
# test/793.npz
# test/787.npz
# test/977.npz
# test/963.npz
# test/552.npz
# test/234.npz
# test/220.npz
# test/546.npz
# test/208.npz
# test/591.npz
# test/1005.npz
# test/1011.npz
# test/585.npz
# test/1039.npz
# test/426.npz
# test/340.npz
# test/354.npz
# test/432.npz
# test/368.npz
# test/383.npz
# test/397.npz
# test/142.npz
# test/624.npz
# test/630.npz
# test/156.npz
# test/80.npz
# test/618.npz
# test/94.npz
# test/181.npz
# test/195.npz
# test/803.npz
# test/43.npz
# test/817.npz
# test/57.npz
# test/5.npz
# test/41.npz
# test/801.npz
# test/7.npz
# test/55.npz
# test/815.npz
# test/183.npz
# test/197.npz
# test/69.npz
# test/829.npz
# test/82.npz
# test/168.npz
# test/96.npz
# test/626.npz
# test/140.npz
# test/154.npz
# test/632.npz
# test/381.npz
# test/395.npz
# test/418.npz
# test/342.npz
# test/424.npz
# test/430.npz
# test/356.npz
# test/1007.npz
# test/593.npz
# test/587.npz
# test/1013.npz
# test/578.npz
# test/236.npz
# test/550.npz
# test/544.npz
# test/222.npz
# test/975.npz
# test/961.npz
# test/949.npz
# test/791.npz
# test/785.npz
# test/752.npz
# test/746.npz
# test/747.npz
# test/753.npz
# test/784.npz
# test/790.npz
# test/948.npz
# test/960.npz
# test/974.npz
# test/545.npz
# test/223.npz
# test/237.npz
# test/551.npz
# test/579.npz
# test/1012.npz
# test/586.npz
# test/592.npz
# test/1006.npz
# test/431.npz
# test/357.npz
# test/343.npz
# test/425.npz
# test/419.npz
# test/394.npz
# test/380.npz
# test/155.npz
# test/633.npz
# test/627.npz
# test/141.npz
# test/169.npz
# test/97.npz
# test/83.npz
# test/196.npz
# test/828.npz
# test/68.npz
# test/182.npz
# test/6.npz
# test/814.npz
# test/54.npz
# test/800.npz
# test/40.npz
# test/186.npz
# test/78.npz
# test/838.npz
# test/192.npz
# test/44.npz
# test/804.npz
# test/50.npz
# test/810.npz
# test/2.npz
# test/145.npz
# test/623.npz
# test/637.npz
# test/151.npz
# test/179.npz
# test/87.npz
# test/93.npz
# test/384.npz
# test/390.npz
# test/421.npz
# test/347.npz
# test/353.npz
# test/435.npz
# test/409.npz
# test/1002.npz
# test/596.npz
# test/582.npz
# test/1016.npz
# test/555.npz
# test/233.npz
# test/227.npz
# test/541.npz
# test/569.npz
# test/794.npz
# test/958.npz
# test/780.npz
# test/970.npz
# test/964.npz
# test/757.npz
# test/743.npz
# test/742.npz
# test/756.npz
# test/965.npz
# test/971.npz
# test/781.npz
# test/959.npz
# test/795.npz
# test/568.npz
# test/226.npz
# test/540.npz
# test/554.npz
# test/232.npz
# test/1017.npz
# test/583.npz
# test/597.npz
# test/1003.npz
# test/408.npz
# test/352.npz
# test/434.npz
# test/420.npz
# test/346.npz
# test/391.npz
# test/385.npz
# test/92.npz
# test/178.npz
# test/86.npz
# test/636.npz
# test/150.npz
# test/144.npz
# test/622.npz
# test/811.npz
# test/51.npz
# test/3.npz
# test/805.npz
# test/45.npz
# test/193.npz
# test/187.npz
# test/839.npz
# test/79.npz
# test/191.npz
# test/185.npz
# test/1.npz
# test/53.npz
# test/813.npz
# test/47.npz
# test/807.npz
# test/152.npz
# test/634.npz
# test/620.npz
# test/146.npz
# test/90.npz
# test/608.npz
# test/84.npz
# test/393.npz
# test/387.npz
# test/1149.npz
# test/436.npz
# test/350.npz
# test/344.npz
# test/422.npz
# test/378.npz
# test/581.npz
# test/1015.npz
# test/1001.npz
# test/595.npz
# test/1029.npz
# test/542.npz
# test/224.npz
# test/230.npz
# test/556.npz
# test/218.npz
# test/783.npz
# test/797.npz
# test/967.npz
# test/973.npz
# test/740.npz
# test/998.npz
# test/754.npz
# test/768.npz
# test/769.npz
# test/755.npz
# test/999.npz
# test/741.npz
# test/972.npz
# test/966.npz
# test/796.npz
# test/782.npz
# test/219.npz
# test/231.npz
# test/557.npz
# test/543.npz
# test/225.npz
# test/1028.npz
# test/594.npz
# test/1000.npz
# test/1014.npz
# test/580.npz
# test/379.npz
# test/345.npz
# test/423.npz
# test/437.npz
# test/351.npz
# test/1148.npz
# test/386.npz
# test/392.npz
# test/85.npz
# test/609.npz
# test/91.npz
# test/621.npz
# test/147.npz
# test/153.npz
# test/635.npz
# test/806.npz
# test/46.npz
# test/0.npz
# test/812.npz
# test/52.npz
# test/184.npz
# test/190.npz

# %%
import os

output_dir = '/content/train_data'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# !tar -xzvf /content/drive/MyDrive/train.tar.gz -C {output_dir}
# Out:
# train/
# train/77.npz
# train/837.npz
# train/189.npz
# train/1409.npz
# train/63.npz
# train/823.npz
# train/1347.npz
# train/1421.npz
# train/1435.npz
# train/1353.npz
# train/638.npz
# train/610.npz
# train/1384.npz
# train/88.npz
# train/176.npz
# train/162.npz
# train/1390.npz
# train/604.npz
# train/1179.npz
# train/1623.npz
# train/1145.npz
# train/1151.npz
# train/1637.npz
# train/348.npz
# train/374.npz
# train/1186.npz
# train/412.npz
# train/406.npz
# train/1192.npz
# train/360.npz
# train/599.npz
# train/1019.npz
# train/1031.npz
# train/1025.npz
# train/228.npz
# train/200.npz
# train/566.npz
# train/572.npz
# train/214.npz
# train/943.npz
# train/1569.npz
# train/957.npz
# train/1233.npz
# train/1555.npz
# train/1541.npz
# train/1227.npz
# train/758.npz
# train/980.npz
# train/994.npz
# train/764.npz
# train/1596.npz
# train/1582.npz
# train/770.npz
# train/1583.npz
# train/771.npz
# train/765.npz
# train/1597.npz
# train/995.npz
# train/981.npz
# train/759.npz
# train/1540.npz
# train/1226.npz
# train/1232.npz
# train/1554.npz
# train/956.npz
# train/942.npz
# train/1568.npz
# train/573.npz
# train/215.npz
# train/201.npz
# train/567.npz
# train/229.npz
# train/1024.npz
# train/1030.npz
# train/1018.npz
# train/598.npz
# train/1193.npz
# train/407.npz
# train/361.npz
# train/375.npz
# train/413.npz
# train/1187.npz
# train/349.npz
# train/1150.npz
# train/1636.npz
# train/1622.npz
# train/1144.npz
# train/1178.npz
# train/163.npz
# train/605.npz
# train/1391.npz
# train/89.npz
# train/1385.npz
# train/611.npz
# train/177.npz
# train/639.npz
# train/1434.npz
# train/1352.npz
# train/1346.npz
# train/1420.npz
# train/1408.npz
# train/822.npz
# train/62.npz
# train/836.npz
# train/76.npz
# train/188.npz
# train/60.npz
# train/820.npz
# train/1378.npz
# train/74.npz
# train/834.npz
# train/1350.npz
# train/1436.npz
# train/1422.npz
# train/1344.npz
# train/48.npz
# train/808.npz
# train/149.npz
# train/1393.npz
# train/607.npz
# train/161.npz
# train/175.npz
# train/613.npz
# train/1387.npz
# train/1608.npz
# train/388.npz
# train/1634.npz
# train/1152.npz
# train/1146.npz
# train/1620.npz
# train/439.npz
# train/363.npz
# train/405.npz
# train/1191.npz
# train/1185.npz
# train/411.npz
# train/377.npz
# train/1026.npz
# train/1032.npz
# train/559.npz
# train/217.npz
# train/571.npz
# train/565.npz
# train/203.npz
# train/954.npz
# train/1218.npz
# train/940.npz
# train/798.npz
# train/968.npz
# train/1224.npz
# train/1542.npz
# train/1556.npz
# train/1230.npz
# train/997.npz
# train/983.npz
# train/773.npz
# train/1581.npz
# train/1595.npz
# train/767.npz
# train/1594.npz
# train/766.npz
# train/772.npz
# train/1580.npz
# train/982.npz
# train/996.npz
# train/1557.npz
# train/1231.npz
# train/1225.npz
# train/969.npz
# train/1543.npz
# train/799.npz
# train/941.npz
# train/1219.npz
# train/955.npz
# train/564.npz
# train/202.npz
# train/216.npz
# train/570.npz
# train/558.npz
# train/1033.npz
# train/1027.npz
# train/410.npz
# train/1184.npz
# train/376.npz
# train/362.npz
# train/1190.npz
# train/404.npz
# train/438.npz
# train/1147.npz
# train/1621.npz
# train/1635.npz
# train/1153.npz
# train/389.npz
# train/1609.npz
# train/174.npz
# train/1386.npz
# train/612.npz
# train/606.npz
# train/1392.npz
# train/160.npz
# train/148.npz
# train/1423.npz
# train/809.npz
# train/49.npz
# train/1345.npz
# train/1351.npz
# train/1437.npz
# train/835.npz
# train/75.npz
# train/1379.npz
# train/821.npz
# train/61.npz
# train/1433.npz
# train/59.npz
# train/1355.npz
# train/819.npz
# train/1341.npz
# train/1427.npz
# train/65.npz
# train/1369.npz
# train/825.npz
# train/71.npz
# train/831.npz
# train/164.npz
# train/1396.npz
# train/602.npz
# train/616.npz
# train/1382.npz
# train/170.npz
# train/158.npz
# train/1157.npz
# train/1631.npz
# train/1625.npz
# train/1143.npz
# train/399.npz
# train/1619.npz
# train/400.npz
# train/1194.npz
# train/366.npz
# train/372.npz
# train/1180.npz
# train/414.npz
# train/428.npz
# train/1023.npz
# train/1037.npz
# train/574.npz
# train/212.npz
# train/206.npz
# train/560.npz
# train/548.npz
# train/1547.npz
# train/1221.npz
# train/979.npz
# train/1235.npz
# train/1553.npz
# train/951.npz
# train/789.npz
# train/945.npz
# train/1209.npz
# train/1584.npz
# train/776.npz
# train/762.npz
# train/1590.npz
# train/992.npz
# train/986.npz
# train/987.npz
# train/993.npz
# train/763.npz
# train/1591.npz
# train/1585.npz
# train/777.npz
# train/1208.npz
# train/944.npz
# train/788.npz
# train/950.npz
# train/1234.npz
# train/978.npz
# train/1552.npz
# train/1546.npz
# train/1220.npz
# train/549.npz
# train/207.npz
# train/561.npz
# train/575.npz
# train/213.npz
# train/1036.npz
# train/1022.npz
# train/429.npz
# train/373.npz
# train/415.npz
# train/1181.npz
# train/1195.npz
# train/401.npz
# train/367.npz
# train/1618.npz
# train/398.npz
# train/1624.npz
# train/1142.npz
# train/1156.npz
# train/1630.npz
# train/159.npz
# train/1383.npz
# train/617.npz
# train/171.npz
# train/165.npz
# train/603.npz
# train/1397.npz
# train/830.npz
# train/70.npz
# train/824.npz
# train/1368.npz
# train/64.npz
# train/1340.npz
# train/1426.npz
# train/1432.npz
# train/818.npz
# train/1354.npz
# train/58.npz
# train/1424.npz
# train/1342.npz
# train/1356.npz
# train/1430.npz
# train/8.npz
# train/1418.npz
# train/72.npz
# train/832.npz
# train/66.npz
# train/826.npz
# train/198.npz
# train/173.npz
# train/615.npz
# train/1381.npz
# train/99.npz
# train/1395.npz
# train/601.npz
# train/167.npz
# train/629.npz
# train/1140.npz
# train/1626.npz
# train/1632.npz
# train/1154.npz
# train/1168.npz
# train/1183.npz
# train/417.npz
# train/371.npz
# train/365.npz
# train/403.npz
# train/1197.npz
# train/359.npz
# train/1034.npz
# train/1020.npz
# train/1008.npz
# train/588.npz
# train/563.npz
# train/205.npz
# train/211.npz
# train/577.npz
# train/239.npz
# train/1550.npz
# train/1236.npz
# train/1222.npz
# train/1544.npz
# train/946.npz
# train/952.npz
# train/1578.npz
# train/1593.npz
# train/761.npz
# train/775.npz
# train/1587.npz
# train/985.npz
# train/749.npz
# train/991.npz
# train/990.npz
# train/748.npz
# train/984.npz
# train/774.npz
# train/1586.npz
# train/1592.npz
# train/760.npz
# train/953.npz
# train/1579.npz
# train/947.npz
# train/1223.npz
# train/1545.npz
# train/1551.npz
# train/1237.npz
# train/238.npz
# train/210.npz
# train/576.npz
# train/562.npz
# train/204.npz
# train/589.npz
# train/1009.npz
# train/1021.npz
# train/1035.npz
# train/358.npz
# train/364.npz
# train/1196.npz
# train/402.npz
# train/416.npz
# train/1182.npz
# train/370.npz
# train/1169.npz
# train/1633.npz
# train/1155.npz
# train/1141.npz
# train/1627.npz
# train/628.npz
# train/600.npz
# train/1394.npz
# train/98.npz
# train/166.npz
# train/172.npz
# train/1380.npz
# train/614.npz
# train/827.npz
# train/67.npz
# train/199.npz
# train/1419.npz
# train/833.npz
# train/73.npz
# train/1357.npz
# train/9.npz
# train/1431.npz
# train/1425.npz
# train/1343.npz
# train/1318.npz
# train/14.npz
# train/854.npz
# train/698.npz
# train/840.npz
# train/1442.npz
# train/1324.npz
# train/28.npz
# train/868.npz
# train/1330.npz
# train/1456.npz
# train/129.npz
# train/897.npz
# train/883.npz
# train/115.npz
# train/1481.npz
# train/673.npz
# train/667.npz
# train/1495.npz
# train/101.npz
# train/1668.npz
# train/1126.npz
# train/1640.npz
# train/1654.npz
# train/1132.npz
# train/459.npz
# train/471.npz
# train/1683.npz
# train/317.npz
# train/303.npz
# train/1697.npz
# train/465.npz
# train/1708.npz
# train/288.npz
# train/1052.npz
# train/1720.npz
# train/1046.npz
# train/539.npz
# train/1091.npz
# train/505.npz
# train/263.npz
# train/277.npz
# train/511.npz
# train/1085.npz
# train/920.npz
# train/934.npz
# train/1278.npz
# train/1536.npz
# train/1250.npz
# train/908.npz
# train/1244.npz
# train/1522.npz
# train/707.npz
# train/1293.npz
# train/1287.npz
# train/713.npz
# train/712.npz
# train/1286.npz
# train/1292.npz
# train/706.npz
# train/1245.npz
# train/909.npz
# train/1523.npz
# train/1537.npz
# train/1251.npz
# train/1279.npz
# train/935.npz
# train/921.npz
# train/276.npz
# train/1084.npz
# train/510.npz
# train/504.npz
# train/1090.npz
# train/262.npz
# train/538.npz
# train/1721.npz
# train/1047.npz
# train/1053.npz
# train/289.npz
# train/1709.npz
# train/1696.npz
# train/302.npz
# train/464.npz
# train/470.npz
# train/316.npz
# train/1682.npz
# train/458.npz
# train/1655.npz
# train/1133.npz
# train/1127.npz
# train/1641.npz
# train/1669.npz
# train/666.npz
# train/100.npz
# train/1494.npz
# train/1480.npz
# train/114.npz
# train/672.npz
# train/882.npz
# train/128.npz
# train/896.npz
# train/1331.npz
# train/1457.npz
# train/1443.npz
# train/869.npz
# train/29.npz
# train/1325.npz
# train/841.npz
# train/699.npz
# train/855.npz
# train/15.npz
# train/1319.npz
# train/1469.npz
# train/843.npz
# train/17.npz
# train/857.npz
# train/1455.npz
# train/1333.npz
# train/1327.npz
# train/1441.npz
# train/880.npz
# train/658.npz
# train/894.npz
# train/1496.npz
# train/102.npz
# train/664.npz
# train/670.npz
# train/116.npz
# train/1482.npz
# train/499.npz
# train/1119.npz
# train/1131.npz
# train/1657.npz
# train/1643.npz
# train/1125.npz
# train/328.npz
# train/466.npz
# train/300.npz
# train/1694.npz
# train/1680.npz
# train/314.npz
# train/472.npz
# train/1079.npz
# train/1045.npz
# train/1723.npz
# train/1051.npz
# train/248.npz
# train/512.npz
# train/1086.npz
# train/274.npz
# train/260.npz
# train/1092.npz
# train/506.npz
# train/937.npz
# train/923.npz
# train/1509.npz
# train/1521.npz
# train/1247.npz
# train/1253.npz
# train/1535.npz
# train/738.npz
# train/1284.npz
# train/710.npz
# train/704.npz
# train/1290.npz
# train/1291.npz
# train/705.npz
# train/711.npz
# train/1285.npz
# train/739.npz
# train/1252.npz
# train/1534.npz
# train/1520.npz
# train/1246.npz
# train/922.npz
# train/1508.npz
# train/936.npz
# train/261.npz
# train/507.npz
# train/1093.npz
# train/1087.npz
# train/513.npz
# train/275.npz
# train/249.npz
# train/1050.npz
# train/1044.npz
# train/1722.npz
# train/1078.npz
# train/315.npz
# train/1681.npz
# train/473.npz
# train/467.npz
# train/1695.npz
# train/301.npz
# train/329.npz
# train/1642.npz
# train/1124.npz
# train/1130.npz
# train/1656.npz
# train/1118.npz
# train/498.npz
# train/671.npz
# train/1483.npz
# train/117.npz
# train/103.npz
# train/1497.npz
# train/665.npz
# train/895.npz
# train/659.npz
# train/881.npz
# train/1326.npz
# train/1440.npz
# train/1454.npz
# train/1332.npz
# train/856.npz
# train/16.npz
# train/1468.npz
# train/842.npz
# train/1336.npz
# train/1450.npz
# train/1444.npz
# train/1322.npz
# train/846.npz
# train/1478.npz
# train/12.npz
# train/852.npz
# train/661.npz
# train/1493.npz
# train/107.npz
# train/113.npz
# train/1487.npz
# train/675.npz
# train/885.npz
# train/891.npz
# train/649.npz
# train/1652.npz
# train/1134.npz
# train/1120.npz
# train/1646.npz
# train/1108.npz
# train/488.npz
# train/305.npz
# train/1691.npz
# train/463.npz
# train/477.npz
# train/1685.npz
# train/311.npz
# train/339.npz
# train/1726.npz
# train/1040.npz
# train/1054.npz
# train/1068.npz
# train/271.npz
# train/517.npz
# train/1083.npz
# train/1097.npz
# train/503.npz
# train/265.npz
# train/259.npz
# train/1242.npz
# train/1524.npz
# train/1530.npz
# train/1256.npz
# train/932.npz
# train/1518.npz
# train/926.npz
# train/1281.npz
# train/715.npz
# train/701.npz
# train/1295.npz
# train/729.npz
# train/728.npz
# train/1294.npz
# train/700.npz
# train/714.npz
# train/1280.npz
# train/927.npz
# train/933.npz
# train/1519.npz
# train/1531.npz
# train/1257.npz
# train/1243.npz
# train/1525.npz
# train/258.npz
# train/502.npz
# train/1096.npz
# train/264.npz
# train/270.npz
# train/1082.npz
# train/516.npz
# train/1069.npz
# train/1055.npz
# train/1727.npz
# train/1041.npz
# train/338.npz
# train/476.npz
# train/310.npz
# train/1684.npz
# train/1690.npz
# train/304.npz
# train/462.npz
# train/489.npz
# train/1109.npz
# train/1121.npz
# train/1647.npz
# train/1653.npz
# train/1135.npz
# train/648.npz
# train/890.npz
# train/884.npz
# train/1486.npz
# train/112.npz
# train/674.npz
# train/660.npz
# train/106.npz
# train/1492.npz
# train/1479.npz
# train/853.npz
# train/13.npz
# train/847.npz
# train/1445.npz
# train/1323.npz
# train/1337.npz
# train/1451.npz
# train/1321.npz
# train/1447.npz
# train/1453.npz
# train/39.npz
# train/1335.npz
# train/879.npz
# train/11.npz
# train/689.npz
# train/851.npz
# train/1309.npz
# train/845.npz
# train/676.npz
# train/110.npz
# train/1484.npz
# train/1490.npz
# train/104.npz
# train/662.npz
# train/892.npz
# train/138.npz
# train/886.npz
# train/1645.npz
# train/1123.npz
# train/1137.npz
# train/1651.npz
# train/1679.npz
# train/1686.npz
# train/312.npz
# train/474.npz
# train/460.npz
# train/306.npz
# train/1692.npz
# train/448.npz
# train/1731.npz
# train/1057.npz
# train/1043.npz
# train/1725.npz
# train/299.npz
# train/1719.npz
# train/266.npz
# train/1094.npz
# train/500.npz
# train/514.npz
# train/1080.npz
# train/272.npz
# train/528.npz
# train/919.npz
# train/1255.npz
# train/1533.npz
# train/1527.npz
# train/1241.npz
# train/925.npz
# train/1269.npz
# train/931.npz
# train/702.npz
# train/1296.npz
# train/1282.npz
# train/716.npz
# train/717.npz
# train/1283.npz
# train/1297.npz
# train/703.npz
# train/930.npz
# train/1268.npz
# train/924.npz
# train/1526.npz
# train/1240.npz
# train/1254.npz
# train/918.npz
# train/1532.npz
# train/529.npz
# train/1081.npz
# train/515.npz
# train/273.npz
# train/267.npz
# train/501.npz
# train/1095.npz
# train/1718.npz
# train/298.npz
# train/1042.npz
# train/1724.npz
# train/1730.npz
# train/1056.npz
# train/449.npz
# train/461.npz
# train/1693.npz
# train/307.npz
# train/313.npz
# train/1687.npz
# train/475.npz
# train/1678.npz
# train/1136.npz
# train/1650.npz
# train/1644.npz
# train/1122.npz
# train/139.npz
# train/887.npz
# train/893.npz
# train/105.npz
# train/1491.npz
# train/663.npz
# train/677.npz
# train/1485.npz
# train/111.npz
# train/844.npz
# train/1308.npz
# train/850.npz
# train/688.npz
# train/10.npz
# train/1452.npz
# train/878.npz
# train/1334.npz
# train/38.npz
# train/1320.npz
# train/1446.npz
# train/1339.npz
# train/35.npz
# train/875.npz
# train/21.npz
# train/861.npz
# train/1463.npz
# train/1305.npz
# train/691.npz
# train/849.npz
# train/685.npz
# train/1311.npz
# train/1477.npz
# train/108.npz
# train/1488.npz
# train/134.npz
# train/652.npz
# train/646.npz
# train/120.npz
# train/1649.npz
# train/493.npz
# train/1107.npz
# train/1661.npz
# train/1675.npz
# train/1113.npz
# train/487.npz
# train/478.npz
# train/450.npz
# train/336.npz
# train/322.npz
# train/444.npz
# train/1729.npz
# train/1073.npz
# train/281.npz
# train/1715.npz
# train/1701.npz
# train/295.npz
# train/1067.npz
# train/518.npz
# train/1098.npz
# train/524.npz
# train/242.npz
# train/256.npz
# train/530.npz
# train/901.npz
# train/915.npz
# train/1259.npz
# train/1517.npz
# train/1271.npz
# train/929.npz
# train/1265.npz
# train/1503.npz
# train/726.npz
# train/732.npz
# train/733.npz
# train/727.npz
# train/1264.npz
# train/928.npz
# train/1502.npz
# train/1516.npz
# train/1270.npz
# train/1258.npz
# train/914.npz
# train/900.npz
# train/257.npz
# train/531.npz
# train/525.npz
# train/243.npz
# train/1099.npz
# train/519.npz
# train/294.npz
# train/1700.npz
# train/1066.npz
# train/1072.npz
# train/1714.npz
# train/280.npz
# train/1728.npz
# train/323.npz
# train/445.npz
# train/451.npz
# train/337.npz
# train/479.npz
# train/1674.npz
# train/486.npz
# train/1112.npz
# train/1106.npz
# train/492.npz
# train/1660.npz
# train/1648.npz
# train/647.npz
# train/121.npz
# train/135.npz
# train/653.npz
# train/1489.npz
# train/109.npz
# train/1310.npz
# train/684.npz
# train/1476.npz
# train/1462.npz
# train/848.npz
# train/690.npz
# train/1304.npz
# train/860.npz
# train/20.npz
# train/874.npz
# train/34.npz
# train/1338.npz
# train/1448.npz
# train/22.npz
# train/862.npz
# train/36.npz
# train/876.npz
# train/1474.npz
# train/686.npz
# train/1312.npz
# train/1306.npz
# train/692.npz
# train/1460.npz
# train/679.npz
# train/123.npz
# train/645.npz
# train/889.npz
# train/651.npz
# train/137.npz
# train/1138.npz
# train/1110.npz
# train/484.npz
# train/1676.npz
# train/1662.npz
# train/490.npz
# train/1104.npz
# train/1689.npz
# train/309.npz
# train/447.npz
# train/321.npz
# train/335.npz
# train/453.npz
# train/1058.npz
# train/1064.npz
# train/1702.npz
# train/296.npz
# train/282.npz
# train/1716.npz
# train/1070.npz
# train/269.npz
# train/533.npz
# train/255.npz
# train/241.npz
# train/527.npz
# train/916.npz
# train/902.npz
# train/1528.npz
# train/1500.npz
# train/1266.npz
# train/1272.npz
# train/1514.npz
# train/1299.npz
# train/719.npz
# train/731.npz
# train/725.npz
# train/724.npz
# train/730.npz
# train/718.npz
# train/1298.npz
# train/1273.npz
# train/1515.npz
# train/1501.npz
# train/1267.npz
# train/903.npz
# train/1529.npz
# train/917.npz
# train/240.npz
# train/526.npz
# train/532.npz
# train/254.npz
# train/268.npz
# train/1717.npz
# train/283.npz
# train/1071.npz
# train/1065.npz
# train/297.npz
# train/1703.npz
# train/1059.npz
# train/334.npz
# train/452.npz
# train/446.npz
# train/320.npz
# train/308.npz
# train/1688.npz
# train/1663.npz
# train/1105.npz
# train/491.npz
# train/485.npz
# train/1111.npz
# train/1677.npz
# train/1139.npz
# train/650.npz
# train/888.npz
# train/136.npz
# train/122.npz
# train/644.npz
# train/678.npz
# train/693.npz
# train/1307.npz
# train/1461.npz
# train/1475.npz
# train/1313.npz
# train/687.npz
# train/877.npz
# train/37.npz
# train/1449.npz
# train/863.npz
# train/23.npz
# train/683.npz
# train/1317.npz
# train/1471.npz
# train/1465.npz
# train/1303.npz
# train/697.npz
# train/27.npz
# train/867.npz
# train/1459.npz
# train/33.npz
# train/873.npz
# train/898.npz
# train/640.npz
# train/126.npz
# train/132.npz
# train/654.npz
# train/668.npz
# train/1673.npz
# train/1115.npz
# train/481.npz
# train/495.npz
# train/1101.npz
# train/1667.npz
# train/1129.npz
# train/324.npz
# train/442.npz
# train/456.npz
# train/330.npz
# train/318.npz
# train/1698.npz
# train/1707.npz
# train/293.npz
# train/1061.npz
# train/1075.npz
# train/287.npz
# train/1713.npz
# train/1049.npz
# train/250.npz
# train/536.npz
# train/522.npz
# train/244.npz
# train/278.npz
# train/1263.npz
# train/1505.npz
# train/1511.npz
# train/1277.npz
# train/913.npz
# train/1539.npz
# train/907.npz
# train/734.npz
# train/720.npz
# train/708.npz
# train/1288.npz
# train/1289.npz
# train/709.npz
# train/721.npz
# train/735.npz
# train/906.npz
# train/912.npz
# train/1538.npz
# train/1510.npz
# train/1276.npz
# train/1262.npz
# train/1504.npz
# train/279.npz
# train/523.npz
# train/245.npz
# train/251.npz
# train/537.npz
# train/1048.npz
# train/1074.npz
# train/1712.npz
# train/286.npz
# train/292.npz
# train/1706.npz
# train/1060.npz
# train/1699.npz
# train/319.npz
# train/457.npz
# train/331.npz
# train/325.npz
# train/443.npz
# train/1128.npz
# train/1100.npz
# train/494.npz
# train/1666.npz
# train/1672.npz
# train/480.npz
# train/1114.npz
# train/669.npz
# train/133.npz
# train/655.npz
# train/641.npz
# train/899.npz
# train/127.npz
# train/1458.npz
# train/872.npz
# train/32.npz
# train/866.npz
# train/26.npz
# train/1464.npz
# train/696.npz
# train/1302.npz
# train/1316.npz
# train/682.npz
# train/1470.npz
# train/1300.npz
# train/694.npz
# train/1466.npz
# train/1472.npz
# train/18.npz
# train/680.npz
# train/1314.npz
# train/858.npz
# train/30.npz
# train/870.npz
# train/24.npz
# train/1328.npz
# train/864.npz
# train/657.npz
# train/131.npz
# train/125.npz
# train/643.npz
# train/1499.npz
# train/119.npz
# train/1664.npz
# train/496.npz
# train/1102.npz
# train/1116.npz
# train/482.npz
# train/1670.npz
# train/1658.npz
# train/333.npz
# train/455.npz
# train/441.npz
# train/327.npz
# train/469.npz
# train/284.npz
# train/1710.npz
# train/1076.npz
# train/1062.npz
# train/1704.npz
# train/290.npz
# train/247.npz
# train/521.npz
# train/535.npz
# train/253.npz
# train/1089.npz
# train/509.npz
# train/938.npz
# train/1274.npz
# train/1512.npz
# train/1506.npz
# train/1260.npz
# train/904.npz
# train/1248.npz
# train/910.npz
# train/723.npz
# train/737.npz
# train/736.npz
# train/722.npz
# train/911.npz
# train/1249.npz
# train/905.npz
# train/1507.npz
# train/1261.npz
# train/1275.npz
# train/939.npz
# train/1513.npz
# train/508.npz
# train/1088.npz
# train/534.npz
# train/252.npz
# train/246.npz
# train/520.npz
# train/1063.npz
# train/291.npz
# train/1705.npz
# train/1711.npz
# train/285.npz
# train/1077.npz
# train/468.npz
# train/440.npz
# train/326.npz
# train/332.npz
# train/454.npz
# train/1659.npz
# train/483.npz
# train/1117.npz
# train/1671.npz
# train/1665.npz
# train/1103.npz
# train/497.npz
# train/118.npz
# train/1498.npz
# train/124.npz
# train/642.npz
# train/656.npz
# train/130.npz
# train/865.npz
# train/1329.npz
# train/25.npz
# train/871.npz
# train/31.npz
# train/1473.npz
# train/859.npz
# train/1315.npz
# train/681.npz
# train/19.npz
# train/695.npz
# train/1301.npz
# train/1467.npz
# train/56.npz
# train/816.npz
# train/4.npz
# train/1428.npz
# train/42.npz
# train/802.npz
# train/1366.npz
# train/1400.npz
# train/194.npz
# train/180.npz
# train/1414.npz
# train/1372.npz
# train/1399.npz
# train/95.npz
# train/619.npz
# train/81.npz
# train/631.npz
# train/157.npz
# train/143.npz
# train/625.npz
# train/1158.npz
# train/396.npz
# train/1602.npz
# train/1164.npz
# train/1170.npz
# train/1616.npz
# train/382.npz
# train/369.npz
# train/355.npz
# train/433.npz
# train/427.npz
# train/341.npz
# train/1038.npz
# train/584.npz
# train/1010.npz
# train/1004.npz
# train/590.npz
# train/209.npz
# train/221.npz
# train/547.npz
# train/553.npz
# train/235.npz
# train/962.npz
# train/1548.npz
# train/976.npz
# train/1212.npz
# train/786.npz
# train/1574.npz
# train/1560.npz
# train/792.npz
# train/1206.npz
# train/779.npz
# train/745.npz
# train/751.npz
# train/989.npz
# train/988.npz
# train/750.npz
# train/744.npz
# train/778.npz
# train/1561.npz
# train/1207.npz
# train/793.npz
# train/787.npz
# train/1213.npz
# train/1575.npz
# train/977.npz
# train/963.npz
# train/1549.npz
# train/552.npz
# train/234.npz
# train/220.npz
# train/546.npz
# train/208.npz
# train/591.npz
# train/1005.npz
# train/1011.npz
# train/585.npz
# train/1039.npz
# train/426.npz
# train/340.npz
# train/354.npz
# train/432.npz
# train/368.npz
# train/1171.npz
# train/383.npz
# train/1617.npz
# train/1603.npz
# train/397.npz
# train/1165.npz
# train/1159.npz
# train/142.npz
# train/624.npz
# train/630.npz
# train/156.npz
# train/80.npz
# train/618.npz
# train/94.npz
# train/1398.npz
# train/1415.npz
# train/181.npz
# train/1373.npz
# train/1367.npz
# train/195.npz
# train/1401.npz
# train/1429.npz
# train/803.npz
# train/43.npz
# train/817.npz
# train/57.npz
# train/5.npz
# train/41.npz
# train/801.npz
# train/7.npz
# train/1359.npz
# train/55.npz
# train/815.npz
# train/1371.npz
# train/183.npz
# train/1417.npz
# train/1403.npz
# train/197.npz
# train/1365.npz
# train/69.npz
# train/829.npz
# train/82.npz
# train/168.npz
# train/96.npz
# train/626.npz
# train/140.npz
# train/154.npz
# train/632.npz
# train/1629.npz
# train/1615.npz
# train/381.npz
# train/1173.npz
# train/1167.npz
# train/395.npz
# train/1601.npz
# train/418.npz
# train/1198.npz
# train/342.npz
# train/424.npz
# train/430.npz
# train/356.npz
# train/1007.npz
# train/593.npz
# train/587.npz
# train/1013.npz
# train/578.npz
# train/236.npz
# train/550.npz
# train/544.npz
# train/222.npz
# train/975.npz
# train/1239.npz
# train/961.npz
# train/949.npz
# train/791.npz
# train/1205.npz
# train/1563.npz
# train/1577.npz
# train/1211.npz
# train/785.npz
# train/1588.npz
# train/752.npz
# train/746.npz
# train/747.npz
# train/753.npz
# train/1589.npz
# train/1576.npz
# train/784.npz
# train/1210.npz
# train/1204.npz
# train/790.npz
# train/948.npz
# train/1562.npz
# train/960.npz
# train/1238.npz
# train/974.npz
# train/545.npz
# train/223.npz
# train/237.npz
# train/551.npz
# train/579.npz
# train/1012.npz
# train/586.npz
# train/592.npz
# train/1006.npz
# train/431.npz
# train/357.npz
# train/343.npz
# train/425.npz
# train/1199.npz
# train/419.npz
# train/1166.npz
# train/1600.npz
# train/394.npz
# train/380.npz
# train/1614.npz
# train/1172.npz
# train/1628.npz
# train/155.npz
# train/633.npz
# train/627.npz
# train/141.npz
# train/169.npz
# train/97.npz
# train/83.npz
# train/196.npz
# train/1402.npz
# train/828.npz
# train/68.npz
# train/1364.npz
# train/1370.npz
# train/1416.npz
# train/182.npz
# train/6.npz
# train/814.npz
# train/54.npz
# train/1358.npz
# train/800.npz
# train/40.npz
# train/186.npz
# train/1412.npz
# train/78.npz
# train/1374.npz
# train/838.npz
# train/1360.npz
# train/1406.npz
# train/192.npz
# train/44.npz
# train/1348.npz
# train/804.npz
# train/50.npz
# train/810.npz
# train/2.npz
# train/145.npz
# train/623.npz
# train/637.npz
# train/151.npz
# train/179.npz
# train/87.npz
# train/93.npz
# train/1176.npz
# train/1610.npz
# train/384.npz
# train/390.npz
# train/1604.npz
# train/1162.npz
# train/1638.npz
# train/421.npz
# train/347.npz
# train/353.npz
# train/435.npz
# train/1189.npz
# train/409.npz
# train/1002.npz
# train/596.npz
# train/582.npz
# train/1016.npz
# train/555.npz
# train/233.npz
# train/227.npz
# train/541.npz
# train/569.npz
# train/1566.npz
# train/794.npz
# train/1200.npz
# train/958.npz
# train/1214.npz
# train/780.npz
# train/1572.npz
# train/970.npz
# train/964.npz
# train/1228.npz
# train/757.npz
# train/743.npz
# train/1599.npz
# train/1598.npz
# train/742.npz
# train/756.npz
# train/1229.npz
# train/965.npz
# train/971.npz
# train/781.npz
# train/1215.npz
# train/959.npz
# train/1573.npz
# train/1567.npz
# train/1201.npz
# train/795.npz
# train/568.npz
# train/226.npz
# train/540.npz
# train/554.npz
# train/232.npz
# train/1017.npz
# train/583.npz
# train/597.npz
# train/1003.npz
# train/408.npz
# train/1188.npz
# train/352.npz
# train/434.npz
# train/420.npz
# train/346.npz
# train/1639.npz
# train/1605.npz
# train/391.npz
# train/1163.npz
# train/1177.npz
# train/385.npz
# train/1611.npz
# train/92.npz
# train/178.npz
# train/86.npz
# train/636.npz
# train/150.npz
# train/144.npz
# train/622.npz
# train/811.npz
# train/51.npz
# train/3.npz
# train/805.npz
# train/1349.npz
# train/45.npz
# train/1361.npz
# train/193.npz
# train/1407.npz
# train/1413.npz
# train/187.npz
# train/839.npz
# train/1375.npz
# train/79.npz
# train/1405.npz
# train/191.npz
# train/1363.npz
# train/1377.npz
# train/185.npz
# train/1411.npz
# train/1.npz
# train/1439.npz
# train/53.npz
# train/813.npz
# train/47.npz
# train/807.npz
# train/152.npz
# train/634.npz
# train/620.npz
# train/146.npz
# train/90.npz
# train/608.npz
# train/84.npz
# train/1388.npz
# train/1161.npz
# train/393.npz
# train/1607.npz
# train/1613.npz
# train/387.npz
# train/1175.npz
# train/1149.npz
# train/436.npz
# train/350.npz
# train/344.npz
# train/422.npz
# train/378.npz
# train/581.npz
# train/1015.npz
# train/1001.npz
# train/595.npz
# train/1029.npz
# train/542.npz
# train/224.npz
# train/230.npz
# train/556.npz
# train/218.npz
# train/1571.npz
# train/1217.npz
# train/783.npz
# train/797.npz
# train/1203.npz
# train/1565.npz
# train/967.npz
# train/973.npz
# train/1559.npz
# train/740.npz
# train/998.npz
# train/754.npz
# train/768.npz
# train/769.npz
# train/755.npz
# train/999.npz
# train/741.npz
# train/972.npz
# train/1558.npz
# train/966.npz
# train/1202.npz
# train/796.npz
# train/1564.npz
# train/1570.npz
# train/782.npz
# train/1216.npz
# train/219.npz
# train/231.npz
# train/557.npz
# train/543.npz
# train/225.npz
# train/1028.npz
# train/594.npz
# train/1000.npz
# train/1014.npz
# train/580.npz
# train/379.npz
# train/345.npz
# train/423.npz
# train/437.npz
# train/351.npz
# train/1148.npz
# train/386.npz
# train/1612.npz
# train/1174.npz
# train/1160.npz
# train/1606.npz
# train/392.npz
# train/1389.npz
# train/85.npz
# train/609.npz
# train/91.npz
# train/621.npz
# train/147.npz
# train/153.npz
# train/635.npz
# train/806.npz
# train/46.npz
# train/1438.npz
# train/812.npz
# train/52.npz
# train/1376.npz
# train/1410.npz
# train/184.npz
# train/190.npz
# train/1404.npz
# train/1362.npz
# train/0.npz

# %%
gt_df = pd.read_csv(gt_path)
wavelength_df = pd.read_csv(wavelength_path)

# %%
def load_data(directory: str):
    data = []

    all_files = np.array(
        sorted(
            glob(os.path.join(directory, "*.npz")),
            key=lambda x: int(os.path.basename(x).replace(".npz", "")),
        )
    )

    for file_name in all_files:
        with np.load(file_name) as npz:
            raw_arr = np.ma.MaskedArray(data=npz['data'], mask=npz['mask'])
            img_tensor_raw = torch.as_tensor(raw_arr.data, dtype=torch.float)
            img_tensor_mask = ~torch.as_tensor(raw_arr.mask) # Revert mask: 0 is invalid, 1 is valid
            img_tensor_masked = torch.mul(img_tensor_raw, img_tensor_mask)
        data.append(img_tensor_masked)

    return data

# %%
def load_gt(file_path: str):
    """Load labels for train set from the ground truth file.
    Args:
        file_path (str): Path to the ground truth .csv file.
    Returns:
        [type]: 2D numpy array with soil properties levels
    """
    gt_file = pd.read_csv(file_path)
    labels = gt_file[["P", "K", "Mg", "pH"]].values
    return labels

# %%
X_train = load_data("/content/train_data/train")
y_train = load_gt("train_gt.csv")

# %%
# Collect all pixels for PCA
# =========================
def collect_pixels(data_list, max_pixels=10000000):
    """
    Flatten pixels from all patches for PCA, sampling to control memory usage.
    Samples pixels from each patch to ensure the total collected does not exceed max_pixels.
    """
    all_pixels = []
    # Estimate total pixels to determine sampling ratio
    total_potential_pixels = sum(arr.shape[1] * arr.shape[2] for arr in data_list)

    sampling_ratio = 1.0
    if total_potential_pixels > max_pixels:
        sampling_ratio = max_pixels / total_potential_pixels
        print(f"Sampling {sampling_ratio*100:.2f}% of pixels to stay within {max_pixels} limit.")

    for arr in data_list:
        #data = arr.filled(0) if isinstance(arr, np.ma.MaskedArray) else arr
        data = np.transpose(arr, (1, 2, 0))  # H, W, C
        pixels = data.reshape(-1, data.shape[-1]) # (H*W, C)

        if sampling_ratio < 1.0 and pixels.shape[0] > 0:
            num_pixels_to_sample = int(pixels.shape[0] * sampling_ratio)
            # Ensure we don't try to sample more pixels than available
            num_pixels_to_sample = max(1, min(num_pixels_to_sample, pixels.shape[0]))
            idx = np.random.choice(pixels.shape[0], num_pixels_to_sample, replace=False)
            all_pixels.append(pixels[idx])
        else:
            all_pixels.append(pixels)

    if not all_pixels:
        return np.empty((0, data_list[0].shape[0])) # Return empty array with correct feature dim

    X = np.vstack(all_pixels)
    return X

# %%
def transform_patches(data_list, scaler, pca):
    """
    Transforms a list of data patches using a fitted StandardScaler and PCA.

    Args:
        data_list (list): A list of torch.Tensor or numpy.ndarray objects,
                          each representing a hyperspectral image patch (C, H, W).
        scaler (StandardScaler): A fitted StandardScaler object.
        pca (PCA): A fitted PCA object.

    Returns:
        list: A list of transformed patches, where each patch is a torch.Tensor
              with reduced dimensions (n_components, H, W).
    """
    transformed_list = []
    for arr in data_list:
        #data = arr.filled(0) if isinstance(arr, np.ma.MaskedArray) else arr
        data = np.transpose(arr, (1, 2, 0))  # H, W, C
        H, W, C = data.shape
        pixels = data.reshape(-1, C)
        pixels_scaled = scaler.transform(pixels)
        pixels_pca = pca.transform(pixels_scaled)
        data_pca = pixels_pca.reshape(H, W, -1)

        tensor_patch = torch.from_numpy(np.transpose(data_pca, (2, 0, 1)).astype(np.float32))

        # # ---- Resize to fixed size ----
        # tensor_patch = F.interpolate(
        #     tensor_patch.unsqueeze(0),
        #     size=(224, 224),
        #     mode='bilinear',
        #     align_corners=False
        # ).squeeze(0)

        transformed_list.append(tensor_patch)
    return transformed_list

# %%
# # -----------------------
# # Split into train, val, test
# # -----------------------

# # First, split off test set (20%)
# X_temp, X_test, y_temp, y_test = train_test_split(
#     X_train, y_train, test_size=0.2, random_state=42
# )

# # Then, split remaining 80% into train/val
# X_train_final, X_val, y_train_final, y_val = train_test_split(
#     X_temp, y_temp, test_size=0.2, random_state=42
# )

# print(f"Train patches: {len(X_train_final)}")
# print(f"Validation patches: {len(X_val)}")
# print(f"Test patches: {len(X_test)}")

# %%
# -----------------------
# Split into train, val, test
# -----------------------

# Create an array of indices for X_train
original_indices = np.arange(len(X_train))

# First, split off test set (20%)
X_temp, X_test, y_temp, y_test, temp_indices, test_indices = train_test_split(
    X_train, y_train, original_indices, test_size=0.2, random_state=10
)

# Then, split remaining 80% into train/val
X_train_final, X_val, y_train_final, y_val, train_indices, val_indices = train_test_split(
    X_temp, y_temp, temp_indices, test_size=0.2, random_state=10
)

print(f"Train patches: {len(X_train_final)}")
print(f"Validation patches: {len(X_val)}")
print(f"Test patches: {len(X_test)}")
# Out:
# Train patches: 1108
# Validation patches: 277
# Test patches: 347

# %%
# # Load PCA instead of refitting
# pca = joblib.load("pca_hyperspectral.pkl")
# print("PCA loaded from file")

# scaler = joblib.load("scaler_hyperspectral.pkl")
# print("Scaler loaded from file")

# %%
# Fit PCA on training pixels (as before)
X_pixels_train = collect_pixels(X_train_final)

# ------------------------
# Normalize training pixels
# ------------------------
scaler = StandardScaler()
X_pixels_train_scaled = scaler.fit_transform(X_pixels_train)

# Save scaler for later
joblib.dump(scaler, "scaler_hyperspectral.pkl")
print("Scaler saved.")

# Set n_components to match the model's in_channels
n_components = 10
pca = PCA(n_components=n_components)
pca.fit(X_pixels_train_scaled)

# Save PCA
joblib.dump(pca, "pca_hyperspectral.pkl")
print("PCA saved")
# Out:
# Scaler saved.
# PCA saved

# %%
X_train_pca = transform_patches(X_train_final, scaler, pca)
X_val_pca   = transform_patches(X_val, scaler, pca)
X_test_pca  = transform_patches(X_test, scaler, pca)

# %%
# -------------------------------
# Scale labels
# -------------------------------
scaler_y = StandardScaler()
y_train_final_scaled = scaler_y.fit_transform(y_train_final)
y_val_scaled   = scaler_y.transform(y_val)
y_test_scaled  = scaler_y.transform(y_test)
joblib.dump(scaler_y, "scaler_labels.pkl")
print("Label scaler saved.")
# Out:
# Label scaler saved.

# %%
class NPZDataset(Dataset):
    def __init__(self, tensor_list, labels, augment=True, size=(224,224)):
        self.tensor_list = tensor_list
        self.labels = labels
        self.augment = augment
        self.size = size

        self.transform_aug = v2.Compose([
            v2.Resize((224, 224)),
            v2.RandomHorizontalFlip(p=0.5),
            v2.GaussianNoise(mean=0.0, sigma=0.03),
        ])

        self.transform_basic = v2.Compose([
            v2.Resize((224, 224)),
        ])


    def __len__(self):
        return len(self.tensor_list)

    def __getitem__(self, idx):
        x = self.tensor_list[idx]

        # # ---- Unconditionally resize to fixed size first ----
        # # This ensures all tensors are of a consistent size before augmentation
        # # and before being passed to the DataLoader's collate_fn.
        # if x.shape[1] != self.size[0] or x.shape[2] != self.size[1]:
        #     x = F.interpolate(
        #         x.unsqueeze(0),  # add batch dim -> (1, C, H, W)
        #         size=self.size,
        #         mode='bilinear',
        #         align_corners=False
        #     ).squeeze(0)       # remove batch dim -> (C, H, W)

        # ---- Apply augmentation ----
        if self.augment:
            x = self.transform_aug(x)
        else:
            x = self.transform_basic(x)

        # ---- Per-channel normalization for CNN ----
        x = (x - x.mean(dim=(1,2), keepdim=True)) / (x.std(dim=(1,2), keepdim=True) + 1e-6)

        y = torch.tensor(self.labels[idx], dtype=torch.float32)
        return x, y

# %%
# -----------------------
# Create Dataset and DataLoader
# -----------------------

train_dataset = NPZDataset(X_train_pca, y_train_final_scaled, augment=True)
val_dataset   = NPZDataset(X_val_pca, y_val_scaled, augment=False)
test_dataset  = NPZDataset(X_test_pca, y_test_scaled, augment=False)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
val_loader   = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=2)
test_loader  = DataLoader(test_dataset, batch_size=16, shuffle=False, num_workers=2)

# %%
class HyperspectralRegressor(nn.Module):
    def __init__(self, in_channels=20, n_outputs=4, backbone_name="efficientnet_b0", pretrained=False):
        """
        Hyperspectral regression model using EfficientNet backbone from timm.
        Args:
            in_channels (int): Number of input channels (after PCA)
            n_outputs (int): Number of regression targets (e.g., 4)
            backbone_name (str): EfficientNet variant from timm
            pretrained (bool): Use ImageNet weights
        """
        super().__init__()

        # Create backbone
        self.backbone = timm.create_model(
            backbone_name,
            pretrained=pretrained,
            in_chans=in_channels,
            num_classes=0,      # No classifier, we'll add our own head
        )

        # Feature dimension after backbone
        if hasattr(self.backbone, "num_features"):
            feat_dim = self.backbone.num_features
        else:
            feat_dim = self.backbone.fc.in_features  # fallback

        # Regression head
        self.regressor = nn.Sequential(
            nn.Linear(feat_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, n_outputs)
        )

    def forward(self, x):
        # x: (B, in_channels, H, W)
        features = self.backbone(x)  # backbone outputs features (B, feat_dim)
        out = self.regressor(features)  # (B, n_outputs)
        return out

# %% [markdown]
# Test overfitting on one batch

# %%
train_data_single_batch = next(iter(train_loader))

# %%
train_data_single_batch[0].shape
# Out:
# torch.Size([16, 10, 224, 224])

# %%
train_data_single_batch[1].shape
# Out:
# torch.Size([16, 4])

# %%
# Re-initialize a fresh model for overfitting
model_overfit = HyperspectralRegressor(
    in_channels=10,   # PCA-reduced channels
    n_outputs=4,      # P, K, Mg, pH
    backbone_name="efficientnet_b0",
    pretrained=False  # Use pre-trained weights
)
model_overfit = model_overfit.to(device)

# Define optimizer and criterion for overfitting
optimizer_overfit = optim.AdamW(model_overfit.parameters(), lr=1e-3, weight_decay=1e-4)
criterion_overfit = nn.MSELoss()

# Extract the single batch
x_single, y_single = train_data_single_batch
x_single, y_single = x_single.to(device), y_single.to(device)

# Overfitting loop
overfit_epochs = 500 # A high number of epochs to ensure overfitting
print(f"\n--- Starting Overfitting on Single Batch for {overfit_epochs} epochs ---")

for epoch_overfit in range(overfit_epochs):
    model_overfit.train()
    optimizer_overfit.zero_grad()

    outputs_overfit = model_overfit(x_single)
    loss_overfit = criterion_overfit(outputs_overfit, y_single)

    loss_overfit.backward()
    optimizer_overfit.step()

    if (epoch_overfit + 1) % 10 == 0 or epoch_overfit == 0:
        print(f"Overfit Epoch {epoch_overfit+1}/{overfit_epochs} - Loss: {loss_overfit.item():.6f}")

print("--- Overfitting complete ---")
# Out:
# --- Starting Overfitting on Single Batch for 500 epochs ---
# Overfit Epoch 1/500 - Loss: 2.221717
# Overfit Epoch 10/500 - Loss: 0.233393
# Overfit Epoch 20/500 - Loss: 0.109071
# Overfit Epoch 30/500 - Loss: 0.055883
# Overfit Epoch 40/500 - Loss: 0.063817
# Overfit Epoch 50/500 - Loss: 0.058445
# Overfit Epoch 60/500 - Loss: 0.092754
# Overfit Epoch 70/500 - Loss: 0.036040
# Overfit Epoch 80/500 - Loss: 0.035439
# Overfit Epoch 90/500 - Loss: 0.029744
# Overfit Epoch 100/500 - Loss: 0.045753
# Overfit Epoch 110/500 - Loss: 0.159967
# Overfit Epoch 120/500 - Loss: 0.063580
# Overfit Epoch 130/500 - Loss: 0.056003
# Overfit Epoch 140/500 - Loss: 0.028000
# Overfit Epoch 150/500 - Loss: 0.061065
# Overfit Epoch 160/500 - Loss: 0.042531
# Overfit Epoch 170/500 - Loss: 0.034951
# Overfit Epoch 180/500 - Loss: 0.032003
# Overfit Epoch 190/500 - Loss: 0.032454
# Overfit Epoch 200/500 - Loss: 0.038700
# Overfit Epoch 210/500 - Loss: 0.023853
# Overfit Epoch 220/500 - Loss: 0.039979
# Overfit Epoch 230/500 - Loss: 0.035894
# Overfit Epoch 240/500 - Loss: 0.028881
# Overfit Epoch 250/500 - Loss: 0.029798
# Overfit Epoch 260/500 - Loss: 0.020869
# Overfit Epoch 270/500 - Loss: 0.034430
# Overfit Epoch 280/500 - Loss: 0.049562
# Overfit Epoch 290/500 - Loss: 0.040976
# Overfit Epoch 300/500 - Loss: 0.023011
# Overfit Epoch 310/500 - Loss: 0.014937
# Overfit Epoch 320/500 - Loss: 0.045915
# Overfit Epoch 330/500 - Loss: 0.016150
# Overfit Epoch 340/500 - Loss: 0.026184
# Overfit Epoch 350/500 - Loss: 0.078072
# Overfit Epoch 360/500 - Loss: 0.064353
# Overfit Epoch 370/500 - Loss: 0.016884
# Overfit Epoch 380/500 - Loss: 0.032771
# Overfit Epoch 390/500 - Loss: 0.029440
# Overfit Epoch 400/500 - Loss: 0.062148
# Overfit Epoch 410/500 - Loss: 0.030581
# Overfit Epoch 420/500 - Loss: 0.018554
# Overfit Epoch 430/500 - Loss: 0.019188
# Overfit Epoch 440/500 - Loss: 0.061839
# Overfit Epoch 450/500 - Loss: 0.027814
# Overfit Epoch 460/500 - Loss: 0.038321
# Overfit Epoch 470/500 - Loss: 0.056715
# Overfit Epoch 480/500 - Loss: 0.024218
# Overfit Epoch 490/500 - Loss: 0.027101
# Overfit Epoch 500/500 - Loss: 0.023498
# --- Overfitting complete ---

# %%
print('\n--- Model Overfit Predictions vs. True Values ---')
model_overfit.eval() # Set model to evaluation mode

with torch.no_grad():
    outputs_single_batch = model_overfit(x_single)

print("Predictions:")
print(outputs_single_batch.cpu().numpy())
print("\nTrue Values:")
print(y_single.cpu().numpy())
# Out:
# --- Model Overfit Predictions vs. True Values ---
# Predictions:
# [[-0.94313025 -0.3659398  -0.38987988  0.01554734]
#  [ 1.2393974   1.5092217   0.45786408  0.5088096 ]
#  [-0.3867297  -0.7555089  -1.3365971   0.45302078]
#  [-0.760373   -0.7140082  -0.37727848 -0.45104742]
#  [-0.68533957 -0.69653875  0.8171796  -1.7455422 ]
#  [ 1.2516267  -0.05957357 -0.8526168   0.92824626]
#  [-0.54445106  0.673693    0.6595629  -0.83951914]
#  [ 2.6618288   1.8153003   0.17287034 -1.1269559 ]
#  [ 4.457479    2.5154278   1.6819814  -0.31714985]
#  [-0.3140385  -0.41279802 -0.6770728   2.1704383 ]
#  [ 2.7467725   2.8887753   0.8461386   3.8318613 ]
#  [-0.9978927  -0.28549686  0.32668105  0.34950837]
#  [ 0.58807296 -0.40671948  1.1855223   1.4642333 ]
#  [-0.10891543  2.5998068   0.85759574 -0.7432222 ]
#  [ 1.5573173   0.4404362  -0.3575731   0.31981483]
#  [-0.97308195 -0.6096755  -0.8756199  -1.2183917 ]]
#
# True Values:
# [[-0.86481756 -0.33594233 -0.3794527   0.06302792]
#  [ 1.160819    1.3698835   0.45306     0.44652563]
#  [-0.35840842 -0.7221671  -1.3099082   0.44652563]
#  [-0.7152739  -0.7221671  -0.3794527  -0.3204698 ]
#  [-0.70507777 -0.77044517  0.94277334 -1.8544607 ]
#  [ 1.160819   -0.03018107 -0.7957091   0.83002335]
#  [-0.50115466  0.62961954  0.599974   -0.7039675 ]
#  [ 3.0641017   2.1584258   0.25717464 -1.3559136 ]
#  [ 5.953013    3.4136562   2.2649994  -0.5889182 ]
#  [-0.351611   -0.4164058  -0.64879507  2.1339157 ]
#  [ 2.7242298   3.107895    0.9182877   3.898005  ]
#  [-0.96338046 -0.30375692  0.35511732  0.44652563]
#  [ 0.5184611  -0.4968693   1.2610871   1.5970188 ]
#  [-0.16468143  2.6090212   0.8448307  -0.7039675 ]
#  [ 1.5006909   0.43650717 -0.35496706  0.25477678]
#  [-0.9225958  -0.5773328  -0.8446804  -1.0874653 ]]

# %%
# Load the label scaler
scaler_y = joblib.load("scaler_labels.pkl")
print("Label scaler loaded.")

print('\n--- Unscaled Model Overfit Predictions vs. Unscaled True Values ---')
# Inverse transform predictions and true values
unscaled_predictions = scaler_y.inverse_transform(outputs_single_batch.cpu().numpy())
unscaled_true_values = scaler_y.inverse_transform(y_single.cpu().numpy())

print("Unscaled Predictions:")
print(unscaled_predictions)
print("\nUnscaled True Values:")
print(unscaled_true_values)
# Out:
# Label scaler loaded.
#
# --- Unscaled Model Overfit Predictions vs. Unscaled True Values ---
# Unscaled Predictions:
# [[ 42.095818  205.13596   144.57416     6.787619 ]
#  [106.312     321.65848   179.1962      6.916241 ]
#  [ 58.46671   180.92815   105.91002     6.901694 ]
#  [ 47.473057  183.50699   145.08879     6.665951 ]
#  [ 49.680756  184.59254   193.87073     6.3284016]
#  [106.67182   224.17355   125.67587     7.0256124]
#  [ 53.826096  269.73874   187.43362     6.564654 ]
#  [148.16399   340.6782    167.55699     6.4897027]
#  [200.99713   384.1841    229.18942     6.7008657]
#  [ 60.60549   202.22418   132.84512     7.3495235]
#  [150.66327   407.3839    195.05342     7.7827525]
#  [ 40.48455   210.13467   173.83865     6.874702 ]
#  [ 87.14818   202.60191   208.91393     7.165375 ]
#  [ 66.64079   389.4274    195.52133     6.589764 ]
#  [115.66611   255.24416   145.89357     6.866959 ]
#  [ 41.214554  189.99022   124.73643     6.46586  ]]
#
# Unscaled True Values:
# [[ 44.4      207.       145.         6.8     ]
#  [104.       313.       179.         6.9     ]
#  [ 59.3      183.       107.         6.9     ]
#  [ 48.8      183.       145.         6.7     ]
#  [ 49.100002 180.       199.         6.3     ]
#  [104.       226.       128.         7.      ]
#  [ 55.1      267.       185.         6.6     ]
#  [160.       362.       171.         6.43    ]
#  [245.       440.       253.         6.63    ]
#  [ 59.5      202.       134.         7.34    ]
#  [150.       421.       198.         7.8     ]
#  [ 41.5      209.       175.         6.9     ]
#  [ 85.1      197.       212.         7.2     ]
#  [ 65.       390.       195.         6.6     ]
#  [114.       255.       146.         6.85    ]
#  [ 42.7      192.       126.         6.5     ]]

# %%
plt.figure(figsize=(15, 5))

metrics = ['P', 'K', 'Mg', 'pH']
for i, metric in enumerate(metrics):
    plt.subplot(1, 4, i + 1) # 1 row, 4 columns
    plt.scatter(unscaled_true_values[:, i], unscaled_predictions[:, i], alpha=0.7)
    plt.plot([min(unscaled_true_values[:, i]), max(unscaled_true_values[:, i])],
             [min(unscaled_true_values[:, i]), max(unscaled_true_values[:, i])],
             'r--') # Red dashed line for ideal prediction
    plt.title(f'{metric} (Overfit Batch)')
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Learning loop

# %%
# ----- Model -----
model = HyperspectralRegressor(
    in_channels=10,   # PCA-reduced channels
    n_outputs=4,      # P, K, Mg, pH
    backbone_name="efficientnet_b0",
    pretrained=False
)

model = model.to(device);

# ----- Optimizer -----
optimizer = optim.AdamW([
    {"params": model.backbone.parameters(), "lr": 5e-5},
    {"params": model.regressor.parameters(), "lr": 1e-3},
], weight_decay=1e-4)

# ----- Loss -----
criterion = nn.MSELoss()

# ----- Scheduler -----
scheduler = ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.3,
    patience=5,
    min_lr=1e-6
)

# ----- Hyperparameters -----
epochs = 100
patience = 15  # early stopping patience
warmup_epochs = 5 # Number of epochs for warm-up

# ----- Initialize wandb -----
# Initializing Weights & Biases for experiment tracking.
wandb.init(
    project="hyperview_challenge efficientnet (no pretrained encoder), warm up phase added, 10M pixels rand pca",
    config={
        "learning_rate_backbone": 5e-5,
        "learning_rate_head": 1e-3,
        "epochs": epochs,
        "batch_size": 16,
        "optimizer": "AdamW",
        "criterion": "MSELoss",
        "backbone": "efficientnet_b0",
        "pca_components": 10, # Consistent with the new n_components
        "scheduler": "ReduceLROnPlateau",
        "scheduler_factor": 0.3,
        "scheduler_patience": 5,
        "min_lr": 1e-6,
        "warmup_epochs": warmup_epochs # Added warm-up epochs to config
    }
)
# Log a note to wandb about this run's configuration
wandb.run.log({"note": "This run uses an EfficientNet backbone without pre-trained weights, with a warm-up phase for the learning rate, and PCA applied to 10M pixels randomly sampled pixels from the training data. 10 PCA components used."})
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>note</td><td>This run uses an Eff...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">unique-deluge-2</strong> at: <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca/runs/4pnm9s6h' target="_blank">https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca/runs/4pnm9s6h</a><br> View project at: <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca' target="_blank">https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260410_022653-4pnm9s6h/logs</code>
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/content/wandb/run-20260410_022733-k5msjcoz</code>
# Syncing run <strong><a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca/runs/k5msjcoz' target="_blank">logical-resonance-3</a></strong> to <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca' target="_blank">https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca</a>
#  View run at <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca/runs/k5msjcoz' target="_blank">https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca/runs/k5msjcoz</a>

# %%
# ----- Training with early stopping -----
best_val_loss = float('inf')
counter = 0

# Store initial learning rates for warm-up
initial_lr_backbone = optimizer.param_groups[0]['lr']
initial_lr_head = optimizer.param_groups[1]['lr']

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}", leave=False)

    # --- Warm-up logic ---
    if epoch < warmup_epochs:
        warmup_factor = (epoch + 1) / warmup_epochs
        for i, param_group in enumerate(optimizer.param_groups):
            if i == 0: # Backbone
                param_group['lr'] = initial_lr_backbone * warmup_factor
            else: # Regressor Head
                param_group['lr'] = initial_lr_head * warmup_factor

    for x, y in loop:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(x)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        loop.set_postfix(loss=loss.item())

    train_loss = running_loss / len(train_loader)

    # ----- Validation -----
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            val_preds = model(X_val_batch)
            val_loss += criterion(val_preds, y_val_batch).item()
    val_loss /= len(val_loader)

    # Get current learning rates for logging
    current_lr_backbone = optimizer.param_groups[0]['lr']
    current_lr_head = optimizer.param_groups[1]['lr']

    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f} - backbone LR: {current_lr_backbone:.6f} - head LR: {current_lr_head:.6f}")

    # ----- Log to wandb -----
    wandb.log({"train_loss": train_loss, "val_loss": val_loss, "epoch": epoch, "learning_rate_backbone": current_lr_backbone, "learning_rate_head": current_lr_head})

    # ----- Scheduler step (only after warm-up) -----
    if epoch >= warmup_epochs - 1: # Apply scheduler after warm-up finishes
        scheduler.step(val_loss)

    # ----- Early stopping -----
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        torch.save(model.state_dict(), "best_hyperspectral_model.pth")
    else:
        counter += 1
        if counter >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

# ----- Load best model -----
model.load_state_dict(torch.load("best_hyperspectral_model.pth"))

# ----- Finish wandb -----
wandb.finish()
# Out:
# Epoch 1/100 - Train Loss: 0.9908 - Val Loss: 2.0011 - backbone LR: 0.000010 - head LR: 0.000200
# Epoch 2/100 - Train Loss: 1.0035 - Val Loss: 1.4570 - backbone LR: 0.000020 - head LR: 0.000400
# Epoch 3/100 - Train Loss: 1.0266 - Val Loss: 1.1833 - backbone LR: 0.000030 - head LR: 0.000600
# Epoch 4/100 - Train Loss: 0.9836 - Val Loss: 0.9943 - backbone LR: 0.000040 - head LR: 0.000800
# Epoch 5/100 - Train Loss: 0.9851 - Val Loss: 1.0855 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 6/100 - Train Loss: 0.9894 - Val Loss: 0.9955 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 7/100 - Train Loss: 0.9808 - Val Loss: 0.9619 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 8/100 - Train Loss: 0.9709 - Val Loss: 0.9730 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 9/100 - Train Loss: 0.9724 - Val Loss: 1.0018 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 10/100 - Train Loss: 0.9800 - Val Loss: 0.9144 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 11/100 - Train Loss: 0.9781 - Val Loss: 0.9502 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 12/100 - Train Loss: 0.9656 - Val Loss: 0.9948 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 13/100 - Train Loss: 0.9644 - Val Loss: 0.9404 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 14/100 - Train Loss: 0.9681 - Val Loss: 0.8991 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 15/100 - Train Loss: 0.9574 - Val Loss: 0.9247 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 16/100 - Train Loss: 0.9623 - Val Loss: 0.9047 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 17/100 - Train Loss: 0.9541 - Val Loss: 0.9431 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 18/100 - Train Loss: 0.9731 - Val Loss: 1.3494 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 19/100 - Train Loss: 0.9490 - Val Loss: 0.9351 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 20/100 - Train Loss: 0.9462 - Val Loss: 0.9896 - backbone LR: 0.000050 - head LR: 0.001000
# Epoch 21/100 - Train Loss: 0.9308 - Val Loss: 0.9169 - backbone LR: 0.000015 - head LR: 0.000300
# Epoch 22/100 - Train Loss: 0.9393 - Val Loss: 0.9287 - backbone LR: 0.000015 - head LR: 0.000300
# Epoch 23/100 - Train Loss: 0.9293 - Val Loss: 0.9937 - backbone LR: 0.000015 - head LR: 0.000300
# Epoch 24/100 - Train Loss: 0.9177 - Val Loss: 0.9969 - backbone LR: 0.000015 - head LR: 0.000300
# Epoch 25/100 - Train Loss: 0.9254 - Val Loss: 0.9684 - backbone LR: 0.000015 - head LR: 0.000300
# Epoch 26/100 - Train Loss: 0.9257 - Val Loss: 0.9399 - backbone LR: 0.000015 - head LR: 0.000300
# Epoch 27/100 - Train Loss: 0.9226 - Val Loss: 0.9490 - backbone LR: 0.000005 - head LR: 0.000090
# Epoch 28/100 - Train Loss: 0.9198 - Val Loss: 0.9418 - backbone LR: 0.000005 - head LR: 0.000090
# Epoch 29/100 - Train Loss: 0.9165 - Val Loss: 0.9630 - backbone LR: 0.000005 - head LR: 0.000090
# Early stopping triggered at epoch 29
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>learning_rate_backbone</td><td>▂▃▅▆████████████████▃▃▃▃▃▃▁▁▁</td></tr><tr><td>learning_rate_head</td><td>▂▃▅▆████████████████▃▃▃▃▃▃▁▁▁</td></tr><tr><td>train_loss</td><td>▆▇█▅▅▆▅▄▅▅▅▄▄▄▄▄▃▅▃▃▂▂▂▁▂▂▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▃▂▂▂▁▁▂▁▁▂▁▁▁▁▁▄▁▂▁▁▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>28</td></tr><tr><td>learning_rate_backbone</td><td>0.0</td></tr><tr><td>learning_rate_head</td><td>9e-05</td></tr><tr><td>note</td><td>This run uses an Eff...</td></tr><tr><td>train_loss</td><td>0.91653</td></tr><tr><td>val_loss</td><td>0.96304</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">logical-resonance-3</strong> at: <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca/runs/k5msjcoz' target="_blank">https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca/runs/k5msjcoz</a><br> View project at: <a href='https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca' target="_blank">https://wandb.ai/ggasowski977-politechnika-warszawska/hyperview_challenge%20efficientnet%20%28no%20pretrained%20encoder%29%2C%20warm%20up%20phase%20added%2C%2010M%20pixels%20rand%20pca</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260410_022733-k5msjcoz/logs</code>

# %% [markdown]
# Evaluate results in comparision to the Baseline Regressor.

# %%
class BaselineRegressor:
    """
    Baseline regressor, which calculates the mean value of the target from the training
    data and returns it for each testing sample.
    """
    def __init__(self):
        self.mean = 0

    def fit(self, X_train: np.ndarray, y_train: np.ndarray):
        self.mean = np.mean(y_train, axis=0)
        self.classes_count = y_train.shape[1]
        return self

    def predict(self, X_test: np.ndarray):
        return np.full((len(X_test), self.classes_count), self.mean)


class SpectralCurveFiltering():
    """
    Create a histogram (a spectral curve) of a 3D cube, using the merge_function
    to aggregate all pixels within one band. The return array will have
    the shape of [CHANNELS_COUNT]
    """

    def __init__(self, merge_function = np.mean):
        self.merge_function = merge_function

    def __call__(self, sample: np.ndarray):
        return self.merge_function(sample, axis=(1, 2))

# %%
def evaluate_dl_model(model, test_loader, scaler_y, device):
    """Evaluates the deep learning model on the test dataset."""
    model.eval()
    test_predictions_scaled = []
    y_true_scaled = [] # To collect the true scaled labels from the DataLoader

    with torch.no_grad():
        for X_batch_test, y_batch_true_scaled in test_loader:
            X_batch_test = X_batch_test.to(device)
            preds_batch = model(X_batch_test)
            test_predictions_scaled.append(preds_batch.cpu().numpy())
            y_true_scaled.append(y_batch_true_scaled.cpu().numpy())

    y_test_scaled_pred = np.vstack(test_predictions_scaled)
    y_test_scaled_true = np.vstack(y_true_scaled)

    # Inverse transform predictions and true values
    y_test_pred = scaler_y.inverse_transform(y_test_scaled_pred)
    y_test_true_from_loader = scaler_y.inverse_transform(y_test_scaled_true)

    model_mse_targets = np.mean((y_test_true_from_loader - y_test_pred)**2, axis=0)
    return y_test_pred, y_test_true_from_loader, model_mse_targets

def evaluate_baseline_regressor(baseline_regressor, X_test_filtered, y_test_true):
    """Evaluates the baseline regressor on the test dataset."""
    baseline_preds_test = baseline_regressor.predict(X_test_filtered)
    baseline_mse_targets = np.mean((y_test_true - baseline_preds_test)**2, axis=0)
    return baseline_preds_test, baseline_mse_targets

def calculate_and_print_results(model_mse_targets, baseline_mse_targets, y_test_true, y_test_pred, baseline_preds_test):
    """Calculates and prints the challenge score and per-target comparison, and plots results."""
    challenge_score = np.mean(model_mse_targets / baseline_mse_targets)

    target_names = ["P", "K", "Mg", "pH"]
    print("Per-target comparison (on local test set from training data):")
    for i, name in enumerate(target_names):
        print(f"{name}: Model MSE = {model_mse_targets[i]:.4f}, Baseline MSE = {baseline_mse_targets[i]:.4f}, Normalized = {model_mse_targets[i]/baseline_mse_targets[i]:.4f}")

    print(f"\nChallenge normalized score (lower is better, on local test set): {challenge_score:.4f}")

    # Plotting
    plt.figure(figsize=(15, 5))
    for i, metric in enumerate(target_names):
        plt.subplot(1, 4, i + 1)
        plt.scatter(y_test_true[:, i], y_test_pred[:, i], alpha=0.7, label='DL Model Predictions')
        plt.scatter(y_test_true[:, i], baseline_preds_test[:, i], alpha=0.7, label='Baseline Predictions', marker='x')
        min_val = min(y_test_true[:, i].min(), y_test_pred[:, i].min(), baseline_preds_test[:, i].min())
        max_val = max(y_test_true[:, i].max(), y_test_pred[:, i].max(), baseline_preds_test[:, i].max())
        plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='Ideal Prediction')
        plt.title(f'{metric} Predictions')
        plt.xlabel('True Values')
        plt.ylabel('Predictions')
        plt.grid(True)
        plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Get true y values from the local test dataset (inverse-scaled)
y_test_scaled_true = np.array([test_dataset[i][1].numpy() for i in range(len(test_dataset))])
y_test_true = scaler_y.inverse_transform(y_test_scaled_true)

# %%
# We need the original unscaled, non-PCA data for the baseline regressor
X_test_nonpca = [X_train[i] for i in test_indices]

# We need to apply SpectralCurveFiltering to the original X_test_nonpca for the baseline regressor
filtering = SpectralCurveFiltering()
X_test_filtered = np.array([filtering(cube.cpu().numpy()) for cube in X_test_nonpca])

# Train a new baseline regressor on the combined training and validation splits
# Combine train and validation indices
combined_train_val_indices = train_indices.tolist() + val_indices.tolist() # Convert to list for concatenation

# Get the original unscaled, non-PCA data for the baseline training
X_combined_train_val_nonpca = [X_train[i] for i in combined_train_val_indices]
y_combined_train_val_nonpca = y_train[combined_train_val_indices] # Use unscaled y_train for baseline training

X_combined_train_val_filtered = np.array([filtering(cube.cpu().numpy()) for cube in X_combined_train_val_nonpca])

# %%
baseline_reg_current = BaselineRegressor() # Initialize a new baseline regressor
baseline_reg_current = baseline_reg_current.fit(X_combined_train_val_filtered, y_combined_train_val_nonpca)

baseline_preds_test = baseline_reg_current.predict(X_test_filtered)

# %%
# Load the best model weights
model.load_state_dict(torch.load("best_hyperspectral_model.pth"))
model.eval()

# Iterate through the local test loader to get predictions
test_predictions_scaled = []

# # Create a DataLoader for the local test dataset
# local_test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

with torch.no_grad():
    for X_batch_test, _ in test_loader:
        X_batch_test = X_batch_test.to(next(model.parameters()).device)
        preds_batch = model(X_batch_test)
        test_predictions_scaled.append(preds_batch.cpu().numpy())

y_test_scaled_pred = np.vstack(test_predictions_scaled) # predicted in scaled units

# Convert to numpy and inverse scale to original units
y_test_pred = scaler_y.inverse_transform(y_test_scaled_pred)

# %%
# -----------------------------
# Compute MSE per target
# -----------------------------
model_mse_targets = np.mean((y_test_true - y_test_pred)**2, axis=0)
baseline_mse_targets = np.mean((y_test_true - baseline_preds_test)**2, axis=0)

# Compute normalized score (challenge metric)
challenge_score = np.mean(model_mse_targets / baseline_mse_targets)

# -----------------------------
# Print per-target comparison
# -----------------------------
target_names = ["P", "K", "Mg", "pH"]
print("Per-target comparison (on local test set from training data):")
for i, name in enumerate(target_names):
    print(f"{name}: Model MSE = {model_mse_targets[i]:.4f}, Baseline MSE = {baseline_mse_targets[i]:.4f}, Normalized = {model_mse_targets[i]/baseline_mse_targets[i]:.4f}")

print(f"\nChallenge normalized score (lower is better, on local test set): {challenge_score:.4f}")
# Out:
# Per-target comparison (on local test set from training data):
# P: Model MSE = 838.8846, Baseline MSE = 833.2123, Normalized = 1.0068
# K: Model MSE = 4089.4575, Baseline MSE = 4031.7278, Normalized = 1.0143
# Mg: Model MSE = 1539.5592, Baseline MSE = 1499.2853, Normalized = 1.0269
# pH: Model MSE = 0.0676, Baseline MSE = 0.0724, Normalized = 0.9333
#
# Challenge normalized score (lower is better, on local test set): 0.9953

# %%
# Load the best model weights for the deep learning model
model.load_state_dict(torch.load("best_hyperspectral_model.pth"))

# Evaluate the deep learning model
dl_y_test_pred, dl_y_test_true, dl_model_mse_targets = evaluate_dl_model(model, test_loader, scaler_y, device)

# Evaluate the baseline regressor (using the globally available y_test_true from inverse scaling test_dataset labels)
baseline_y_test_pred, baseline_mse_targets = evaluate_baseline_regressor(baseline_reg_current, X_test_filtered, y_test_true)

# Calculate and print combined results, including plotting
calculate_and_print_results(dl_model_mse_targets, baseline_mse_targets, y_test_true, dl_y_test_pred, baseline_y_test_pred)
# Out:
# Per-target comparison (on local test set from training data):
# P: Model MSE = 838.8846, Baseline MSE = 833.2123, Normalized = 1.0068
# K: Model MSE = 4089.4575, Baseline MSE = 4031.7278, Normalized = 1.0143
# Mg: Model MSE = 1539.5592, Baseline MSE = 1499.2853, Normalized = 1.0269
# pH: Model MSE = 0.0676, Baseline MSE = 0.0724, Normalized = 0.9333
#
# Challenge normalized score (lower is better, on local test set): 0.9953

# %%
import matplotlib.pyplot as plt
import numpy as np

target_names = ["P", "K", "Mg", "pH"]

# Get the MSEs from the kernel state
# Assuming model_mse_targets and baseline_mse_targets are available from previous execution
model_mse_targets = np.array(model_mse_targets) # Ensure it's a numpy array for indexing
baseline_mse_targets = np.array(baseline_mse_targets) # Ensure it's a numpy array for indexing

x = np.arange(len(target_names))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, model_mse_targets, width, label='Model MSE')
rects2 = ax.bar(x + width/2, baseline_mse_targets, width, label='Baseline MSE')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Target')
ax.set_ylabel('Mean Squared Error (MSE)')
ax.set_title('Model vs. Baseline MSE for Individual Targets')
ax.set_xticks(x)
ax.set_xticklabels(target_names)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()

# %%
import wandb
import matplotlib.pyplot as plt

# Assuming you are logged into wandb or using an anonymous account for the project.
# This will fetch the runs for the specified project.
# If you have multiple runs, you might need to specify the run ID or pick the latest one.

api = wandb.Api()
# Replace 'YOUR_ENTITY' with your Weights & Biases username or team name
# If you ran anonymously, the entity might be 'anonymous' or automatically inferred.
# We'll try to get the most recent run for the project.
runs = api.runs(path="hyperview_challenge efficientnet (pretrained encoder), rand pca", order="-created_at")

if runs:
    run = runs[0] # Get the latest run
    print(f"Fetching history for run: {run.name} (ID: {run.id})")
    history = run.history()

    plt.figure(figsize=(10, 6))
    plt.plot(history['epoch'], history['train_loss'], label='Train Loss')
    plt.plot(history['epoch'], history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss Curves')
    plt.xlabel('Epoch')
    plt.ylabel('Loss (MSE)')
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print("No runs found for the project 'hyperview_challenge efficientnet (pretrained encoder), rand pca'.")
    print("Please ensure you are logged into wandb or the project name is correct.")
# Out:
# Fetching history for run: futile-dominion-1 (ID: rdqcj7jx)
